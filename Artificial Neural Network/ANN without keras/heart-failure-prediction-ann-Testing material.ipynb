# %% [markdown]
#  # <h1 style='background:#6daa9f; border:0; color:black'><center>HEART FAILURE</center></h1>
#  ![Yellow%20and%20Black%20Personal%20Trainer%20LinkedIn.png](attachment:Yellow%20and%20Black%20Personal%20Trainer%20LinkedIn.png)
#
# Cardiovascular diseases are the most common cause of deaths globally, taking an estimated 17.9 million lives each year, which accounts for 31% of all deaths worldwide. Heart failure is a common event caused by Cardiovascular diseases. It is characterized by the heart’s inability to pump an adequate supply of blood to the body. Without sufficient blood flow, all major body functions are disrupted. Heart failure is a condition or a collection of symptoms that weaken the heart.

# %% [markdown]
# # **<span style="color:#6daa9f;">IMPORTING LIBRARIES</span>**

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from sklearn import preprocessing
from sklearn.preprocessing import StandardScaler
from sklearn.model_selection import train_test_split
import seaborn as sns
from keras.layers import Dense, BatchNormalization, Dropout, LSTM
from keras.models import Sequential
from keras.utils import to_categorical
from keras import callbacks
from sklearn.metrics import precision_score, recall_score, confusion_matrix, classification_report, accuracy_score, f1_score
# Out:
# 2023-02-15 11:54:26.710181: I tensorflow/core/platform/cpu_feature_guard.cc:193] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  SSE4.1 SSE4.2
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.

# %% [markdown]
# # **<span style="color:#6daa9f;">LOADING DATA</span>**

# %%
#loading data
data = pd.read_csv("heart_failure_clinical_records_dataset.csv")
data.head()
# Out:
#     age  anaemia  creatinine_phosphokinase  diabetes  ejection_fraction  \
# 0  75.0        0                       582         0                 20
# 1  55.0        0                      7861         0                 38
# 2  65.0        0                       146         0                 20
# 3  50.0        1                       111         0                 20
# 4  65.0        1                       160         1                 20
#
#    high_blood_pressure  platelets  serum_creatinine  serum_sodium  sex  \
# 0                    1  265000.00               1.9           130    1
# 1                    0  263358.03               1.1           136    1
# 2                    0  162000.00               1.3           129    1
# 3                    0  210000.00               1.9           137    1
# 4                    0  327000.00               2.7           116    0
#
#    smoking  time  DEATH_EVENT
# 0        0     4            1
# 1        0     6            1
# 2        1     7            1
# 3        0     7            1
# 4        0     8            1

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 299 entries, 0 to 298
# Data columns (total 13 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   age                       299 non-null    float64
#  1   anaemia                   299 non-null    int64
#  2   creatinine_phosphokinase  299 non-null    int64
#  3   diabetes                  299 non-null    int64
#  4   ejection_fraction         299 non-null    int64
#  5   high_blood_pressure       299 non-null    int64
#  6   platelets                 299 non-null    float64
#  7   serum_creatinine          299 non-null    float64
#  8   serum_sodium              299 non-null    int64
#  9   sex                       299 non-null    int64
#  10  smoking                   299 non-null    int64
#  11  time                      299 non-null    int64
#  12  DEATH_EVENT               299 non-null    int64
# dtypes: float64(3), int64(10)
# memory usage: 30.5 KB

# %% [markdown]
# **About the data:**
#
# * age: Age of the patient
# * anaemia: If the patient had the haemoglobin below the normal range
# * creatinine_phosphokinase: The level of the creatine phosphokinase in the blood in mcg/L
# * diabetes: If the patient was diabetic
# * ejection_fraction: Ejection fraction is a measurement of how much blood the left ventricle pumps out with each contraction
# * high_blood_pressure: If the patient had hypertension
# * platelets: Platelet count of blood in kiloplatelets/mL
# * serum_creatinine: The level of serum creatinine in the blood in mg/dL
# * serum_sodium: The level of serum sodium in the blood in mEq/L
# * sex: The sex of the patient
# * smoking: If the patient smokes actively or ever did in past
# * time: It is the time of the patient's follow-up visit for the disease in months
# * DEATH_EVENT: If the patient deceased during the follow-up period

# %% [markdown]
# # **<span style="color:#6daa9f;">DATA ANALYSIS</span>**
#
# Steps in data analysis and visulisation:
#
# We begin our analysis by plotting a count plot of the targer attribute.
# A corelation matrix od the various attributes to examine the feature importance.

# %%
#first of all let us evaluate the target and find out if our data is imbalanced or not
cols= ["#6daa9f","#774571"]
sns.countplot(x= data["DEATH_EVENT"], palette= cols)
# Out:
# <Axes: xlabel='DEATH_EVENT', ylabel='count'>

# %% [markdown]
# Point to note is that there is an imbalance in the data.

# %%
#Examaning a corelation matrix of all the features 
cmap = sns.diverging_palette(275,150,  s=40, l=65, n=9)
corrmat = data.corr()
plt.subplots(figsize=(18,18))
sns.heatmap(corrmat,cmap= cmap,annot=True, square=True);

# %% [markdown]
# **Notable points:**
# * Time of the patient's follow-up visit for the disease is crucial in as initial diagnosis with cardiovascular issue and treatment reduces the chances of any fatality. It holds and inverse relation.
# * Ejection fraction is the second most important feature. It is quite expected as it is basically the efficiency of the heart.
# * Age of the patient is the third most correlated feature. Clearly as heart's functioning declines with ageing
#
# **Next, we will examine the count plot of age.**

# %%
#Evauating age distrivution 
plt.figure(figsize=(20,12))
#colours =["#774571","#b398af","#f1f1f1" ,"#afcdc7", "#6daa9f"]
Days_of_week=sns.countplot(x=data['age'],data=data, hue ="DEATH_EVENT",palette = cols)
Days_of_week.set_title("Distribution Of Age", color="#774571")
# Out:
# Text(0.5, 1.0, 'Distribution Of Age')

# %%
# Boxen and swarm plot of some non binary features.
feature = ["age","creatinine_phosphokinase","ejection_fraction","platelets","serum_creatinine","serum_sodium", "time"]
for i in feature:
    plt.figure(figsize=(8,8))
    sns.swarmplot(x=data["DEATH_EVENT"], y=data[i], color="black", alpha=0.5)
    sns.boxenplot(x=data["DEATH_EVENT"], y=data[i], palette=cols)
    plt.show()
# Out:
# /Users/shreyanthhg/opt/anaconda3/envs/Tensorflow/lib/python3.9/site-packages/seaborn/categorical.py:3544: UserWarning: 16.7% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)

# %% [markdown]
# I spotted outliers on our dataset. I didn't remove them yet as it may lead to overfitting. Though we may end up with better statistics. In this case, with medical data, the outliers may be an important deciding factor.
#
# Next, we examine the kdeplot of time and age as they both are significant features.

# %%
sns.kdeplot(x=data["time"], y=data["age"], hue =data["DEATH_EVENT"], palette=cols)
# Out:
# <Axes: xlabel='time', ylabel='age'>

# %%
data.describe().T
# Out:
#                           count           mean           std      min  \
# age                       299.0      60.833893     11.894809     40.0
# anaemia                   299.0       0.431438      0.496107      0.0
# creatinine_phosphokinase  299.0     581.839465    970.287881     23.0
# diabetes                  299.0       0.418060      0.494067      0.0
# ejection_fraction         299.0      38.083612     11.834841     14.0
# high_blood_pressure       299.0       0.351171      0.478136      0.0
# platelets                 299.0  263358.029264  97804.236869  25100.0
# serum_creatinine          299.0       1.393880      1.034510      0.5
# serum_sodium              299.0     136.625418      4.412477    113.0
# sex                       299.0       0.648829      0.478136      0.0
# smoking                   299.0       0.321070      0.467670      0.0
# time                      299.0     130.260870     77.614208      4.0
# DEATH_EVENT               299.0       0.321070      0.467670      0.0
#
#                                25%       50%       75%       max
# age                           51.0      60.0      70.0      95.0
# anaemia                        0.0       0.0       1.0       1.0
# creatinine_phosphokinase     116.5     250.0     582.0    7861.0
# diabetes                       0.0       0.0       1.0       1.0
# ejection_fraction             30.0      38.0      45.0      80.0
# high_blood_pressure            0.0       0.0       1.0       1.0
# platelets                 212500.0  262000.0  303500.0  850000.0
# serum_creatinine               0.9       1.1       1.4       9.4
# serum_sodium                 134.0     137.0     140.0     148.0
# sex                            0.0       1.0       1.0       1.0
# smoking                        0.0       0.0       1.0       1.0
# time                          73.0     115.0     203.0     285.0
# DEATH_EVENT                    0.0       0.0       1.0       1.0

# %% [markdown]
# # **<span style="color:#6daa9f;">DATA PREPROCESSING</span>**
#
# **Steps involved in Data Preprocessing**
# * Dropping the outliers based on data analysis
# * Assigning values to features as X and target as y
# * Perform the scaling of the features
# * Split test and training sets

# %%
#assigning values to features as X and target as y
X=data.drop(["DEATH_EVENT"],axis=1)
y=data["DEATH_EVENT"]

# %%
#Set up a standard scaler for the features
col_names = list(X.columns)
s_scaler = preprocessing.StandardScaler()
X_df= s_scaler.fit_transform(X)
X_df = pd.DataFrame(X_df, columns=col_names)   
X_df.describe().T
# Out:
#                           count          mean       std       min       25%  \
# age                       299.0  5.703353e-16  1.001676 -1.754448 -0.828124
# anaemia                   299.0  1.009969e-16  1.001676 -0.871105 -0.871105
# creatinine_phosphokinase  299.0  0.000000e+00  1.001676 -0.576918 -0.480393
# diabetes                  299.0  9.060014e-17  1.001676 -0.847579 -0.847579
# ejection_fraction         299.0 -3.267546e-17  1.001676 -2.038387 -0.684180
# high_blood_pressure       299.0  0.000000e+00  1.001676 -0.735688 -0.735688
# platelets                 299.0  7.723291e-17  1.001676 -2.440155 -0.520870
# serum_creatinine          299.0  1.425838e-16  1.001676 -0.865509 -0.478205
# serum_sodium              299.0 -8.673849e-16  1.001676 -5.363206 -0.595996
# sex                       299.0 -8.911489e-18  1.001676 -1.359272 -1.359272
# smoking                   299.0 -1.188199e-17  1.001676 -0.687682 -0.687682
# time                      299.0 -1.901118e-16  1.001676 -1.629502 -0.739000
#
#                                50%       75%       max
# age                      -0.070223  0.771889  2.877170
# anaemia                  -0.871105  1.147968  1.147968
# creatinine_phosphokinase -0.342574  0.000166  7.514640
# diabetes                 -0.847579  1.179830  1.179830
# ejection_fraction        -0.007077  0.585389  3.547716
# high_blood_pressure      -0.735688  1.359272  1.359272
# platelets                -0.013908  0.411120  6.008180
# serum_creatinine         -0.284552  0.005926  7.752020
# serum_sodium              0.085034  0.766064  2.582144
# sex                       0.735688  0.735688  0.735688
# smoking                  -0.687682  1.454161  1.454161
# time                     -0.196954  0.938759  1.997038

# %%
#looking at the scaled features
colours =["#774571","#b398af","#f1f1f1" ,"#afcdc7", "#6daa9f"]
plt.figure(figsize=(20,10))
sns.boxenplot(data = X_df,palette = colours)
plt.xticks(rotation=90)
plt.show()

# %%
#spliting test and training sets
X_train, X_test, y_train,y_test = train_test_split(X_df,y,test_size=0.25,random_state=7)

# %% [markdown]
# # **<span style="color:#6daa9f;">MODEL BUILDING</span>**
#
# In this project, we build an artificial neural network.
#
# **Following steps are involved in the model building**
# * Initialising the ANN
# * Defining by adding layers
# * Compiling the ANN
# * Train the ANN

# %% [markdown]
# monitor: Quantity to be monitored.
#
# min_delta: Minimum change in the monitored quantity to qualify as an improvement, i.e. an absolute change of less than min_delta, will count as no improvement.
#
# patience: Number of epochs with no improvement after which training will be stopped.
#
# verbose: Verbosity mode, 0 or 1. Mode 0 is silent, and mode 1 displays messages when the callback takes an action.
#
# mode: One of {"auto", "min", "max"}. In min mode, training will stop when the quantity monitored has stopped decreasing; in "max" mode it will stop when the quantity monitored has stopped increasing; in "auto" mode, the direction is automatically inferred from the name of the monitored quantity.
#
# baseline: Baseline value for the monitored quantity. Training will stop if the model doesn't show improvement over the baseline.
#
# restore_best_weights: Whether to restore model weights from the epoch with the best value of the monitored quantity. If False, the model weights obtained at the last step of training are used. An epoch will be restored regardless of the performance relative to the baseline. If no epoch improves on baseline, training will run for patience epochs and restore weights from the best epoch in that set.
#
# start_from_epoch: Number of epochs to wait before starting to monitor improvement. This allows for a warm-up period in which no improvement is expected and thus training will not be stopped.

# %%
early_stopping = callbacks.EarlyStopping(
    min_delta=0.001, # minimium amount of change to count as an improvement
    patience=20, # how many epochs to wait before stopping
    restore_best_weights=True)

# Initialising the NN
model = Sequential()

# layers
model.add(Dense(units = 16, kernel_initializer = 'uniform', activation = 'relu', input_dim = 12))
model.add(Dense(units = 8, kernel_initializer = 'uniform', activation = 'relu'))
model.add(Dropout(0.25))
model.add(Dense(units = 4, kernel_initializer = 'uniform', activation = 'relu'))
model.add(Dropout(0.5))
model.add(Dense(units = 1, kernel_initializer = 'uniform', activation = 'sigmoid'))
from keras.optimizers import SGD
# Compiling the ANN
model.compile(optimizer = 'adam', loss = 'binary_crossentropy', metrics = ['accuracy'])

# Train the ANN
history = model.fit(X_train, y_train, batch_size = 32, epochs = 500,callbacks=[early_stopping], validation_split=0.2)
# Out:
# 2023-02-15 11:54:33.736588: I tensorflow/core/platform/cpu_feature_guard.cc:193] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  SSE4.1 SSE4.2
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.
# /Users/shreyanthhg/opt/anaconda3/envs/Tensorflow/lib/python3.9/site-packages/keras/engine/data_adapter.py:1699: FutureWarning: The behavior of `series[i:j]` with an integer-dtype index is deprecated. In a future version, this will be treated as *label-based* indexing, consistent with e.g. `series[i]` lookups. To retain the old behavior, use `series.iloc[i:j]`. To get the future behavior, use `series.loc[i:j]`.
#   return t[start:end]
# Epoch 1/500
# 6/6 [==============================] - 0s 25ms/step - loss: 0.6928 - accuracy: 0.6313 - val_loss: 0.6921 - val_accuracy: 0.6667
# Epoch 2/500
# 6/6 [==============================] - 0s 4ms/step - loss: 0.6919 - accuracy: 0.6480 - val_loss: 0.6912 - val_accuracy: 0.6667
# Epoch 3/500
# 6/6 [==============================] - 0s 5ms/step - loss: 0.6912 - accuracy: 0.6480 - val_loss: 0.6903 - val_accuracy: 0.6667
# Epoch 4/500
# 6/6 [==============================] - 0s 4ms/step - loss: 0.6903 - accuracy: 0.6480 - val_loss: 0.6893 - val_accuracy: 0.6667
# Epoch 5/500
# 6/6 [==============================] - 0s 5ms/step - loss: 0.6893 - accuracy: 0.6480 - val_loss: 0.6884 - val_accuracy: 0.6667
# Epoch 6/500
# 6/6 [==============================] - 0s 5ms/step - loss: 0.6886 - accuracy: 0.6480 - val_loss: 0.6874 - val_accuracy: 0.6667
# Epoch 7/500
# 6/6 [==============================] - 0s 5ms/step - loss: 0.6875 - accuracy: 0.6480 - val_loss: 0.6863 - val_accuracy: 0.6667
# Epoch 8/500
# 6/6 [==============================] - 0s 5ms/step - loss: 0.6866 - accuracy: 0.6480 - val_loss: 0.6851 - val_accuracy: 0.6667
# Epoch 9/500
# 6/6 [==============================] - 0s 5ms/step - loss: 0.6856 - accuracy: 0.6480 - val_loss: 0.6837 - val_accuracy: 0.6667
# Epoch 10/500
# 6/6 [==============================] - 0s 5ms/step - loss: 0.6844 - accuracy: 0.6480 - val_loss: 0.6822 - val_accuracy: 0.6667
# Epoch 11/500
# 6/6 [==============================] - 0s 5ms/step - loss: 0.6832 - accuracy: 0.6480 - val_loss: 0.6803 - val_accuracy: 0.6667
# Epoch 12/500
# 6/6 [==============================] - 0s 5ms/step - loss: 0.6824 - accuracy: 0.6480 - val_loss: 0.6781 - val_accuracy: 0.6667
# Epoch 13/500
# 6/6 [==============================] - 0s 5ms/step - loss: 0.6799 - accuracy: 0.6480 - val_loss: 0.6756 - val_accuracy: 0.6667
# Epoch 14/500
# 6/6 [==============================] - 0s 5ms/step - loss: 0.6752 - accuracy: 0.6480 - val_loss: 0.6724 - val_accuracy: 0.6667
# Epoch 15/500
# 6/6 [==============================] - 0s 5ms/step - loss: 0.6736 - accuracy: 0.6480 - val_loss: 0.6679 - val_accuracy: 0.6667
# Epoch 16/500
# 6/6 [==============================] - 0s 5ms/step - loss: 0.6711 - accuracy: 0.6480 - val_loss: 0.6628 - val_accuracy: 0.6667
# Epoch 17/500
# 6/6 [==============================] - 0s 5ms/step - loss: 0.6626 - accuracy: 0.6480 - val_loss: 0.6567 - val_accuracy: 0.6667
# Epoch 18/500
# 6/6 [==============================] - 0s 5ms/step - loss: 0.6605 - accuracy: 0.6480 - val_loss: 0.6488 - val_accuracy: 0.6667
# Epoch 19/500
# 6/6 [==============================] - 0s 5ms/step - loss: 0.6489 - accuracy: 0.6480 - val_loss: 0.6393 - val_accuracy: 0.6667
# Epoch 20/500
# 6/6 [==============================] - 0s 5ms/step - loss: 0.6435 - accuracy: 0.6480 - val_loss: 0.6279 - val_accuracy: 0.6667
# Epoch 21/500
# 6/6 [==============================] - 0s 5ms/step - loss: 0.6384 - accuracy: 0.6480 - val_loss: 0.6157 - val_accuracy: 0.6667
# Epoch 22/500
# 6/6 [==============================] - 0s 4ms/step - loss: 0.6303 - accuracy: 0.6480 - val_loss: 0.6026 - val_accuracy: 0.6667
# Epoch 23/500
# 6/6 [==============================] - 0s 4ms/step - loss: 0.6127 - accuracy: 0.6480 - val_loss: 0.5879 - val_accuracy: 0.6667
# Epoch 24/500
# 6/6 [==============================] - 0s 4ms/step - loss: 0.6004 - accuracy: 0.6480 - val_loss: 0.5726 - val_accuracy: 0.6667
# Epoch 25/500
# 6/6 [==============================] - 0s 5ms/step - loss: 0.5872 - accuracy: 0.6480 - val_loss: 0.5592 - val_accuracy: 0.6667
# Epoch 26/500
# 6/6 [==============================] - 0s 4ms/step - loss: 0.5673 - accuracy: 0.6480 - val_loss: 0.5466 - val_accuracy: 0.6667
# Epoch 27/500
# 6/6 [==============================] - 0s 5ms/step - loss: 0.5943 - accuracy: 0.6480 - val_loss: 0.5368 - val_accuracy: 0.6667
# Epoch 28/500
# 6/6 [==============================] - 0s 4ms/step - loss: 0.5421 - accuracy: 0.6480 - val_loss: 0.5279 - val_accuracy: 0.6667
# Epoch 29/500
# 6/6 [==============================] - 0s 5ms/step - loss: 0.5660 - accuracy: 0.6480 - val_loss: 0.5214 - val_accuracy: 0.6667
# Epoch 30/500
# 6/6 [==============================] - 0s 4ms/step - loss: 0.5455 - accuracy: 0.6480 - val_loss: 0.5167 - val_accuracy: 0.6667
# Epoch 31/500
# 6/6 [==============================] - 0s 5ms/step - loss: 0.5663 - accuracy: 0.6480 - val_loss: 0.5143 - val_accuracy: 0.6667
# Epoch 32/500
# 6/6 [==============================] - 0s 4ms/step - loss: 0.5286 - accuracy: 0.6480 - val_loss: 0.5138 - val_accuracy: 0.6667
# Epoch 33/500
# 6/6 [==============================] - 0s 5ms/step - loss: 0.5430 - accuracy: 0.6480 - val_loss: 0.5135 - val_accuracy: 0.6667
# Epoch 34/500
# 6/6 [==============================] - 0s 4ms/step - loss: 0.5209 - accuracy: 0.6480 - val_loss: 0.5135 - val_accuracy: 0.6667
# Epoch 35/500
# 6/6 [==============================] - 0s 4ms/step - loss: 0.5039 - accuracy: 0.6480 - val_loss: 0.5134 - val_accuracy: 0.6667
# Epoch 36/500
# 6/6 [==============================] - 0s 4ms/step - loss: 0.5265 - accuracy: 0.6480 - val_loss: 0.5132 - val_accuracy: 0.6667
# Epoch 37/500
# 6/6 [==============================] - 0s 4ms/step - loss: 0.5301 - accuracy: 0.6480 - val_loss: 0.5126 - val_accuracy: 0.6667
# Epoch 38/500
# 6/6 [==============================] - 0s 4ms/step - loss: 0.5181 - accuracy: 0.6480 - val_loss: 0.5128 - val_accuracy: 0.6667
# Epoch 39/500
# 6/6 [==============================] - 0s 4ms/step - loss: 0.5184 - accuracy: 0.6480 - val_loss: 0.5124 - val_accuracy: 0.6667
# Epoch 40/500
# 6/6 [==============================] - 0s 5ms/step - loss: 0.5213 - accuracy: 0.6480 - val_loss: 0.5121 - val_accuracy: 0.6667
# Epoch 41/500
# 6/6 [==============================] - 0s 4ms/step - loss: 0.5340 - accuracy: 0.6480 - val_loss: 0.5112 - val_accuracy: 0.6667
# Epoch 42/500
# 6/6 [==============================] - 0s 4ms/step - loss: 0.5075 - accuracy: 0.6480 - val_loss: 0.5091 - val_accuracy: 0.6667
# Epoch 43/500
# 6/6 [==============================] - 0s 4ms/step - loss: 0.5233 - accuracy: 0.6480 - val_loss: 0.5088 - val_accuracy: 0.6667
# Epoch 44/500
# 6/6 [==============================] - 0s 4ms/step - loss: 0.5347 - accuracy: 0.6480 - val_loss: 0.5076 - val_accuracy: 0.6667
# Epoch 45/500
# 6/6 [==============================] - 0s 4ms/step - loss: 0.5088 - accuracy: 0.6480 - val_loss: 0.5070 - val_accuracy: 0.6667
# Epoch 46/500
# 6/6 [==============================] - 0s 4ms/step - loss: 0.5098 - accuracy: 0.6480 - val_loss: 0.5069 - val_accuracy: 0.6667
# Epoch 47/500
# 6/6 [==============================] - 0s 4ms/step - loss: 0.4965 - accuracy: 0.6480 - val_loss: 0.5078 - val_accuracy: 0.6667
# Epoch 48/500
# 6/6 [==============================] - 0s 4ms/step - loss: 0.5079 - accuracy: 0.6480 - val_loss: 0.5096 - val_accuracy: 0.6667
# Epoch 49/500
# 6/6 [==============================] - 0s 4ms/step - loss: 0.5473 - accuracy: 0.6480 - val_loss: 0.5115 - val_accuracy: 0.6667
# Epoch 50/500
# 6/6 [==============================] - 0s 4ms/step - loss: 0.5200 - accuracy: 0.6480 - val_loss: 0.5123 - val_accuracy: 0.6667
# Epoch 51/500
# 6/6 [==============================] - 0s 5ms/step - loss: 0.5523 - accuracy: 0.6480 - val_loss: 0.5129 - val_accuracy: 0.6667
# Epoch 52/500
# 6/6 [==============================] - 0s 4ms/step - loss: 0.5206 - accuracy: 0.6480 - val_loss: 0.5120 - val_accuracy: 0.6667
# Epoch 53/500
# 6/6 [==============================] - 0s 4ms/step - loss: 0.5556 - accuracy: 0.6480 - val_loss: 0.5110 - val_accuracy: 0.6667
# Epoch 54/500
# 6/6 [==============================] - 0s 4ms/step - loss: 0.5137 - accuracy: 0.6480 - val_loss: 0.5100 - val_accuracy: 0.6667
# Epoch 55/500
# 6/6 [==============================] - 0s 4ms/step - loss: 0.5486 - accuracy: 0.6480 - val_loss: 0.5083 - val_accuracy: 0.6667
# Epoch 56/500
# 6/6 [==============================] - 0s 4ms/step - loss: 0.5024 - accuracy: 0.6480 - val_loss: 0.5079 - val_accuracy: 0.6667
# Epoch 57/500
# 6/6 [==============================] - 0s 4ms/step - loss: 0.5080 - accuracy: 0.6480 - val_loss: 0.5066 - val_accuracy: 0.6667
# Epoch 58/500
# 6/6 [==============================] - 0s 4ms/step - loss: 0.5211 - accuracy: 0.6480 - val_loss: 0.5067 - val_accuracy: 0.6667
# Epoch 59/500
# 6/6 [==============================] - 0s 4ms/step - loss: 0.5017 - accuracy: 0.6480 - val_loss: 0.5064 - val_accuracy: 0.6667
# Epoch 60/500
# 6/6 [==============================] - 0s 4ms/step - loss: 0.4933 - accuracy: 0.6480 - val_loss: 0.5055 - val_accuracy: 0.6667
# Epoch 61/500
# 6/6 [==============================] - 0s 4ms/step - loss: 0.5147 - accuracy: 0.6480 - val_loss: 0.5051 - val_accuracy: 0.6667
# Epoch 62/500
# 6/6 [==============================] - 0s 4ms/step - loss: 0.5052 - accuracy: 0.6480 - val_loss: 0.5054 - val_accuracy: 0.6667
# Epoch 63/500
# 6/6 [==============================] - 0s 4ms/step - loss: 0.5264 - accuracy: 0.6480 - val_loss: 0.5055 - val_accuracy: 0.6667
# Epoch 64/500
# 6/6 [==============================] - 0s 4ms/step - loss: 0.5332 - accuracy: 0.6480 - val_loss: 0.5060 - val_accuracy: 0.6667
# Epoch 65/500
# 6/6 [==============================] - 0s 4ms/step - loss: 0.4810 - accuracy: 0.6480 - val_loss: 0.5074 - val_accuracy: 0.6667
# Epoch 66/500
# 6/6 [==============================] - 0s 4ms/step - loss: 0.5121 - accuracy: 0.6480 - val_loss: 0.5075 - val_accuracy: 0.6667
# Epoch 67/500
# 6/6 [==============================] - 0s 4ms/step - loss: 0.4970 - accuracy: 0.6480 - val_loss: 0.5082 - val_accuracy: 0.6667
# Epoch 68/500
# 6/6 [==============================] - 0s 4ms/step - loss: 0.5208 - accuracy: 0.6480 - val_loss: 0.5083 - val_accuracy: 0.6667
# Epoch 69/500
# 6/6 [==============================] - 0s 4ms/step - loss: 0.4884 - accuracy: 0.6480 - val_loss: 0.5083 - val_accuracy: 0.6667
# Epoch 70/500
# 6/6 [==============================] - 0s 4ms/step - loss: 0.5362 - accuracy: 0.6480 - val_loss: 0.5086 - val_accuracy: 0.6667
# Epoch 71/500
# 6/6 [==============================] - 0s 4ms/step - loss: 0.4900 - accuracy: 0.6480 - val_loss: 0.5091 - val_accuracy: 0.6667
# Epoch 72/500
# 6/6 [==============================] - 0s 4ms/step - loss: 0.5331 - accuracy: 0.6480 - val_loss: 0.5096 - val_accuracy: 0.6667
# Epoch 73/500
# 6/6 [==============================] - 0s 4ms/step - loss: 0.5323 - accuracy: 0.6480 - val_loss: 0.5101 - val_accuracy: 0.6667
# Epoch 74/500
# 6/6 [==============================] - 0s 4ms/step - loss: 0.5159 - accuracy: 0.6480 - val_loss: 0.5112 - val_accuracy: 0.6667
# Epoch 75/500
# 6/6 [==============================] - 0s 4ms/step - loss: 0.5438 - accuracy: 0.6480 - val_loss: 0.5104 - val_accuracy: 0.6667
# Epoch 76/500
# 6/6 [==============================] - 0s 4ms/step - loss: 0.5277 - accuracy: 0.6480 - val_loss: 0.5080 - val_accuracy: 0.6667
# Epoch 77/500
# 6/6 [==============================] - 0s 4ms/step - loss: 0.5382 - accuracy: 0.6480 - val_loss: 0.5071 - val_accuracy: 0.6667
# Epoch 78/500
# 6/6 [==============================] - 0s 4ms/step - loss: 0.5104 - accuracy: 0.6480 - val_loss: 0.5066 - val_accuracy: 0.6667
# Epoch 79/500
# 6/6 [==============================] - 0s 4ms/step - loss: 0.5231 - accuracy: 0.6480 - val_loss: 0.5070 - val_accuracy: 0.6667
# Epoch 80/500
# 6/6 [==============================] - 0s 5ms/step - loss: 0.4869 - accuracy: 0.6480 - val_loss: 0.5076 - val_accuracy: 0.6667

# %%
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense (Dense)               (None, 16)                208
#
#  dense_1 (Dense)             (None, 8)                 136
#
#  dropout (Dropout)           (None, 8)                 0
#
#  dense_2 (Dense)             (None, 4)                 36
#
#  dropout_1 (Dropout)         (None, 4)                 0
#
#  dense_3 (Dense)             (None, 1)                 5
#
# =================================================================
# Total params: 385
# Trainable params: 385
# Non-trainable params: 0
# _________________________________________________________________

# %%
val_accuracy = np.mean(history.history['val_accuracy'])
print("\n%s: %.2f%%" % ('val_accuracy', val_accuracy*100))
# Out:
# val_accuracy: 66.67%

# %% [markdown]
# **Plotting training and validation loss over epochs**

# %%
history_df = pd.DataFrame(history.history)

plt.plot(history_df.loc[:, ['loss']], "#6daa9f", label='Training loss')
plt.plot(history_df.loc[:, ['val_loss']],"#774571", label='Validation loss')
plt.title('Training and Validation loss')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.legend(loc="best")

plt.show()

# %% [markdown]
# **Plotting training and validation accuracy over epochs**

# %%
history_df = pd.DataFrame(history.history)

plt.plot(history_df.loc[:, ['accuracy']], "#6daa9f", label='Training accuracy')
plt.plot(history_df.loc[:, ['val_accuracy']], "#774571", label='Validation accuracy')

plt.title('Training and Validation accuracy')
plt.xlabel('Epochs')
plt.ylabel('Accuracy')
plt.legend()
plt.show()

# %% [markdown]
# # **<span style="color:#6daa9f;">CONCLUSIONS</span>**
#
# **Concluding the model with:**
#
# * Testing on the test set
# * Evaluating the confusion matrix
# * Evaluating the classification report

# %%
# Predicting the test set results
y_pred = model.predict(X_test)
y_pred = (y_pred > 0.5)
np.set_printoptions()
# Out:
# 3/3 [==============================] - 0s 918us/step

# %%
# confusion matrix
cmap1 = sns.diverging_palette(275,150,  s=40, l=65, n=6)
plt.subplots(figsize=(12,8))
cf_matrix = confusion_matrix(y_test, y_pred)
sns.heatmap(cf_matrix/np.sum(cf_matrix), cmap = cmap1, annot = True, annot_kws = {'size':15})
# Out:
# <Axes: >

# %%
print(classification_report(y_test, y_pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.76      1.00      0.86        57
#            1       0.00      0.00      0.00        18
#
#     accuracy                           0.76        75
#    macro avg       0.38      0.50      0.43        75
# weighted avg       0.58      0.76      0.66        75
# /Users/shreyanthhg/opt/anaconda3/envs/Tensorflow/lib/python3.9/site-packages/sklearn/metrics/_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /Users/shreyanthhg/opt/anaconda3/envs/Tensorflow/lib/python3.9/site-packages/sklearn/metrics/_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /Users/shreyanthhg/opt/anaconda3/envs/Tensorflow/lib/python3.9/site-packages/sklearn/metrics/_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))

# %% [markdown]
# **<span style="color:#b398af;"> If you liked this Notebook, please do upvote.</span>**
#
# **<span style="color:#b398af;"> If you have any suggestions or questions, feel free to comment!</span>**
#
# **<span style="color:#b398af;">Best Wishes!</span>**
#
#
# # <h1 style='background:#6daa9f; border:0; color:black'><center>FIN</center></h1>

# %%
pip install ai-benchmark
# Out:
# Collecting ai-benchmark
#   Downloading ai_benchmark-0.1.2-py3-none-any.whl (21.5 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 21.5/21.5 MB 5.5 MB/s eta 0:00:0000:0100:01
# Requirement already satisfied: requests in /Users/shreyanthhg/opt/anaconda3/envs/Tensorflow/lib/python3.9/site-packages (from ai-benchmark) (2.28.2)
# Requirement already satisfied: pillow in /Users/shreyanthhg/opt/anaconda3/envs/Tensorflow/lib/python3.9/site-packages (from ai-benchmark) (9.4.0)
# Collecting py-cpuinfo
#   Downloading py_cpuinfo-9.0.0-py3-none-any.whl (22 kB)
# Requirement already satisfied: numpy in /Users/shreyanthhg/opt/anaconda3/envs/Tensorflow/lib/python3.9/site-packages (from ai-benchmark) (1.24.2)
# Requirement already satisfied: psutil in /Users/shreyanthhg/opt/anaconda3/envs/Tensorflow/lib/python3.9/site-packages (from ai-benchmark) (5.9.0)
# Requirement already satisfied: setuptools in /Users/shreyanthhg/opt/anaconda3/envs/Tensorflow/lib/python3.9/site-packages (from ai-benchmark) (65.6.3)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in /Users/shreyanthhg/opt/anaconda3/envs/Tensorflow/lib/python3.9/site-packages (from requests->ai-benchmark) (1.26.14)
# Requirement already satisfied: certifi>=2017.4.17 in /Users/shreyanthhg/opt/anaconda3/envs/Tensorflow/lib/python3.9/site-packages (from requests->ai-benchmark) (2022.12.7)
# Requirement already satisfied: idna<4,>=2.5 in /Users/shreyanthhg/opt/anaconda3/envs/Tensorflow/lib/python3.9/site-packages (from requests->ai-benchmark) (3.4)
# Requirement already satisfied: charset-normalizer<4,>=2 in /Users/shreyanthhg/opt/anaconda3/envs/Tensorflow/lib/python3.9/site-packages (from requests->ai-benchmark) (3.0.1)
# Installing collected packages: py-cpuinfo, ai-benchmark
# Successfully installed ai-benchmark-0.1.2 py-cpuinfo-9.0.0
# Note: you may need to restart the kernel to use updated packages.

# %%
from ai_benchmark import AIBenchmark
benchmark = AIBenchmark()
results = benchmark.run()
# Out:
# >>   AI-Benchmark-v.0.1.2
# >>   Let the AI Games begin..
#
# *  TF Version: 2.10.0
# *  Platform: macOS-10.16-x86_64-i386-64bit
# *  CPU: N/A
# *  CPU RAM: 8 GB
#
# The benchmark is running...
# The tests might take up to 20 minutes
# Please don't interrupt the script
#
# 1/19. MobileNet-V2
#
# 1.1 - inference | batch=50, size=224x224: 390 ± 19 ms
# 1.2 - training  | batch=50, size=224x224: 2489 ± 198 ms
#
# 2/19. Inception-V3
#
# 2.1 - inference | batch=20, size=346x346: 2110 ± 69 ms
# 2.2 - training  | batch=20, size=346x346: 8625 ± 80 ms
#
# 3/19. Inception-V4
#
# 3.1 - inference | batch=10, size=346x346: 2409 ± 45 ms
# 3.2 - training  | batch=10, size=346x346: 9360 ± 345 ms
#
# 4/19. Inception-ResNet-V2
#
# 4.1 - inference | batch=10, size=346x346: 2801 ± 58 ms
# 4.2 - training  | batch=8, size=346x346: 8525 ± 289 ms
#
# 5/19. ResNet-V2-50
#
# 5.1 - inference | batch=10, size=346x346: 1507 ± 42 ms
# 5.2 - training  | batch=10, size=346x346: 5536 ± 81 ms
#
# 6/19. ResNet-V2-152
#
# 6.1 - inference | batch=10, size=256x256: 2514 ± 48 ms
# 6.2 - training  | batch=10, size=256x256: 9650 ± 153 ms
#
# 7/19. VGG-16
#
# 7.1 - inference | batch=20, size=224x224: 5047 ± 80 ms
# 7.2 - training  | batch=2, size=224x224: 4236 ± 149 ms
#
# 8/19. SRCNN 9-5-5
#
# 8.1 - inference | batch=10, size=512x512: 3855 ± 116 ms
# 8.2 - inference | batch=1, size=1536x1536: 3542 ± 52 ms
# 8.3 - training  | batch=10, size=512x512: 22488 ± 457 ms
#
# 9/19. VGG-19 Super-Res
#
# 9.1 - inference | batch=10, size=256x256: 7551 ± 67 ms
# 9.2 - inference | batch=1, size=1024x1024: 12584 ± 145 ms
# 9.3 - training  | batch=10, size=224x224: 20164 ± 24 ms
#
# 10/19. ResNet-SRGAN
#
# 10.1 - inference | batch=10, size=512x512: 6062 ± 223 ms
# 10.2 - inference | batch=1, size=1536x1536: 5390 ± 140 ms
# 10.3 - training  | batch=5, size=512x512: 10101 ± 139 ms
#
# 11/19. ResNet-DPED
#
# 11.1 - inference | batch=10, size=256x256: 6557 ± 147 ms
# 11.2 - inference | batch=1, size=1024x1024: 10474 ± 252 ms
# 11.3 - training  | batch=15, size=128x128: 8268 ± 78 ms
#
# 12/19. U-Net
#
# 12.1 - inference | batch=4, size=512x512: 14869 ± 226 ms
# 12.2 - inference | batch=1, size=1024x1024: 15455 ± 398 ms
# 12.3 - training  | batch=4, size=256x256: 14787 ± 681 ms
#
# 13/19. Nvidia-SPADE
#
# 13.1 - inference | batch=5, size=128x128: 6534 ± 78 ms
# 13.2 - training  | batch=1, size=128x128: 5895 ± 488 ms
#
# 14/19. ICNet
#
# 14.1 - inference | batch=5, size=1024x1536: 2690 ± 76 ms
# 14.2 - training  | batch=10, size=1024x1536: 6594 ± 195 ms
#
# 15/19. PSPNet
#
# 15.1 - inference | batch=5, size=720x720: 32671 ± 685 ms
# 15.2 - training  | batch=1, size=512x512: 12046 ± 377 ms
#
# 16/19. DeepLab
#
# 16.1 - inference | batch=2, size=512x512: 7302 ± 89 ms
# 16.2 - training  | batch=1, size=384x384: 7366 ± 156 ms
#
# 17/19. Pixel-RNN
#
# 17.1 - inference | batch=50, size=64x64: 1648 ± 254 ms
# 17.2 - training  | batch=10, size=64x64: 1323 ± 127 ms
#
# 18/19. LSTM-Sentiment
#
# 18.1 - inference | batch=100, size=1024x300: 14703 ± 592 ms
# 18.2 - training  | batch=10, size=1024x300: 42766 ± 1118 ms
#
# 19/19. GNMT-Translation
#
# 19.1 - inference | batch=1, size=1x20: 1050 ± 46 ms
#
# Device Inference Score: 306
# Device Training Score: 354
# Device AI Score: 660
#
# For more information and results, please visit http://ai-benchmark.com/alpha

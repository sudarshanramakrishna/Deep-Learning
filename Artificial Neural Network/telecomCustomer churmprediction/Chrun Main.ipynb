# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
import warnings
warnings.filterwarnings("ignore")

# %%
chrun = pd.read_csv('churn_data.csv')
customer = pd.read_csv('customer_data.csv')
internet = pd.read_csv('internet_data.csv')

# %%
chrun
# Out:
#       customerID  tenure PhoneService        Contract PaperlessBilling  \
# 0     7590-VHVEG     1.0           No  Month-to-month              Yes
# 1     5575-GNVDE    34.0          Yes        One year               No
# 2     3668-QPYBK     2.0          Yes  Month-to-month              Yes
# 3     7795-CFOCW    45.0           No        One year               No
# 4     9237-HQITU     2.0          Yes  Month-to-month              Yes
# ...          ...     ...          ...             ...              ...
# 7037  2569-WGERO    72.0          Yes        Two year              Yes
# 7038  6840-RESVB    24.0          Yes        One year              Yes
# 7039  2234-XADUH    72.0          Yes        One year              Yes
# 7040  4801-JZAZL    11.0           No  Month-to-month              Yes
# 7041  8361-LTMKD     4.0          Yes  Month-to-month              Yes
#
#                   PaymentMethod  MonthlyCharges TotalCharges Churn
# 0              Electronic check           29.85        29.85    No
# 1                  Mailed check           56.95       1889.5    No
# 2                  Mailed check           53.85          NaN   Yes
# 3     Bank transfer (automatic)           42.30      1840.75    No
# 4              Electronic check           70.70       151.65   Yes
# ...                         ...             ...          ...   ...
# 7037  Bank transfer (automatic)           21.15       1419.4    No
# 7038               Mailed check           84.80       1990.5    No
# 7039    Credit card (automatic)          103.20       7362.9    No
# 7040           Electronic check           29.60       346.45    No
# 7041               Mailed check           74.40        306.6   Yes
#
# [7042 rows x 9 columns]

# %%
customer
# Out:
#       customerID  gender  SeniorCitizen Partner Dependents
# 0     7590-VHVEG  Female              0     Yes         No
# 1     5575-GNVDE    Male              0      No         No
# 2     3668-QPYBK    Male              0      No         No
# 3     7795-CFOCW    Male              0      No         No
# 4     9237-HQITU  Female              0      No         No
# ...          ...     ...            ...     ...        ...
# 7037  2569-WGERO  Female              0      No         No
# 7038  6840-RESVB    Male              0     Yes        Yes
# 7039  2234-XADUH  Female              0     Yes        Yes
# 7040  4801-JZAZL  Female              0     Yes        Yes
# 7041  8361-LTMKD    Male              1     Yes         No
#
# [7042 rows x 5 columns]

# %%
internet
# Out:
#       customerID     MultipleLines InternetService       OnlineSecurity  \
# 0     7590-VHVEG  No phone service             DSL                   No
# 1     5575-GNVDE                No             DSL                  Yes
# 2     3668-QPYBK                No             DSL                  Yes
# 3     7795-CFOCW  No phone service             DSL                  Yes
# 4     9237-HQITU                No     Fiber optic                   No
# ...          ...               ...             ...                  ...
# 7037  2569-WGERO                No              No  No internet service
# 7038  6840-RESVB               Yes             DSL                  Yes
# 7039  2234-XADUH               Yes     Fiber optic                   No
# 7040  4801-JZAZL  No phone service             DSL                  Yes
# 7041  8361-LTMKD               Yes     Fiber optic                   No
#
#              OnlineBackup     DeviceProtection          TechSupport  \
# 0                     Yes                   No                   No
# 1                      No                  Yes                   No
# 2                     Yes                   No                   No
# 3                      No                  Yes                  Yes
# 4                      No                   No                   No
# ...                   ...                  ...                  ...
# 7037  No internet service  No internet service  No internet service
# 7038                   No                  Yes                  Yes
# 7039                  Yes                  Yes                   No
# 7040                   No                   No                   No
# 7041                   No                   No                   No
#
#               StreamingTV      StreamingMovies
# 0                      No                   No
# 1                      No                   No
# 2                      No                   No
# 3                      No                   No
# 4                      No                   No
# ...                   ...                  ...
# 7037  No internet service  No internet service
# 7038                  Yes                  Yes
# 7039                  Yes                  Yes
# 7040                   No                   No
# 7041                   No                   No
#
# [7042 rows x 9 columns]

# %%
chrun_customer = pd.merge(chrun, customer, how='left', on=['customerID'])
chrun_customer
# Out:
#       customerID  tenure PhoneService        Contract PaperlessBilling  \
# 0     7590-VHVEG     1.0           No  Month-to-month              Yes
# 1     5575-GNVDE    34.0          Yes        One year               No
# 2     3668-QPYBK     2.0          Yes  Month-to-month              Yes
# 3     7795-CFOCW    45.0           No        One year               No
# 4     9237-HQITU     2.0          Yes  Month-to-month              Yes
# ...          ...     ...          ...             ...              ...
# 7037  2569-WGERO    72.0          Yes        Two year              Yes
# 7038  6840-RESVB    24.0          Yes        One year              Yes
# 7039  2234-XADUH    72.0          Yes        One year              Yes
# 7040  4801-JZAZL    11.0           No  Month-to-month              Yes
# 7041  8361-LTMKD     4.0          Yes  Month-to-month              Yes
#
#                   PaymentMethod  MonthlyCharges TotalCharges Churn  gender  \
# 0              Electronic check           29.85        29.85    No  Female
# 1                  Mailed check           56.95       1889.5    No    Male
# 2                  Mailed check           53.85          NaN   Yes    Male
# 3     Bank transfer (automatic)           42.30      1840.75    No    Male
# 4              Electronic check           70.70       151.65   Yes  Female
# ...                         ...             ...          ...   ...     ...
# 7037  Bank transfer (automatic)           21.15       1419.4    No  Female
# 7038               Mailed check           84.80       1990.5    No    Male
# 7039    Credit card (automatic)          103.20       7362.9    No  Female
# 7040           Electronic check           29.60       346.45    No  Female
# 7041               Mailed check           74.40        306.6   Yes    Male
#
#       SeniorCitizen Partner Dependents
# 0                 0     Yes         No
# 1                 0      No         No
# 2                 0      No         No
# 3                 0      No         No
# 4                 0      No         No
# ...             ...     ...        ...
# 7037              0      No         No
# 7038              0     Yes        Yes
# 7039              0     Yes        Yes
# 7040              0     Yes        Yes
# 7041              1     Yes         No
#
# [7042 rows x 13 columns]

# %%
final = pd.merge(chrun_customer, internet, how='left', on=['customerID'])
final
# Out:
#       customerID  tenure PhoneService        Contract PaperlessBilling  \
# 0     7590-VHVEG     1.0           No  Month-to-month              Yes
# 1     5575-GNVDE    34.0          Yes        One year               No
# 2     3668-QPYBK     2.0          Yes  Month-to-month              Yes
# 3     7795-CFOCW    45.0           No        One year               No
# 4     9237-HQITU     2.0          Yes  Month-to-month              Yes
# ...          ...     ...          ...             ...              ...
# 7037  2569-WGERO    72.0          Yes        Two year              Yes
# 7038  6840-RESVB    24.0          Yes        One year              Yes
# 7039  2234-XADUH    72.0          Yes        One year              Yes
# 7040  4801-JZAZL    11.0           No  Month-to-month              Yes
# 7041  8361-LTMKD     4.0          Yes  Month-to-month              Yes
#
#                   PaymentMethod  MonthlyCharges TotalCharges Churn  gender  \
# 0              Electronic check           29.85        29.85    No  Female
# 1                  Mailed check           56.95       1889.5    No    Male
# 2                  Mailed check           53.85          NaN   Yes    Male
# 3     Bank transfer (automatic)           42.30      1840.75    No    Male
# 4              Electronic check           70.70       151.65   Yes  Female
# ...                         ...             ...          ...   ...     ...
# 7037  Bank transfer (automatic)           21.15       1419.4    No  Female
# 7038               Mailed check           84.80       1990.5    No    Male
# 7039    Credit card (automatic)          103.20       7362.9    No  Female
# 7040           Electronic check           29.60       346.45    No  Female
# 7041               Mailed check           74.40        306.6   Yes    Male
#
#       ...  Partner Dependents     MultipleLines InternetService  \
# 0     ...      Yes         No  No phone service             DSL
# 1     ...       No         No                No             DSL
# 2     ...       No         No                No             DSL
# 3     ...       No         No  No phone service             DSL
# 4     ...       No         No                No     Fiber optic
# ...   ...      ...        ...               ...             ...
# 7037  ...       No         No                No              No
# 7038  ...      Yes        Yes               Yes             DSL
# 7039  ...      Yes        Yes               Yes     Fiber optic
# 7040  ...      Yes        Yes  No phone service             DSL
# 7041  ...      Yes         No               Yes     Fiber optic
#
#            OnlineSecurity         OnlineBackup     DeviceProtection  \
# 0                      No                  Yes                   No
# 1                     Yes                   No                  Yes
# 2                     Yes                  Yes                   No
# 3                     Yes                   No                  Yes
# 4                      No                   No                   No
# ...                   ...                  ...                  ...
# 7037  No internet service  No internet service  No internet service
# 7038                  Yes                   No                  Yes
# 7039                   No                  Yes                  Yes
# 7040                  Yes                   No                   No
# 7041                   No                   No                   No
#
#               TechSupport          StreamingTV      StreamingMovies
# 0                      No                   No                   No
# 1                      No                   No                   No
# 2                      No                   No                   No
# 3                     Yes                   No                   No
# 4                      No                   No                   No
# ...                   ...                  ...                  ...
# 7037  No internet service  No internet service  No internet service
# 7038                  Yes                  Yes                  Yes
# 7039                   No                  Yes                  Yes
# 7040                   No                   No                   No
# 7041                   No                   No                   No
#
# [7042 rows x 21 columns]

# %%
final.describe()
# Out:
#             tenure  MonthlyCharges  SeniorCitizen
# count  7038.000000     7028.000000    7042.000000
# mean     32.359761       64.741641       0.162170
# std      24.554612       30.098308       0.368633
# min       0.000000       18.250000       0.000000
# 25%       9.000000       35.450000       0.000000
# 50%      29.000000       70.325000       0.000000
# 75%      55.000000       89.850000       0.000000
# max      72.000000      118.750000       1.000000

# %%
final.dtypes
# Out:
# customerID           object
# tenure              float64
# PhoneService         object
# Contract             object
# PaperlessBilling     object
# PaymentMethod        object
# MonthlyCharges      float64
# TotalCharges         object
# Churn                object
# gender               object
# SeniorCitizen         int64
# Partner              object
# Dependents           object
# MultipleLines        object
# InternetService      object
# OnlineSecurity       object
# OnlineBackup         object
# DeviceProtection     object
# TechSupport          object
# StreamingTV          object
# StreamingMovies      object
# dtype: object

# %%
final.isna().sum()
# Out:
# customerID           0
# tenure               4
# PhoneService         3
# Contract             2
# PaperlessBilling     3
# PaymentMethod        7
# MonthlyCharges      14
# TotalCharges        11
# Churn                0
# gender               0
# SeniorCitizen        0
# Partner              0
# Dependents           0
# MultipleLines        0
# InternetService      0
# OnlineSecurity       0
# OnlineBackup         0
# DeviceProtection     0
# TechSupport          0
# StreamingTV          0
# StreamingMovies      0
# dtype: int64

# %%
for i in final.columns:
    print(i,final[i].unique())
# Out:
# customerID ['7590-VHVEG' '5575-GNVDE' '3668-QPYBK' ... '2234-XADUH' '4801-JZAZL'
#  '8361-LTMKD']
# tenure [ 1. 34.  2. 45.  8. 22. 10. 28. 62. 13. nan 58. 49. 25. 69. 52. 71. 21.
#  12. 30. 47. 72. 17. 27.  5. 46. 11. 70. 63. 43. 15. 60. 18. 66.  9.  3.
#  31. 50. 64. 56.  7. 42. 35. 48. 29. 65. 38. 68. 32. 55. 37. 36. 41.  6.
#   4. 33. 67. 23. 57. 61. 14. 16. 20. 53. 40. 59. 24. 44. 19. 54. 51. 26.
#   0. 39.]
# PhoneService ['No' 'Yes' nan]
# Contract ['Month-to-month' 'One year' 'Two year' nan]
# PaperlessBilling ['Yes' 'No' nan]
# PaymentMethod ['Electronic check' 'Mailed check' 'Bank transfer (automatic)'
#  'Credit card (automatic)' nan]
# MonthlyCharges [29.85 56.95 53.85 ... 63.1  44.2  78.7 ]
# TotalCharges ['29.85' '1889.5' nan ... '7362.9' '346.45' '306.6']
# Churn ['No' 'Yes']
# gender ['Female' 'Male']
# SeniorCitizen [0 1]
# Partner ['Yes' 'No']
# Dependents ['No' 'Yes']
# MultipleLines ['No phone service' 'No' 'Yes']
# InternetService ['DSL' 'Fiber optic' 'No']
# OnlineSecurity ['No' 'Yes' 'No internet service']
# OnlineBackup ['Yes' 'No' 'No internet service']
# DeviceProtection ['No' 'Yes' 'No internet service']
# TechSupport ['No' 'Yes' 'No internet service']
# StreamingTV ['No' 'Yes' 'No internet service']
# StreamingMovies ['No' 'Yes' 'No internet service']

# %%
final['TotalCharges']=final['TotalCharges'].fillna(method="ffill")
final['PhoneService']=final['PhoneService'].fillna(method="ffill")
final['Contract']=final['Contract'].fillna(method="ffill")
final['PaperlessBilling']=final['PaymentMethod'].fillna(method="ffill")
final['PaymentMethod']=final['PaymentMethod'].fillna(method="ffill")

final['TotalCharges']=final['TotalCharges'].fillna(method="ffill")


final['tenure']=final['tenure']=final['tenure'].fillna(final['MonthlyCharges'].mean())
final['MonthlyCharges']=final['MonthlyCharges']=final['MonthlyCharges'].fillna(final['MonthlyCharges'].mean())

# %%
final.isna().sum()
# Out:
# customerID          0
# tenure              0
# PhoneService        0
# Contract            0
# PaperlessBilling    0
# PaymentMethod       0
# MonthlyCharges      0
# TotalCharges        0
# Churn               0
# gender              0
# SeniorCitizen       0
# Partner             0
# Dependents          0
# MultipleLines       0
# InternetService     0
# OnlineSecurity      0
# OnlineBackup        0
# DeviceProtection    0
# TechSupport         0
# StreamingTV         0
# StreamingMovies     0
# dtype: int64

# %%
final
# Out:
#       customerID  tenure PhoneService        Contract  \
# 0     7590-VHVEG     1.0           No  Month-to-month
# 1     5575-GNVDE    34.0          Yes        One year
# 2     3668-QPYBK     2.0          Yes  Month-to-month
# 3     7795-CFOCW    45.0           No        One year
# 4     9237-HQITU     2.0          Yes  Month-to-month
# ...          ...     ...          ...             ...
# 7037  2569-WGERO    72.0          Yes        Two year
# 7038  6840-RESVB    24.0          Yes        One year
# 7039  2234-XADUH    72.0          Yes        One year
# 7040  4801-JZAZL    11.0           No  Month-to-month
# 7041  8361-LTMKD     4.0          Yes  Month-to-month
#
#                PaperlessBilling              PaymentMethod  MonthlyCharges  \
# 0              Electronic check           Electronic check           29.85
# 1                  Mailed check               Mailed check           56.95
# 2                  Mailed check               Mailed check           53.85
# 3     Bank transfer (automatic)  Bank transfer (automatic)           42.30
# 4              Electronic check           Electronic check           70.70
# ...                         ...                        ...             ...
# 7037  Bank transfer (automatic)  Bank transfer (automatic)           21.15
# 7038               Mailed check               Mailed check           84.80
# 7039    Credit card (automatic)    Credit card (automatic)          103.20
# 7040           Electronic check           Electronic check           29.60
# 7041               Mailed check               Mailed check           74.40
#
#      TotalCharges Churn  gender  ...  Partner Dependents     MultipleLines  \
# 0           29.85    No  Female  ...      Yes         No  No phone service
# 1          1889.5    No    Male  ...       No         No                No
# 2          1889.5   Yes    Male  ...       No         No                No
# 3         1840.75    No    Male  ...       No         No  No phone service
# 4          151.65   Yes  Female  ...       No         No                No
# ...           ...   ...     ...  ...      ...        ...               ...
# 7037       1419.4    No  Female  ...       No         No                No
# 7038       1990.5    No    Male  ...      Yes        Yes               Yes
# 7039       7362.9    No  Female  ...      Yes        Yes               Yes
# 7040       346.45    No  Female  ...      Yes        Yes  No phone service
# 7041        306.6   Yes    Male  ...      Yes         No               Yes
#
#      InternetService       OnlineSecurity         OnlineBackup  \
# 0                DSL                   No                  Yes
# 1                DSL                  Yes                   No
# 2                DSL                  Yes                  Yes
# 3                DSL                  Yes                   No
# 4        Fiber optic                   No                   No
# ...              ...                  ...                  ...
# 7037              No  No internet service  No internet service
# 7038             DSL                  Yes                   No
# 7039     Fiber optic                   No                  Yes
# 7040             DSL                  Yes                   No
# 7041     Fiber optic                   No                   No
#
#          DeviceProtection          TechSupport          StreamingTV  \
# 0                      No                   No                   No
# 1                     Yes                   No                   No
# 2                      No                   No                   No
# 3                     Yes                  Yes                   No
# 4                      No                   No                   No
# ...                   ...                  ...                  ...
# 7037  No internet service  No internet service  No internet service
# 7038                  Yes                  Yes                  Yes
# 7039                  Yes                   No                  Yes
# 7040                   No                   No                   No
# 7041                   No                   No                   No
#
#           StreamingMovies
# 0                      No
# 1                      No
# 2                      No
# 3                      No
# 4                      No
# ...                   ...
# 7037  No internet service
# 7038                  Yes
# 7039                  Yes
# 7040                   No
# 7041                   No
#
# [7042 rows x 21 columns]

# %%
plt.figure(figsize=(20,12))
sns.countplot(x= final["InternetService"])
plt.show()

# %%
plt.figure(figsize=(20,12))
sns.countplot(x= final["PaymentMethod"])
plt.show()

# %%
#Evauating age distrivution 
plt.figure(figsize=(20,12))
Days_of_week=sns.countplot(x=final['PhoneService'],data=final, hue ="gender")
Days_of_week.set_title("Number of people activating PhoneService gender wise", color="#774571")
# Out:
# Text(0.5, 1.0, 'Number of people activating PhoneService gender wise')

# %%
final=final.drop('customerID',axis=1)

# %%
obj=final.select_dtypes(include='object')
obj.columns
# Out:
# Index(['PhoneService', 'Contract', 'PaperlessBilling', 'PaymentMethod',
#        'TotalCharges', 'Churn', 'gender', 'Partner', 'Dependents',
#        'MultipleLines', 'InternetService', 'OnlineSecurity', 'OnlineBackup',
#        'DeviceProtection', 'TechSupport', 'StreamingTV', 'StreamingMovies'],
#       dtype='object')

# %%
class LabelEncoder:
    def __init__(self):
        self.labels = {}

    def fit_transform(self, y):
        unique_labels = set(y)
        for i, label in enumerate(unique_labels):
            self.labels[label] = i

        encoded_labels = []
        for label in y:
            encoded_labels.append(self.labels[label])

        return encoded_labels

    def inverse_transform(self, y):
        inv_labels = {v: k for k, v in self.labels.items()}

        decoded_labels = []
        for label in y:
            decoded_labels.append(inv_labels[label])

        return decoded_labels

# %%
encoded={}
for i in obj.columns:
    le = LabelEncoder()
    encoded_data = le.fit_transform(obj[i])
    encoded[i]=encoded_data
encoded
df=pd.DataFrame(encoded)
pd.set_option('display.max_columns', None)
df
# Out:
#       PhoneService  Contract  PaperlessBilling  PaymentMethod  TotalCharges  \
# 0                0         1                 3              3          1728
# 1                1         0                 2              2          1007
# 2                1         1                 2              2          1007
# 3                0         0                 0              0          1083
# 4                1         1                 3              3           883
# ...            ...       ...               ...            ...           ...
# 7037             1         2                 0              0          4455
# 7038             1         0                 2              2          1869
# 7039             1         0                 1              1          2271
# 7040             0         1                 3              3          1281
# 7041             1         1                 2              2          2043
#
#       Churn  gender  Partner  Dependents  MultipleLines  InternetService  \
# 0         0       0        1           0              0                1
# 1         0       1        0           0              2                1
# 2         1       1        0           0              2                1
# 3         0       1        0           0              0                1
# 4         1       0        0           0              2                2
# ...     ...     ...      ...         ...            ...              ...
# 7037      0       0        0           0              2                0
# 7038      0       1        1           1              1                1
# 7039      0       0        1           1              1                2
# 7040      0       0        1           1              0                1
# 7041      1       1        1           0              1                2
#
#       OnlineSecurity  OnlineBackup  DeviceProtection  TechSupport  \
# 0                  1             2                 1            1
# 1                  2             1                 2            1
# 2                  2             2                 1            1
# 3                  2             1                 2            2
# 4                  1             1                 1            1
# ...              ...           ...               ...          ...
# 7037               0             0                 0            0
# 7038               2             1                 2            2
# 7039               1             2                 2            1
# 7040               2             1                 1            1
# 7041               1             1                 1            1
#
#       StreamingTV  StreamingMovies
# 0               1                1
# 1               1                1
# 2               1                1
# 3               1                1
# 4               1                1
# ...           ...              ...
# 7037            0                0
# 7038            2                2
# 7039            2                2
# 7040            1                1
# 7041            1                1
#
# [7042 rows x 17 columns]

# %%
final.drop(final[['PhoneService', 'Contract', 'PaperlessBilling',
       'PaymentMethod', 'TotalCharges', 'Churn', 'gender', 'Partner',
       'Dependents', 'MultipleLines', 'InternetService', 'OnlineSecurity',
       'OnlineBackup', 'DeviceProtection', 'TechSupport', 'StreamingTV',
       'StreamingMovies']],axis=1, inplace=True)

# %%
final
# Out:
#       tenure  MonthlyCharges  SeniorCitizen
# 0        1.0           29.85              0
# 1       34.0           56.95              0
# 2        2.0           53.85              0
# 3       45.0           42.30              0
# 4        2.0           70.70              0
# ...      ...             ...            ...
# 7037    72.0           21.15              0
# 7038    24.0           84.80              0
# 7039    72.0          103.20              0
# 7040    11.0           29.60              0
# 7041     4.0           74.40              1
#
# [7042 rows x 3 columns]

# %%
final = pd.concat([final, df], axis=1)
final
# Out:
#       tenure  MonthlyCharges  SeniorCitizen  PhoneService  Contract  \
# 0        1.0           29.85              0             0         1
# 1       34.0           56.95              0             1         0
# 2        2.0           53.85              0             1         1
# 3       45.0           42.30              0             0         0
# 4        2.0           70.70              0             1         1
# ...      ...             ...            ...           ...       ...
# 7037    72.0           21.15              0             1         2
# 7038    24.0           84.80              0             1         0
# 7039    72.0          103.20              0             1         0
# 7040    11.0           29.60              0             0         1
# 7041     4.0           74.40              1             1         1
#
#       PaperlessBilling  PaymentMethod  TotalCharges  Churn  gender  Partner  \
# 0                    3              3          1728      0       0        1
# 1                    2              2          1007      0       1        0
# 2                    2              2          1007      1       1        0
# 3                    0              0          1083      0       1        0
# 4                    3              3           883      1       0        0
# ...                ...            ...           ...    ...     ...      ...
# 7037                 0              0          4455      0       0        0
# 7038                 2              2          1869      0       1        1
# 7039                 1              1          2271      0       0        1
# 7040                 3              3          1281      0       0        1
# 7041                 2              2          2043      1       1        1
#
#       Dependents  MultipleLines  InternetService  OnlineSecurity  \
# 0              0              0                1               1
# 1              0              2                1               2
# 2              0              2                1               2
# 3              0              0                1               2
# 4              0              2                2               1
# ...          ...            ...              ...             ...
# 7037           0              2                0               0
# 7038           1              1                1               2
# 7039           1              1                2               1
# 7040           1              0                1               2
# 7041           0              1                2               1
#
#       OnlineBackup  DeviceProtection  TechSupport  StreamingTV  \
# 0                2                 1            1            1
# 1                1                 2            1            1
# 2                2                 1            1            1
# 3                1                 2            2            1
# 4                1                 1            1            1
# ...            ...               ...          ...          ...
# 7037             0                 0            0            0
# 7038             1                 2            2            2
# 7039             2                 2            1            2
# 7040             1                 1            1            1
# 7041             1                 1            1            1
#
#       StreamingMovies
# 0                   1
# 1                   1
# 2                   1
# 3                   1
# 4                   1
# ...               ...
# 7037                0
# 7038                2
# 7039                2
# 7040                1
# 7041                1
#
# [7042 rows x 20 columns]

# %%
int64=final.select_dtypes(include ='int64')
int64.columns
# Out:
# Index(['SeniorCitizen', 'PhoneService', 'Contract', 'PaperlessBilling',
#        'PaymentMethod', 'TotalCharges', 'Churn', 'gender', 'Partner',
#        'Dependents', 'MultipleLines', 'InternetService', 'OnlineSecurity',
#        'OnlineBackup', 'DeviceProtection', 'TechSupport', 'StreamingTV',
#        'StreamingMovies'],
#       dtype='object')

# %%
sns.countplot(x= final["Churn"])
# Out:
# <Axes: xlabel='Churn', ylabel='count'>

# %%
corrmat = final.corr()
plt.subplots(figsize=(18,18))
sns.heatmap(corrmat,annot=True, square=True);

# %%
y=final['Churn']
x=final.drop('Churn',axis=1)

# %%
y
# Out:
# 0       0
# 1       0
# 2       1
# 3       0
# 4       1
#        ..
# 7037    0
# 7038    0
# 7039    0
# 7040    0
# 7041    1
# Name: Churn, Length: 7042, dtype: int64

# %%
x
# Out:
#       tenure  MonthlyCharges  SeniorCitizen  PhoneService  Contract  \
# 0        1.0           29.85              0             0         1
# 1       34.0           56.95              0             1         0
# 2        2.0           53.85              0             1         1
# 3       45.0           42.30              0             0         0
# 4        2.0           70.70              0             1         1
# ...      ...             ...            ...           ...       ...
# 7037    72.0           21.15              0             1         2
# 7038    24.0           84.80              0             1         0
# 7039    72.0          103.20              0             1         0
# 7040    11.0           29.60              0             0         1
# 7041     4.0           74.40              1             1         1
#
#       PaperlessBilling  PaymentMethod  TotalCharges  gender  Partner  \
# 0                    3              3          1728       0        1
# 1                    2              2          1007       1        0
# 2                    2              2          1007       1        0
# 3                    0              0          1083       1        0
# 4                    3              3           883       0        0
# ...                ...            ...           ...     ...      ...
# 7037                 0              0          4455       0        0
# 7038                 2              2          1869       1        1
# 7039                 1              1          2271       0        1
# 7040                 3              3          1281       0        1
# 7041                 2              2          2043       1        1
#
#       Dependents  MultipleLines  InternetService  OnlineSecurity  \
# 0              0              0                1               1
# 1              0              2                1               2
# 2              0              2                1               2
# 3              0              0                1               2
# 4              0              2                2               1
# ...          ...            ...              ...             ...
# 7037           0              2                0               0
# 7038           1              1                1               2
# 7039           1              1                2               1
# 7040           1              0                1               2
# 7041           0              1                2               1
#
#       OnlineBackup  DeviceProtection  TechSupport  StreamingTV  \
# 0                2                 1            1            1
# 1                1                 2            1            1
# 2                2                 1            1            1
# 3                1                 2            2            1
# 4                1                 1            1            1
# ...            ...               ...          ...          ...
# 7037             0                 0            0            0
# 7038             1                 2            2            2
# 7039             2                 2            1            2
# 7040             1                 1            1            1
# 7041             1                 1            1            1
#
#       StreamingMovies
# 0                   1
# 1                   1
# 2                   1
# 3                   1
# 4                   1
# ...               ...
# 7037                0
# 7038                2
# 7039                2
# 7040                1
# 7041                1
#
# [7042 rows x 19 columns]

# %%
def train_test_split(X, y, test_ratio=0.2, random_state=None):
   
    if random_state is not None:
        np.random.seed(random_state)

    num_samples = X.shape[0]
    shuffle_idx = np.random.permutation(num_samples)
    test_size = int(num_samples * test_ratio)

    X_train = X.iloc[shuffle_idx[test_size:],:]
    y_train = y.iloc[shuffle_idx[test_size:]]
    X_test = X.iloc[shuffle_idx[:test_size],:]
    y_test = y.iloc[shuffle_idx[:test_size]]

    return X_train, X_test, y_train, y_test

# %%
X_train, X_test, y_train,y_test = train_test_split(x,y,test_ratio=0.2,random_state=42)
X_train=X_train.to_numpy()
X_test=X_test.to_numpy()
y_train=y_train.to_numpy()
y_test=y_test.to_numpy()
X_train
# Out:
# array([[ 4.  , 70.2 ,  0.  , ...,  1.  ,  1.  ,  1.  ],
#        [64.  , 89.45,  0.  , ...,  1.  ,  1.  ,  1.  ],
#        [ 7.  , 69.55,  0.  , ...,  1.  ,  1.  ,  1.  ],
#        ...,
#        [12.  , 21.15,  0.  , ...,  0.  ,  0.  ,  0.  ],
#        [12.  , 99.45,  1.  , ...,  1.  ,  2.  ,  2.  ],
#        [26.  , 19.8 ,  0.  , ...,  0.  ,  0.  ,  0.  ]])

# %%
def StandardScaler(X):
    mean = np.mean(X, axis=0)
    std = np.std(X, axis=0)
    a=((X - mean) / std)
    return a

# %%
StandardScaler(X_train)
StandardScaler(X_test)
# Out:
# array([[-0.64750329,  0.21963061, -0.43611285, ..., -0.12364732,
#         -0.23343128,  1.12667663],
#        [-0.07815134,  0.53643996, -0.43611285, ...,  1.3033644 ,
#          1.10808399,  1.12667663],
#        [-1.01351525,  0.38983138,  2.29298447, ..., -0.12364732,
#         -0.23343128, -0.22226954],
#        ...,
#        [-0.15948733,  0.86167508, -0.43611285, ...,  1.3033644 ,
#         -0.23343128,  1.12667663],
#        [ 0.04385265,  0.86841571, -0.43611285, ..., -0.12364732,
#         -0.23343128,  1.12667663],
#        [-1.25752322,  0.32411029, -0.43611285, ..., -0.12364732,
#         -0.23343128, -0.22226954]])

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import time
import tensorflow as tf

from tensorflow import keras

from sklearn import preprocessing
import seaborn as sns
from keras.layers import Dense, BatchNormalization, Dropout, LSTM
from keras.models import Sequential
from keras import callbacks
from sklearn.metrics import precision_score, recall_score, confusion_matrix, classification_report, accuracy_score, f1_score

model = Sequential()

# layers
model.add(Dense(units = 16, kernel_initializer = 'uniform', activation = 'relu', input_dim = 19))
model.add(Dense(units = 8, kernel_initializer = 'uniform', activation = 'relu'))
model.add(Dropout(0.25))
model.add(Dense(units = 4, kernel_initializer = 'uniform', activation = 'relu'))
model.add(Dropout(0.5))
model.add(Dense(units = 1, kernel_initializer = 'uniform', activation = 'sigmoid'))
from keras.optimizers import SGD
# Compiling the ANN
model.compile(optimizer = 'adam', loss = 'binary_crossentropy', metrics = ['accuracy'])


# Train the ANN
history = model.fit(X_train, y_train, batch_size = 32, epochs = 100, validation_split=0.2,)
# Out:
# 2023-03-09 22:58:00.118588: I tensorflow/core/platform/cpu_feature_guard.cc:193] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  SSE4.1 SSE4.2
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.
# Epoch 1/100
# 2023-03-09 22:58:02.478355: I tensorflow/core/platform/cpu_feature_guard.cc:193] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  SSE4.1 SSE4.2
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 141/141 [==============================] - 1s 2ms/step - loss: 0.6532 - accuracy: 0.7271 - val_loss: 0.6068 - val_accuracy: 0.7471
# Epoch 2/100
# 141/141 [==============================] - 0s 864us/step - loss: 0.6151 - accuracy: 0.7311 - val_loss: 0.5878 - val_accuracy: 0.7471
# Epoch 3/100
# 141/141 [==============================] - 0s 864us/step - loss: 0.6046 - accuracy: 0.7311 - val_loss: 0.5630 - val_accuracy: 0.7471
# Epoch 4/100
# 141/141 [==============================] - 0s 859us/step - loss: 0.5757 - accuracy: 0.7311 - val_loss: 0.5108 - val_accuracy: 0.7471
# Epoch 5/100
# 141/141 [==============================] - 0s 860us/step - loss: 0.5584 - accuracy: 0.7311 - val_loss: 0.4987 - val_accuracy: 0.7471
# Epoch 6/100
# 141/141 [==============================] - 0s 864us/step - loss: 0.5457 - accuracy: 0.7311 - val_loss: 0.5051 - val_accuracy: 0.7471
# Epoch 7/100
# 141/141 [==============================] - 0s 860us/step - loss: 0.5440 - accuracy: 0.7311 - val_loss: 0.4971 - val_accuracy: 0.7471
# Epoch 8/100
# 141/141 [==============================] - 0s 861us/step - loss: 0.5404 - accuracy: 0.7311 - val_loss: 0.4839 - val_accuracy: 0.7471
# Epoch 9/100
# 141/141 [==============================] - 0s 866us/step - loss: 0.5340 - accuracy: 0.7311 - val_loss: 0.5094 - val_accuracy: 0.7471
# Epoch 10/100
# 141/141 [==============================] - 0s 842us/step - loss: 0.5468 - accuracy: 0.7311 - val_loss: 0.4848 - val_accuracy: 0.7471
# Epoch 11/100
# 141/141 [==============================] - 0s 892us/step - loss: 0.5337 - accuracy: 0.7311 - val_loss: 0.4771 - val_accuracy: 0.7471
# Epoch 12/100
# 141/141 [==============================] - 0s 880us/step - loss: 0.5345 - accuracy: 0.7311 - val_loss: 0.4733 - val_accuracy: 0.7471
# Epoch 13/100
# 141/141 [==============================] - 0s 861us/step - loss: 0.5272 - accuracy: 0.7311 - val_loss: 0.5057 - val_accuracy: 0.7471
# Epoch 14/100
# 141/141 [==============================] - 0s 894us/step - loss: 0.5315 - accuracy: 0.7311 - val_loss: 0.4765 - val_accuracy: 0.7471
# Epoch 15/100
# 141/141 [==============================] - 0s 918us/step - loss: 0.5336 - accuracy: 0.7311 - val_loss: 0.4929 - val_accuracy: 0.7471
# Epoch 16/100
# 141/141 [==============================] - 0s 902us/step - loss: 0.5351 - accuracy: 0.7311 - val_loss: 0.4912 - val_accuracy: 0.7471
# Epoch 17/100
# 141/141 [==============================] - 0s 958us/step - loss: 0.5328 - accuracy: 0.7311 - val_loss: 0.4879 - val_accuracy: 0.7471
# Epoch 18/100
# 141/141 [==============================] - 0s 856us/step - loss: 0.5311 - accuracy: 0.7311 - val_loss: 0.4948 - val_accuracy: 0.7471
# Epoch 19/100
# 141/141 [==============================] - 0s 869us/step - loss: 0.5308 - accuracy: 0.7311 - val_loss: 0.4732 - val_accuracy: 0.7471
# Epoch 20/100
# 141/141 [==============================] - 0s 841us/step - loss: 0.5268 - accuracy: 0.7311 - val_loss: 0.4925 - val_accuracy: 0.7471
# Epoch 21/100
# 141/141 [==============================] - 0s 849us/step - loss: 0.5298 - accuracy: 0.7311 - val_loss: 0.4698 - val_accuracy: 0.7471
# Epoch 22/100
# 141/141 [==============================] - 0s 869us/step - loss: 0.5336 - accuracy: 0.7311 - val_loss: 0.4744 - val_accuracy: 0.7471
# Epoch 23/100
# 141/141 [==============================] - 0s 848us/step - loss: 0.5260 - accuracy: 0.7311 - val_loss: 0.4720 - val_accuracy: 0.7471
# Epoch 24/100
# 141/141 [==============================] - 0s 842us/step - loss: 0.5322 - accuracy: 0.7311 - val_loss: 0.4687 - val_accuracy: 0.7471
# Epoch 25/100
# 141/141 [==============================] - 0s 855us/step - loss: 0.5263 - accuracy: 0.7311 - val_loss: 0.4752 - val_accuracy: 0.7471
# Epoch 26/100
# 141/141 [==============================] - 0s 863us/step - loss: 0.5326 - accuracy: 0.7311 - val_loss: 0.4773 - val_accuracy: 0.7471
# Epoch 27/100
# 141/141 [==============================] - 0s 849us/step - loss: 0.5270 - accuracy: 0.7311 - val_loss: 0.4707 - val_accuracy: 0.7471
# Epoch 28/100
# 141/141 [==============================] - 0s 847us/step - loss: 0.5288 - accuracy: 0.7311 - val_loss: 0.4665 - val_accuracy: 0.7471
# Epoch 29/100
# 141/141 [==============================] - 0s 845us/step - loss: 0.5317 - accuracy: 0.7311 - val_loss: 0.4696 - val_accuracy: 0.7471
# Epoch 30/100
# 141/141 [==============================] - 0s 919us/step - loss: 0.5305 - accuracy: 0.7311 - val_loss: 0.4764 - val_accuracy: 0.7471
# Epoch 31/100
# 141/141 [==============================] - 0s 859us/step - loss: 0.5305 - accuracy: 0.7311 - val_loss: 0.4803 - val_accuracy: 0.7471
# Epoch 32/100
# 141/141 [==============================] - 0s 856us/step - loss: 0.5274 - accuracy: 0.7311 - val_loss: 0.4772 - val_accuracy: 0.7471
# Epoch 33/100
# 141/141 [==============================] - 0s 837us/step - loss: 0.5341 - accuracy: 0.7311 - val_loss: 0.4672 - val_accuracy: 0.7471
# Epoch 34/100
# 141/141 [==============================] - 0s 838us/step - loss: 0.5274 - accuracy: 0.7311 - val_loss: 0.4727 - val_accuracy: 0.7471
# Epoch 35/100
# 141/141 [==============================] - 0s 834us/step - loss: 0.5285 - accuracy: 0.7311 - val_loss: 0.4773 - val_accuracy: 0.7471
# Epoch 36/100
# 141/141 [==============================] - 0s 843us/step - loss: 0.5322 - accuracy: 0.7311 - val_loss: 0.4700 - val_accuracy: 0.7471
# Epoch 37/100
# 141/141 [==============================] - 0s 831us/step - loss: 0.5189 - accuracy: 0.7311 - val_loss: 0.4656 - val_accuracy: 0.7471
# Epoch 38/100
# 141/141 [==============================] - 0s 837us/step - loss: 0.5270 - accuracy: 0.7311 - val_loss: 0.4702 - val_accuracy: 0.7471
# Epoch 39/100
# 141/141 [==============================] - 0s 851us/step - loss: 0.5282 - accuracy: 0.7311 - val_loss: 0.4722 - val_accuracy: 0.7471
# Epoch 40/100
# 141/141 [==============================] - 0s 837us/step - loss: 0.5275 - accuracy: 0.7311 - val_loss: 0.4701 - val_accuracy: 0.7471
# Epoch 41/100
# 141/141 [==============================] - 0s 850us/step - loss: 0.5277 - accuracy: 0.7311 - val_loss: 0.4652 - val_accuracy: 0.7471
# Epoch 42/100
# 141/141 [==============================] - 0s 843us/step - loss: 0.5305 - accuracy: 0.7311 - val_loss: 0.4673 - val_accuracy: 0.7471
# Epoch 43/100
# 141/141 [==============================] - 0s 840us/step - loss: 0.5265 - accuracy: 0.7311 - val_loss: 0.4810 - val_accuracy: 0.7471
# Epoch 44/100
# 141/141 [==============================] - 0s 840us/step - loss: 0.5305 - accuracy: 0.7311 - val_loss: 0.4794 - val_accuracy: 0.7471
# Epoch 45/100
# 141/141 [==============================] - 0s 842us/step - loss: 0.5218 - accuracy: 0.7311 - val_loss: 0.4760 - val_accuracy: 0.7471
# Epoch 46/100
# 141/141 [==============================] - 0s 839us/step - loss: 0.5265 - accuracy: 0.7311 - val_loss: 0.4614 - val_accuracy: 0.7471
# Epoch 47/100
# 141/141 [==============================] - 0s 838us/step - loss: 0.5255 - accuracy: 0.7311 - val_loss: 0.4642 - val_accuracy: 0.7471
# Epoch 48/100
# 141/141 [==============================] - 0s 848us/step - loss: 0.5249 - accuracy: 0.7311 - val_loss: 0.4572 - val_accuracy: 0.7471
# Epoch 49/100
# 141/141 [==============================] - 0s 850us/step - loss: 0.5158 - accuracy: 0.7311 - val_loss: 0.4611 - val_accuracy: 0.7471
# Epoch 50/100
# 141/141 [==============================] - 0s 855us/step - loss: 0.5168 - accuracy: 0.7311 - val_loss: 0.4636 - val_accuracy: 0.7471
# Epoch 51/100
# 141/141 [==============================] - 0s 854us/step - loss: 0.5140 - accuracy: 0.7311 - val_loss: 0.4622 - val_accuracy: 0.7471
# Epoch 52/100
# 141/141 [==============================] - 0s 845us/step - loss: 0.5085 - accuracy: 0.7311 - val_loss: 0.4713 - val_accuracy: 0.7471
# Epoch 53/100
# 141/141 [==============================] - 0s 841us/step - loss: 0.5160 - accuracy: 0.7311 - val_loss: 0.4609 - val_accuracy: 0.7471
# Epoch 54/100
# 141/141 [==============================] - 0s 846us/step - loss: 0.5124 - accuracy: 0.7311 - val_loss: 0.4595 - val_accuracy: 0.7471
# Epoch 55/100
# 141/141 [==============================] - 0s 835us/step - loss: 0.5164 - accuracy: 0.7311 - val_loss: 0.4597 - val_accuracy: 0.7471
# Epoch 56/100
# 141/141 [==============================] - 0s 837us/step - loss: 0.5073 - accuracy: 0.7311 - val_loss: 0.4575 - val_accuracy: 0.7471
# Epoch 57/100
# 141/141 [==============================] - 0s 841us/step - loss: 0.5151 - accuracy: 0.7311 - val_loss: 0.4615 - val_accuracy: 0.7471
# Epoch 58/100
# 141/141 [==============================] - 0s 839us/step - loss: 0.5101 - accuracy: 0.7311 - val_loss: 0.4677 - val_accuracy: 0.7471
# Epoch 59/100
# 141/141 [==============================] - 0s 846us/step - loss: 0.5141 - accuracy: 0.7311 - val_loss: 0.4557 - val_accuracy: 0.7471
# Epoch 60/100
# 141/141 [==============================] - 0s 847us/step - loss: 0.5115 - accuracy: 0.7311 - val_loss: 0.4558 - val_accuracy: 0.7471
# Epoch 61/100
# 141/141 [==============================] - 0s 848us/step - loss: 0.5096 - accuracy: 0.7311 - val_loss: 0.4593 - val_accuracy: 0.7471
# Epoch 62/100
# 141/141 [==============================] - 0s 849us/step - loss: 0.5068 - accuracy: 0.7311 - val_loss: 0.4590 - val_accuracy: 0.7471
# Epoch 63/100
# 141/141 [==============================] - 0s 839us/step - loss: 0.5079 - accuracy: 0.7311 - val_loss: 0.4558 - val_accuracy: 0.7471
# Epoch 64/100
# 141/141 [==============================] - 0s 851us/step - loss: 0.5197 - accuracy: 0.7311 - val_loss: 0.4563 - val_accuracy: 0.7471
# Epoch 65/100
# 141/141 [==============================] - 0s 846us/step - loss: 0.5092 - accuracy: 0.7311 - val_loss: 0.4798 - val_accuracy: 0.7471
# Epoch 66/100
# 141/141 [==============================] - 0s 843us/step - loss: 0.5096 - accuracy: 0.7311 - val_loss: 0.4588 - val_accuracy: 0.7471
# Epoch 67/100
# 141/141 [==============================] - 0s 852us/step - loss: 0.5155 - accuracy: 0.7311 - val_loss: 0.4547 - val_accuracy: 0.7471
# Epoch 68/100
# 141/141 [==============================] - 0s 858us/step - loss: 0.5128 - accuracy: 0.7311 - val_loss: 0.4633 - val_accuracy: 0.7471
# Epoch 69/100
# 141/141 [==============================] - 0s 854us/step - loss: 0.5034 - accuracy: 0.7311 - val_loss: 0.4520 - val_accuracy: 0.7471
# Epoch 70/100
# 141/141 [==============================] - 0s 850us/step - loss: 0.5070 - accuracy: 0.7311 - val_loss: 0.4535 - val_accuracy: 0.7471
# Epoch 71/100
# 141/141 [==============================] - 0s 847us/step - loss: 0.5044 - accuracy: 0.7311 - val_loss: 0.4534 - val_accuracy: 0.7471
# Epoch 72/100
# 141/141 [==============================] - 0s 840us/step - loss: 0.5044 - accuracy: 0.7311 - val_loss: 0.4529 - val_accuracy: 0.7471
# Epoch 73/100
# 141/141 [==============================] - 0s 827us/step - loss: 0.5098 - accuracy: 0.7311 - val_loss: 0.4540 - val_accuracy: 0.7471
# Epoch 74/100
# 141/141 [==============================] - 0s 836us/step - loss: 0.5066 - accuracy: 0.7311 - val_loss: 0.4516 - val_accuracy: 0.7471
# Epoch 75/100
# 141/141 [==============================] - 0s 838us/step - loss: 0.5068 - accuracy: 0.7311 - val_loss: 0.4502 - val_accuracy: 0.7471
# Epoch 76/100
# 141/141 [==============================] - 0s 842us/step - loss: 0.5062 - accuracy: 0.7311 - val_loss: 0.4515 - val_accuracy: 0.7471
# Epoch 77/100
# 141/141 [==============================] - 0s 834us/step - loss: 0.5032 - accuracy: 0.7311 - val_loss: 0.4566 - val_accuracy: 0.7471
# Epoch 78/100
# 141/141 [==============================] - 0s 841us/step - loss: 0.5095 - accuracy: 0.7311 - val_loss: 0.4866 - val_accuracy: 0.7471
# Epoch 79/100
# 141/141 [==============================] - 0s 842us/step - loss: 0.5140 - accuracy: 0.7311 - val_loss: 0.4572 - val_accuracy: 0.7471
# Epoch 80/100
# 141/141 [==============================] - 0s 845us/step - loss: 0.5061 - accuracy: 0.7311 - val_loss: 0.4892 - val_accuracy: 0.7471
# Epoch 81/100
# 141/141 [==============================] - 0s 853us/step - loss: 0.5111 - accuracy: 0.7311 - val_loss: 0.4500 - val_accuracy: 0.7471
# Epoch 82/100
# 141/141 [==============================] - 0s 845us/step - loss: 0.5047 - accuracy: 0.7311 - val_loss: 0.4716 - val_accuracy: 0.7471
# Epoch 83/100
# 141/141 [==============================] - 0s 847us/step - loss: 0.5037 - accuracy: 0.7311 - val_loss: 0.4511 - val_accuracy: 0.7471
# Epoch 84/100
# 141/141 [==============================] - 0s 846us/step - loss: 0.5094 - accuracy: 0.7311 - val_loss: 0.4494 - val_accuracy: 0.7471
# Epoch 85/100
# 141/141 [==============================] - 0s 844us/step - loss: 0.5098 - accuracy: 0.7311 - val_loss: 0.4540 - val_accuracy: 0.7471
# Epoch 86/100
# 141/141 [==============================] - 0s 857us/step - loss: 0.5040 - accuracy: 0.7311 - val_loss: 0.4498 - val_accuracy: 0.7471
# Epoch 87/100
# 141/141 [==============================] - 0s 847us/step - loss: 0.5113 - accuracy: 0.7311 - val_loss: 0.4500 - val_accuracy: 0.7471
# Epoch 88/100
# 141/141 [==============================] - 0s 845us/step - loss: 0.5145 - accuracy: 0.7311 - val_loss: 0.4562 - val_accuracy: 0.7471
# Epoch 89/100
# 141/141 [==============================] - 0s 849us/step - loss: 0.5075 - accuracy: 0.7311 - val_loss: 0.4528 - val_accuracy: 0.7471
# Epoch 90/100
# 141/141 [==============================] - 0s 852us/step - loss: 0.5035 - accuracy: 0.7311 - val_loss: 0.4610 - val_accuracy: 0.7471
# Epoch 91/100
# 141/141 [==============================] - 0s 841us/step - loss: 0.5018 - accuracy: 0.7311 - val_loss: 0.4548 - val_accuracy: 0.7471
# Epoch 92/100
# 141/141 [==============================] - 0s 909us/step - loss: 0.5034 - accuracy: 0.7311 - val_loss: 0.4514 - val_accuracy: 0.7471
# Epoch 93/100
# 141/141 [==============================] - 0s 848us/step - loss: 0.5066 - accuracy: 0.7311 - val_loss: 0.4495 - val_accuracy: 0.7471
# Epoch 94/100
# 141/141 [==============================] - 0s 848us/step - loss: 0.5037 - accuracy: 0.7311 - val_loss: 0.4529 - val_accuracy: 0.7471
# Epoch 95/100
# 141/141 [==============================] - 0s 847us/step - loss: 0.5014 - accuracy: 0.7311 - val_loss: 0.4708 - val_accuracy: 0.7471
# Epoch 96/100
# 141/141 [==============================] - 0s 849us/step - loss: 0.5199 - accuracy: 0.7311 - val_loss: 0.4568 - val_accuracy: 0.7471
# Epoch 97/100
# 141/141 [==============================] - 0s 852us/step - loss: 0.5073 - accuracy: 0.7311 - val_loss: 0.4532 - val_accuracy: 0.7471
# Epoch 98/100
# 141/141 [==============================] - 0s 854us/step - loss: 0.5043 - accuracy: 0.7311 - val_loss: 0.4496 - val_accuracy: 0.7471
# Epoch 99/100
# 141/141 [==============================] - 0s 840us/step - loss: 0.5061 - accuracy: 0.7311 - val_loss: 0.4503 - val_accuracy: 0.7471
# Epoch 100/100
# 141/141 [==============================] - 0s 853us/step - loss: 0.5068 - accuracy: 0.7311 - val_loss: 0.4490 - val_accuracy: 0.7471

# %%
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense (Dense)               (None, 16)                320
#
#  dense_1 (Dense)             (None, 8)                 136
#
#  dropout (Dropout)           (None, 8)                 0
#
#  dense_2 (Dense)             (None, 4)                 36
#
#  dropout_1 (Dropout)         (None, 4)                 0
#
#  dense_3 (Dense)             (None, 1)                 5
#
# =================================================================
# Total params: 497
# Trainable params: 497
# Non-trainable params: 0
# _________________________________________________________________

# %%
val_accuracy = np.mean(history.history['val_accuracy'])
print("\n%s: %.2f%%" % ('val_accuracy', val_accuracy*100))
# Out:
# val_accuracy: 74.71%

# %%
history_df = pd.DataFrame(history.history)

plt.plot(history_df.loc[:, ['loss']], "#6daa9f", label='Training loss')
plt.plot(history_df.loc[:, ['val_loss']],"#774571", label='Validation loss')
plt.title('Training and Validation loss')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.legend(loc="best")

plt.show()

# %%
history_df = pd.DataFrame(history.history)

plt.plot(history_df.loc[:, ['accuracy']], "#6daa9f", label='Training accuracy')
plt.plot(history_df.loc[:, ['val_accuracy']], "#774571", label='Validation accuracy')

plt.title('Training and Validation accuracy')
plt.xlabel('Epochs')
plt.ylabel('Accuracy')
plt.legend()
plt.show()

# %%
y_pred = model.predict(X_test)
y_pred = (y_pred > 0.5)
print(classification_report(y_test, y_pred))
# Out:
# 44/44 [==============================] - 0s 445us/step
#               precision    recall  f1-score   support
#
#            0       0.74      1.00      0.85      1036
#            1       0.00      0.00      0.00       372
#
#     accuracy                           0.74      1408
#    macro avg       0.37      0.50      0.42      1408
# weighted avg       0.54      0.74      0.62      1408

# %%
import math

# %%
class ANN:
    
    def predict(self,X, y, parameters,active_func_h,active_func_o):
        m = X.shape[1]
        p = np.zeros((1,m), dtype = np.int64)
        a3, caches = self.forward_propagation(X, parameters,active_func_h,active_func_o)
        for i in range(0, a3.shape[1]):
            if a3[0,i] > 0.5:
                p[0,i] = 1
            else:
                p[0,i] = 0
        #print("Accuracy: "  + str(np.mean((p[0,:] == y[0]))))
        a=str(np.mean((p[0,:] == y[0])))
        return p,a
    
    def predict_ann(self,x_test, parameters, active_func_h, active_func_o):
        m = x_test.shape[1]
        p = np.zeros((1,m), dtype=np.int64)
        a3, caches = self.forward_propagation(x_test, parameters, active_func_h, active_func_o)
        for i in range(0, a3.shape[1]):
            if a3[0,i] > 0.5:
                p[0,i] = 1
            else:
                p[0,i] = 0
        return p

    def update_parameters_with_gd(self,parameters, grads, learning_rate):
        L = len(parameters) // 2 # number of layers in the neural networks
        for l in range(L):
            parameters["W" + str(l+1)] = parameters["W" + str(l+1)] - learning_rate * grads["dW" + str(l+1)]
            parameters["b" + str(l+1)] = parameters["b" + str(l+1)] - learning_rate * grads["db" + str(l+1)]
        return parameters

    def backward_propagation(self,X, Y, cache):
        m = X.shape[1]
        (z1, a1, W1, b1, z2, a2, W2, b2, z3, a3, W3, b3) = cache

        dz3 = 1./m * (a3 - Y)
        dW3 = np.dot(dz3, a2.T)
        db3 = np.sum(dz3, axis=1, keepdims = True)
        
        da2 = np.dot(W3.T, dz3)
        dz2 = np.multiply(da2, np.int64(a2 > 0))
        dW2 = np.dot(dz2, a1.T)
        db2 = np.sum(dz2, axis=1, keepdims = True)
        
        da1 = np.dot(W2.T, dz2)
        dz1 = np.multiply(da1, np.int64(a1 > 0))
        dW1 = np.dot(dz1, X.T)
        db1 = np.sum(dz1, axis=1, keepdims = True)
        
        gradients = {"dz3": dz3, "dW3": dW3, "db3": db3,
                 "da2": da2, "dz2": dz2, "dW2": dW2, "db2": db2,
                 "da1": da1, "dz1": dz1, "dW1": dW1, "db1": db1}
    
        return gradients

    def compute_cost(self,a3, Y):
        m = Y.shape[1]
        logprobs = np.multiply(-np.log(a3),Y) + np.multiply(-np.log(1 - a3), 1 - Y)
        cost = 1./m * np.sum(logprobs)
        return cost

    def relu(self,x):
        s = np.maximum(0,x)
        return s
    
    def sigmoid(self,x):
        s = 1/(1+np.exp(-x))
        return s
    
    def leaky_relu(self,x, alpha=0.01):
        return np.maximum(alpha*x, x)

    def tanh(self,x):
        return np.tanh(x)

    def softmax(self,x):
        e_x = np.exp(x - np.max(x))
        return e_x / e_x.sum()

    def elu(self,z, alpha=1):
        return np.where(z < 0, alpha * (np.exp(z) - 1), z)

    def swish(self,z, beta=1):
        return z / (1 + np.exp(-beta * z))

    def softplus(self,z):
        return np.log(1 + np.exp(z))

    def softsign(self,z):
        return z / (1 + np.abs(z))


    def forward_propagation(self,X, parameters,active_func_h,active_func_o):
        W1 = parameters["W1"]
        b1 = parameters["b1"]
        W2 = parameters["W2"]
        b2 = parameters["b2"]
        W3 = parameters["W3"]
        b3 = parameters["b3"]
        
        if(active_func_h =='sigmoid'):
            z1 = np.dot(W1, X) + b1
            a1 = self.sigmoid(z1)
            z2 = np.dot(W2, a1) + b2
            a2 = self.sigmoid(z2)
            
        elif(active_func_h=='relu'):
            z1 = np.dot(W1, X) + b1
            a1 = self.relu(z1)
            z2 = np.dot(W2, a1) + b2
            a2 = self.relu(z2)
            
        elif(active_func_h=='leaky_relu'):
            z1 = np.dot(W1, X) + b1
            a1 = self.leaky_relu(z1)
            z2 = np.dot(W2, a1) + b2
            a2 = self.leaky_relu(z2)
            
        elif(active_func_h=='tanh'):
            z1 = np.dot(W1, X) + b1
            a1 = self.tanh(z1)
            z2 = np.dot(W2, a1) + b2
            a2 = self.tanh(z2)
            
        elif(active_func_h=='elu'):
            z1 = np.dot(W1, X) + b1
            a1 = self.elu(z1)
            z2 = np.dot(W2, a1) + b2
            a2 = self.elu(z2)
            
        elif(active_func_h=='softplus'):
            z1 = np.dot(W1, X) + b1
            a1 = self.softplus(z1)
            z2 = np.dot(W2, a1) + b2
            a2 = self.softplus(z2)
        
        if(active_func_o=='sigmoid'):
            z3 = np.dot(W3, a2) + b3
            a3 = self.sigmoid(z3)
        
        elif(active_func_o=='softmax'):
            z3 = np.dot(W3, a2) + b3
            a3 = self.softmax(z3)
        
    
        cache = (z1, a1, W1, b1, z2, a2, W2, b2, z3, a3, W3, b3)
    
        return a3, cache

    def random_mini_batches(self,X, Y, mini_batch_size = 64, seed = 0):
    
        np.random.seed(seed)            
        m = X.shape[1]                 
        mini_batches = []
        
        permutation = list(np.random.permutation(m))   
        shuffled_X = X.iloc[:, permutation]
        shuffled_Y = Y[permutation].values.reshape((1, m))
        #shuffled_Y = Y[permutation].reshape((1, m))
        

        num_complete_minibatches = math.floor(m/mini_batch_size) 
        for k in range(0, num_complete_minibatches):
            mini_batch_X = shuffled_X[:, k * mini_batch_size : (k + 1) * mini_batch_size]
            mini_batch_Y = shuffled_Y[:, k * mini_batch_size : (k + 1) * mini_batch_size]
            mini_batch = (mini_batch_X, mini_batch_Y)
            mini_batches.append(mini_batch)
    
        if m % mini_batch_size != 0:
            mini_batch_X = shuffled_X.iloc[:, num_complete_minibatches * mini_batch_size : ]
            mini_batch_Y = shuffled_Y[:, num_complete_minibatches * mini_batch_size : ]
            mini_batch = (mini_batch_X, mini_batch_Y)
            mini_batches.append(mini_batch)
    
        return mini_batches

    def initialize_parameters(self,layer_dims):
        np.random.seed(3)
        parameters = {}
        L = len(layer_dims) # number of layers in the network

        for l in range(1, L):
            parameters['W' + str(l)] = np.random.randn(layer_dims[l], layer_dims[l-1])*  np.sqrt(2 / layer_dims[l-1])
            parameters['b' + str(l)] = np.zeros((layer_dims[l], 1))
        
            assert (parameters['W' + str(l)].shape == layer_dims[l], layer_dims[l-1])
            assert (parameters['W' + str(l)].shape == layer_dims[l], 1)
        
        return parameters
    # GRADED FUNCTION: update_parameters_with_momentum

    def update_parameters_with_momentum(self,parameters, grads, v, beta, learning_rate):
  
        L = len(parameters) // 2
        for l in range(L):
            v["dW" + str(l+1)] = beta * v["dW" + str(l+1)] + (1 - beta) * grads["dW" + str(l+1)]
            v["db" + str(l+1)] = beta * v["db" + str(l+1)] + (1 - beta) * grads["db" + str(l+1)]
            parameters["W" + str(l+1)] = parameters["W" + str(l+1)] - learning_rate * v["dW" + str(l+1)]
            parameters["b" + str(l+1)] = parameters["b" + str(l+1)] - learning_rate * v["db" + str(l+1)]
        
        return parameters, v

    def initialize_velocity(self,parameters):
        L = len(parameters) // 2 
        v = {}
        for l in range(L):
            v["dW" + str(l+1)] = np.zeros(parameters["W"+str(l+1)].shape)
            v["db" + str(l+1)] = np.zeros(parameters["b"+str(l+1)].shape)
        return v
    
    def update_parameters_with_adam(self,parameters, grads, v, s, t, learning_rate = 0.01,
                                beta1 = 0.9, beta2 = 0.999,  epsilon = 1e-8):
        L = len(parameters) // 2                 
        v_corrected = {}                         
        s_corrected = {}                         
    
        for l in range(L):
            v["dW" + str(l+1)] = beta1 * v["dW" + str(l+1)] + (1 - beta1) * grads["dW" + str(l+1)]
            v["db" + str(l+1)] = beta1 * v["db" + str(l+1)] + (1 - beta1) * grads["db" + str(l+1)]
            v_corrected["dW" + str(l+1)] = v["dW" + str(l+1)] / (1 - beta1)
            v_corrected["db" + str(l+1)] = v["db" + str(l+1)] / (1 - beta1)
            s["dW" + str(l+1)] = beta2 * s["dW" + str(l+1)] + (1 - beta2) * (grads["dW" + str(l+1)] * grads["dW" + str(l+1)])
            s["db" + str(l+1)] = beta2 * s["db" + str(l+1)] + (1 - beta2) * (grads["db" + str(l+1)] * grads["db" + str(l+1)])
            s_corrected["dW" + str(l+1)] = s["dW" + str(l+1)] / (1 - beta2)
            s_corrected["db" + str(l+1)] = s["db" + str(l+1)] / (1 - beta2)
            parameters["W" + str(l+1)] = parameters["W" + str(l+1)] - learning_rate * v_corrected["dW" + str(l+1)] / (np.sqrt(s_corrected["dW" + str(l+1)]) + epsilon)
            parameters["b" + str(l+1)] = parameters["b" + str(l+1)] - learning_rate * v_corrected["db" + str(l+1)] / (np.sqrt(s_corrected["db" + str(l+1)]) + epsilon)

        return parameters, v, s

    def initialize_adam(self,parameters):
        L = len(parameters) // 2 
        v = {}
        s = {}
        for l in range(L):
            v["dW" + str(l+1)] = np.zeros(parameters["W" + str(l+1)].shape)
            v["db" + str(l+1)] = np.zeros(parameters["b" + str(l+1)].shape)
            s["dW" + str(l+1)] = np.zeros(parameters["W" + str(l+1)].shape)
            s["db" + str(l+1)] = np.zeros(parameters["b" + str(l+1)].shape)    
        return v, s
    
    def model(self,X, Y, layers_dims, optimizer, learning_rate = 0.001, mini_batch_size =64, beta = 0.9,
          beta1 = 0.9, beta2 = 0.999,  epsilon = 1e-8, num_epochs = 1000, active_func_h=None, active_func_o=None, print_cost = True):
        acc=0
        L = len(layers_dims)            
        costs = []
        accuracy=[]
        t = 0                            
        seed = 10                        
        parameters = self.initialize_parameters(layers_dims)
        
        if optimizer == "gd":
            pass 
        elif optimizer == "momentum":
            v = self.initialize_velocity(parameters)
        elif optimizer == "adam":
            v, s = self.initialize_adam(parameters)
    
        for i in range(num_epochs):
            seed = seed + 1
            minibatches = self.random_mini_batches(X, Y, mini_batch_size, seed)

            for minibatch in minibatches:
                (minibatch_X, minibatch_Y) = minibatch
                a3, caches = self.forward_propagation(minibatch_X, parameters,active_func_h,active_func_o)
                cost = self.compute_cost(a3, minibatch_Y)
                grads = self.backward_propagation(minibatch_X, minibatch_Y, caches)
                if optimizer == "gd":
                    parameters = self.update_parameters_with_gd(parameters, grads, learning_rate)
                elif optimizer == "momentum":
                    parameters, v = self.update_parameters_with_momentum(parameters, grads, v, beta, learning_rate)
                elif optimizer == "adam":
                    t = t + 1 
                    parameters, v, s = self.update_parameters_with_adam(parameters, grads, v, s,
                                                               t, learning_rate, beta1, beta2,  epsilon)
            
            if print_cost and i % 100 == 0:
                p,a=self.predict(minibatch_X, minibatch_Y, parameters,active_func_h,active_func_o)
                print ("Cost after epoch %i: %f" %(i, cost),'Accuracy: ',a)
            if print_cost and i % 1 == 0:
                costs.append(cost)
                p,a=self.predict(minibatch_X, minibatch_Y, parameters,active_func_h,active_func_o)
                accuracy.append(float(a))
            if print_cost and i == (num_epochs-1):
                p,a=self.predict(minibatch_X, minibatch_Y, parameters,active_func_h,active_func_o)
                acc=a
                
        
        plt.plot(costs)
        plt.ylabel('cost')
        plt.xlabel('epochs (per 100)')
        plt.title("Cost @ Learning rate = " + str(learning_rate))
        plt.show()
        
        plt.plot(accuracy)
        plt.ylabel('accuracy')
        plt.xlabel('epochs (per 100)')
        plt.title("Accuracy @ Learning rate = " + str(learning_rate))
        plt.show()
        print ('Accuracy: ',acc)
        return parameters

# %%
layers_dims = [x.shape[0], 5,3, 1]
adam=ANN()
adam_parameters = adam.model(x, y, layers_dims, optimizer = "adam",active_func_h="relu",active_func_o="sigmoid")
# Out:
# Cost after epoch 0: inf Accuracy:  0.3157894736842105
# Cost after epoch 100: 0.670637 Accuracy:  0.6842105263157895
# Cost after epoch 200: 0.659979 Accuracy:  0.6842105263157895
# Cost after epoch 300: 0.652890 Accuracy:  0.6842105263157895
# Cost after epoch 400: 0.647621 Accuracy:  0.6842105263157895
# Cost after epoch 500: 0.643495 Accuracy:  0.6842105263157895
# Cost after epoch 600: 0.640165 Accuracy:  0.6842105263157895
# Cost after epoch 700: 0.637429 Accuracy:  0.6842105263157895
# Cost after epoch 800: 0.635152 Accuracy:  0.6842105263157895
# Cost after epoch 900: 0.633243 Accuracy:  0.6842105263157895
# Accuracy:  0.6842105263157895

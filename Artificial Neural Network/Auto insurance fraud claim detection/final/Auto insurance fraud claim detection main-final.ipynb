# %% [markdown]
# # Auto insurance fraud claim detection

# %% [markdown]
# ![1_HdI-8wph0XW816WtzUOykw.jpg](attachment:1_HdI-8wph0XW816WtzUOykw.jpg)

# %% [markdown]
# # Information about attributes:
#
# ## Demographics Data :
#
# • CustomerID : Customer ID
#
# • InsuredAge : age
#
# • InsuredZipCode : Zip Code
#
# • InsuredGender : Gender - the missing value is represented as “NA”
#
# • InsuredEducationLevel : Education
#
# • InsuredOccupation : Occupation
#
# • InsuredHobbies : Hobbies
#
# • CapitalGains : Capital gains(Financial Status)
#
# • CapitalLoss : capital loss(Financial Status)
#
# • Country : Country
#
# ## Policy Information :
#
# • CustomerID : Customer ID
#
# • CustomerLoyaltyPeriod : Duration of customer relationship
#
# • InsurancePolicyNumber : policy number
#
# • DateOfPolicyCoverage : policy commencement date
#
# • InsurancePolicyState : Policy location (State)
#
# • Policy_CombinedSingleLimit : Split Limit and Combined Single Limit
#
# • Policy_Deductible : Deductible amount
#
# • PolicyAnnualPremium : Annual Premium – the missing value is
#
# represented as “-1”
#
# • UmbrellaLimit : Umbrella Limit amount
#
# • InsuredRelationship : Realtionship
#
# • TotalCharges : Customer account information (Total). ( For this
# attribute,
# missing values are denoted as “MISSINGVAL” also)
#
# • DOE : Date of entry as customer
#
# • ElectronicBilling : Customer account information - whether electronic
# billing
#
# • ContractType : Contract type ( For this attribute,
# denoted as “NA”)
#
# • PaymentMethod : payment method
#
#
# ## Claim Information :
#
#
# • CustomerID : Customer ID
#
# • DateOfIncident : Date of incident
# missing values are
#
# • TypeOfIncident : Type of incident
#
# • TypeOfCollission : Type of Collision - “?” is the missing value
#
# • SeverityOfIncident : Collision severity
#
# • AuthoritiesContacted : Which authorities are contacted
#
# • IncidentState : Incident location (State)
#
# • IncidentCity : Incident location (City)
#
# • IncidentAddress : Incident location (address)
#
# • IncidentTime : time of incident – Hour of the day - the missing value
# is represented
# as “-5”
#
# • NumberOfVehicles : Number of vehicles involved
#
# • PropertyDamage : If property damage is there - “?” is the missing value
#
# • BodilyInjuries : Number of bodily injuries
#
# • Witnesses : Number of witnesses - missing value is represented as
# "MISSINGVALUE"
#
# • PoliceReport : If police report available - “?” is the missing value
#
# • AmountOfTotalClaim : Total claim amount - the missing value is represented as
# “MISSEDDATA”
#
# • AmountOfInjuryClaim : Claim for injury
#
# • AmountOfPropertyClaim : claim for property damage
#
# • AmountOfVehicleDamage : claim for vehicle damage
#
# ## Data of Vehicle:
#
# • CustomerID : Customer ID
#
# • VehicleAttribute : Service signed for
#
# • VehicleAttributeDetails : Value of the vehicle attribute - the missing value is
# represented as “???”
#
#
# ## Fraud Data :
#
# • CustomerID : Customer ID
#
# • ReportedFraud : Fraud or not – Target

# %%
import pandas as pd
import numpy as np
import math
import matplotlib.pyplot as plt
import seaborn as sns


import warnings
warnings.filterwarnings("ignore")

# %%
claim = pd.read_csv("Train_Claim.csv")
Demog=pd.read_csv("Train_Demographics.csv")
policy=pd.read_csv("Train_Policy.csv")
vehicle=pd.read_csv("Train_Vehicle.csv")
target=pd.read_csv("Traindata_with_Target.csv")

# %%
claim
# Out:
#       CustomerID DateOfIncident            TypeOfIncident TypeOfCollission  \
# 0      Cust10000     2015-02-03   Multi-vehicle Collision   Side Collision
# 1      Cust10001     2015-02-02   Multi-vehicle Collision   Side Collision
# 2      Cust10002     2015-01-15  Single Vehicle Collision   Side Collision
# 3      Cust10003     2015-01-19  Single Vehicle Collision   Side Collision
# 4      Cust10004     2015-01-09  Single Vehicle Collision   Rear Collision
# ...          ...            ...                       ...              ...
# 28831   Cust9993     2015-01-24             Vehicle Theft                ?
# 28832   Cust9994     2015-02-09  Single Vehicle Collision  Front Collision
# 28833   Cust9996     2015-01-28  Single Vehicle Collision   Rear Collision
# 28834   Cust9997     2015-01-28  Single Vehicle Collision   Rear Collision
# 28835   Cust9999     2015-01-13  Single Vehicle Collision  Front Collision
#
#       SeverityOfIncident AuthoritiesContacted IncidentState IncidentCity  \
# 0             Total Loss               Police        State7        City1
# 1             Total Loss               Police        State7        City5
# 2           Minor Damage                Other        State8        City6
# 3           Minor Damage                Other        State9        City6
# 4           Minor Damage                 Fire        State8        City6
# ...                  ...                  ...           ...          ...
# 28831     Trivial Damage               Police        State9        City4
# 28832       Minor Damage                 Fire        State8        City3
# 28833       Minor Damage                 Fire        State9        City7
# 28834       Minor Damage            Ambulance        State9        City3
# 28835         Total Loss                Other        State8        City3
#
#       IncidentAddress  IncidentTime  NumberOfVehicles PropertyDamage  \
# 0       Location 1311            17                 3              ?
# 1       Location 1311            10                 3            YES
# 2       Location 2081            22                 1            YES
# 3       Location 2081            22                 1            YES
# 4       Location 1695            10                 1             NO
# ...               ...           ...               ...            ...
# 28831   Location 1890             3                 1             NO
# 28832   Location 2097            17                 1            YES
# 28833   Location 1452             1                 1            YES
# 28834   Location 1876             1                 1              ?
# 28835   Location 1874             9                 1             NO
#
#        BodilyInjuries Witnesses PoliceReport AmountOfTotalClaim  \
# 0                   1         0            ?              65501
# 1                   2         1          YES              61382
# 2                   2         3           NO              66755
# 3                   2         3           NO              66243
# 4                   2         1          YES              53544
# ...               ...       ...          ...                ...
# 28831               0         3            ?               6590
# 28832               0         2          YES              74547
# 28833               2         0          YES              55305
# 28834               2         0          YES              55830
# 28835               1         3          YES              68969
#
#        AmountOfInjuryClaim  AmountOfPropertyClaim  AmountOfVehicleDamage
# 0                    13417                   6071                  46013
# 1                    15560                   5919                  39903
# 2                    11630                  11630                  43495
# 3                    12003                  12003                  42237
# 4                     8829                   7234                  37481
# ...                    ...                    ...                    ...
# 28831                  870                   1078                   4642
# 28832                14699                   7875                  51973
# 28833                 7043                   7043                  41219
# 28834                 7059                   7059                  41712
# 28835                12075                   6038                  50856
#
# [28836 rows x 19 columns]

# %%
Demog
# Out:
#       CustomerID  InsuredAge  InsuredZipCode InsuredGender  \
# 0      Cust10000          35          454776          MALE
# 1      Cust10001          36          454776          MALE
# 2      Cust10002          33          603260          MALE
# 3      Cust10003          36          474848          MALE
# 4      Cust10004          29          457942        FEMALE
# ...          ...         ...             ...           ...
# 28831   Cust9993          46          600561          MALE
# 28832   Cust9994          44          439304          MALE
# 28833   Cust9996          53          460722          MALE
# 28834   Cust9997          53          472634          MALE
# 28835   Cust9999          36          450730        FEMALE
#
#       InsuredEducationLevel  InsuredOccupation InsuredHobbies  CapitalGains  \
# 0                        JD       armed-forces         movies         56700
# 1                        JD       tech-support      cross-fit         70600
# 2                        JD       armed-forces           polo         66400
# 3                        JD       armed-forces           polo         47900
# 4               High School    exec-managerial        dancing             0
# ...                     ...                ...            ...           ...
# 28831               Masters    protective-serv       sleeping             0
# 28832               Masters       adm-clerical        dancing             0
# 28833                   PhD   transport-moving   base-jumping         63100
# 28834             Associate   transport-moving      skydiving         67400
# 28835                   PhD  handlers-cleaners   base-jumping         46400
#
#        CapitalLoss Country
# 0           -48500   India
# 1           -48500   India
# 2           -63700   India
# 3           -73400   India
# 4           -41500   India
# ...            ...     ...
# 28831            0   India
# 28832       -28800   India
# 28833       -43800   India
# 28834       -43800   India
# 28835       -74300   India
#
# [28836 rows x 10 columns]

# %%
policy
# Out:
#        InsurancePolicyNumber  CustomerLoyaltyPeriod DateOfPolicyCoverage  \
# 0                     110122                    328           2014-10-17
# 1                     110125                    256           1990-05-25
# 2                     110126                    228           2014-06-06
# 3                     110127                    256           2006-10-12
# 4                     110128                    137           2000-06-04
# ...                      ...                    ...                  ...
# 28831                 148614                    425           1999-10-12
# 28832                 148615                    367           1996-11-09
# 28833                 148616                    208           1995-12-04
# 28834                 148618                    401           1994-09-12
# 28835                 148619                    331           2006-07-16
#
#       InsurancePolicyState Policy_CombinedSingleLimit  Policy_Deductible  \
# 0                   State3                    250/500               1000
# 1                   State1                    250/500               2000
# 2                   State1                   500/1000               1000
# 3                   State3                    250/500               1000
# 4                   State2                    250/500               1000
# ...                    ...                        ...                ...
# 28831               State3                    250/500               1000
# 28832               State3                    250/500               1000
# 28833               State3                    250/500               1000
# 28834               State3                    250/500                856
# 28835               State3                    250/500               1000
#
#        PolicyAnnualPremium  UmbrellaLimit InsuredRelationship CustomerID
# 0                  1406.91              0             husband   Cust1001
# 1                  1415.74        6000000           unmarried   Cust1004
# 2                  1583.91        6000000           unmarried   Cust1005
# 3                  1351.10              0           unmarried   Cust1006
# 4                  1333.35              0             husband   Cust1007
# ...                    ...            ...                 ...        ...
# 28831               839.81              0                wife  Cust39493
# 28832               811.03              0             husband  Cust39494
# 28833               891.37              0             husband  Cust39495
# 28834               911.37              0           own-child  Cust39497
# 28835              1062.91              0                wife  Cust39498
#
# [28836 rows x 10 columns]

# %%
vehicle
# Out:
#        CustomerID VehicleAttribute VehicleAttributeDetails
# 0       Cust20179        VehicleID             Vehicle8898
# 1       Cust21384     VehicleModel                  Malibu
# 2       Cust33335      VehicleMake                  Toyota
# 3       Cust27118     VehicleModel                    Neon
# 4       Cust13038        VehicleID            Vehicle30212
# ...           ...              ...                     ...
# 115339  Cust22134      VehicleMake                    Audi
# 115340  Cust25338        VehicleID            Vehicle28831
# 115341   Cust7637        VehicleID            Vehicle12870
# 115342  Cust33581        VehicleID            Vehicle19680
# 115343  Cust14156     VehicleModel                 Corolla
#
# [115344 rows x 3 columns]

# %%
vehicle = vehicle.pivot(index='CustomerID', columns='VehicleAttribute', values='VehicleAttributeDetails').reset_index()
vehicle.columns.name = None  # To remove the "VehicleAttribute" label from the top row
vehicle
# Out:
#       CustomerID     VehicleID VehicleMake VehicleModel VehicleYOM
# 0      Cust10000  Vehicle26917        Audi           A5       2008
# 1      Cust10001  Vehicle15893        Audi           A5       2006
# 2      Cust10002   Vehicle5152  Volkswagen        Jetta       1999
# 3      Cust10003  Vehicle37363  Volkswagen        Jetta       2003
# 4      Cust10004  Vehicle28633      Toyota          CRV       2010
# ...          ...           ...         ...          ...        ...
# 28831   Cust9993  Vehicle13568      Suburu      Impreza       2007
# 28832   Cust9994  Vehicle19810        Jeep     Wrangler       2003
# 28833   Cust9996   Vehicle3339      Suburu       Legacy       2004
# 28834   Cust9997  Vehicle10240      Suburu    Forrestor       2004
# 28835   Cust9999  Vehicle39163      Suburu         E400       2007
#
# [28836 rows x 5 columns]

# %%
target
# Out:
#       CustomerID ReportedFraud
# 0      Cust20065             N
# 1      Cust37589             N
# 2      Cust24312             N
# 3       Cust5493             Y
# 4       Cust7704             Y
# ...          ...           ...
# 28831   Cust9773             N
# 28832  Cust38439             N
# 28833  Cust38444             N
# 28834  Cust26466             N
# 28835  Cust29555             N
#
# [28836 rows x 2 columns]

# %%
claim_Demog = pd.merge(claim, Demog, how='left', on=['CustomerID'])
claim_Demog
# Out:
#       CustomerID DateOfIncident            TypeOfIncident TypeOfCollission  \
# 0      Cust10000     2015-02-03   Multi-vehicle Collision   Side Collision
# 1      Cust10001     2015-02-02   Multi-vehicle Collision   Side Collision
# 2      Cust10002     2015-01-15  Single Vehicle Collision   Side Collision
# 3      Cust10003     2015-01-19  Single Vehicle Collision   Side Collision
# 4      Cust10004     2015-01-09  Single Vehicle Collision   Rear Collision
# ...          ...            ...                       ...              ...
# 28831   Cust9993     2015-01-24             Vehicle Theft                ?
# 28832   Cust9994     2015-02-09  Single Vehicle Collision  Front Collision
# 28833   Cust9996     2015-01-28  Single Vehicle Collision   Rear Collision
# 28834   Cust9997     2015-01-28  Single Vehicle Collision   Rear Collision
# 28835   Cust9999     2015-01-13  Single Vehicle Collision  Front Collision
#
#       SeverityOfIncident AuthoritiesContacted IncidentState IncidentCity  \
# 0             Total Loss               Police        State7        City1
# 1             Total Loss               Police        State7        City5
# 2           Minor Damage                Other        State8        City6
# 3           Minor Damage                Other        State9        City6
# 4           Minor Damage                 Fire        State8        City6
# ...                  ...                  ...           ...          ...
# 28831     Trivial Damage               Police        State9        City4
# 28832       Minor Damage                 Fire        State8        City3
# 28833       Minor Damage                 Fire        State9        City7
# 28834       Minor Damage            Ambulance        State9        City3
# 28835         Total Loss                Other        State8        City3
#
#       IncidentAddress  IncidentTime  ...  AmountOfVehicleDamage InsuredAge  \
# 0       Location 1311            17  ...                  46013         35
# 1       Location 1311            10  ...                  39903         36
# 2       Location 2081            22  ...                  43495         33
# 3       Location 2081            22  ...                  42237         36
# 4       Location 1695            10  ...                  37481         29
# ...               ...           ...  ...                    ...        ...
# 28831   Location 1890             3  ...                   4642         46
# 28832   Location 2097            17  ...                  51973         44
# 28833   Location 1452             1  ...                  41219         53
# 28834   Location 1876             1  ...                  41712         53
# 28835   Location 1874             9  ...                  50856         36
#
#        InsuredZipCode InsuredGender InsuredEducationLevel  InsuredOccupation  \
# 0              454776          MALE                    JD       armed-forces
# 1              454776          MALE                    JD       tech-support
# 2              603260          MALE                    JD       armed-forces
# 3              474848          MALE                    JD       armed-forces
# 4              457942        FEMALE           High School    exec-managerial
# ...               ...           ...                   ...                ...
# 28831          600561          MALE               Masters    protective-serv
# 28832          439304          MALE               Masters       adm-clerical
# 28833          460722          MALE                   PhD   transport-moving
# 28834          472634          MALE             Associate   transport-moving
# 28835          450730        FEMALE                   PhD  handlers-cleaners
#
#        InsuredHobbies  CapitalGains  CapitalLoss  Country
# 0              movies         56700       -48500    India
# 1           cross-fit         70600       -48500    India
# 2                polo         66400       -63700    India
# 3                polo         47900       -73400    India
# 4             dancing             0       -41500    India
# ...               ...           ...          ...      ...
# 28831        sleeping             0            0    India
# 28832         dancing             0       -28800    India
# 28833    base-jumping         63100       -43800    India
# 28834       skydiving         67400       -43800    India
# 28835    base-jumping         46400       -74300    India
#
# [28836 rows x 28 columns]

# %%
claim_Demog_policy = pd.merge(claim_Demog, policy, how='left', on=['CustomerID'])
claim_Demog_policy
# Out:
#       CustomerID DateOfIncident            TypeOfIncident TypeOfCollission  \
# 0      Cust10000     2015-02-03   Multi-vehicle Collision   Side Collision
# 1      Cust10001     2015-02-02   Multi-vehicle Collision   Side Collision
# 2      Cust10002     2015-01-15  Single Vehicle Collision   Side Collision
# 3      Cust10003     2015-01-19  Single Vehicle Collision   Side Collision
# 4      Cust10004     2015-01-09  Single Vehicle Collision   Rear Collision
# ...          ...            ...                       ...              ...
# 28831   Cust9993     2015-01-24             Vehicle Theft                ?
# 28832   Cust9994     2015-02-09  Single Vehicle Collision  Front Collision
# 28833   Cust9996     2015-01-28  Single Vehicle Collision   Rear Collision
# 28834   Cust9997     2015-01-28  Single Vehicle Collision   Rear Collision
# 28835   Cust9999     2015-01-13  Single Vehicle Collision  Front Collision
#
#       SeverityOfIncident AuthoritiesContacted IncidentState IncidentCity  \
# 0             Total Loss               Police        State7        City1
# 1             Total Loss               Police        State7        City5
# 2           Minor Damage                Other        State8        City6
# 3           Minor Damage                Other        State9        City6
# 4           Minor Damage                 Fire        State8        City6
# ...                  ...                  ...           ...          ...
# 28831     Trivial Damage               Police        State9        City4
# 28832       Minor Damage                 Fire        State8        City3
# 28833       Minor Damage                 Fire        State9        City7
# 28834       Minor Damage            Ambulance        State9        City3
# 28835         Total Loss                Other        State8        City3
#
#       IncidentAddress  IncidentTime  ...  Country InsurancePolicyNumber  \
# 0       Location 1311            17  ...    India                119121
# 1       Location 1311            10  ...    India                119122
# 2       Location 2081            22  ...    India                119123
# 3       Location 2081            22  ...    India                119124
# 4       Location 1695            10  ...    India                119125
# ...               ...           ...  ...      ...                   ...
# 28831   Location 1890             3  ...    India                119114
# 28832   Location 2097            17  ...    India                119115
# 28833   Location 1452             1  ...    India                119117
# 28834   Location 1876             1  ...    India                119118
# 28835   Location 1874             9  ...    India                119120
#
#        CustomerLoyaltyPeriod DateOfPolicyCoverage InsurancePolicyState  \
# 0                         49           1998-10-25               State1
# 1                        114           2000-11-15               State1
# 2                        167           2001-02-12               State3
# 3                        190           2005-04-11               State2
# 4                        115           1996-10-25               State2
# ...                      ...                  ...                  ...
# 28831                    321           1998-04-18               State1
# 28832                    237           2004-09-07               State2
# 28833                    392           1998-09-10               State3
# 28834                    391           1998-08-10               State3
# 28835                    191           2003-04-12               State2
#
#       Policy_CombinedSingleLimit  Policy_Deductible  PolicyAnnualPremium  \
# 0                        100/300               1000              1632.73
# 1                        100/300               1000              1255.19
# 2                       500/1000                617              1373.38
# 3                       500/1000                722              1337.60
# 4                        100/300                500              1353.73
# ...                          ...                ...                  ...
# 28831                   500/1000                655              1276.01
# 28832                    100/300               1089              1273.38
# 28833                    250/500                787              1380.92
# 28834                    250/500                780              1389.29
# 28835                   500/1000               2000               928.43
#
#        UmbrellaLimit  InsuredRelationship
# 0                  0        not-in-family
# 1                  0        not-in-family
# 2                  0                 wife
# 3                  0            own-child
# 4            4279863            unmarried
# ...              ...                  ...
# 28831              0            unmarried
# 28832              0            unmarried
# 28833        3448735            own-child
# 28834        3364301        not-in-family
# 28835        2909175              husband
#
# [28836 rows x 37 columns]

# %%
claim_Demog_policy_vehicle = pd.merge(claim_Demog_policy, vehicle, how='left', on=['CustomerID'])
claim_Demog_policy_vehicle
# Out:
#       CustomerID DateOfIncident            TypeOfIncident TypeOfCollission  \
# 0      Cust10000     2015-02-03   Multi-vehicle Collision   Side Collision
# 1      Cust10001     2015-02-02   Multi-vehicle Collision   Side Collision
# 2      Cust10002     2015-01-15  Single Vehicle Collision   Side Collision
# 3      Cust10003     2015-01-19  Single Vehicle Collision   Side Collision
# 4      Cust10004     2015-01-09  Single Vehicle Collision   Rear Collision
# ...          ...            ...                       ...              ...
# 28831   Cust9993     2015-01-24             Vehicle Theft                ?
# 28832   Cust9994     2015-02-09  Single Vehicle Collision  Front Collision
# 28833   Cust9996     2015-01-28  Single Vehicle Collision   Rear Collision
# 28834   Cust9997     2015-01-28  Single Vehicle Collision   Rear Collision
# 28835   Cust9999     2015-01-13  Single Vehicle Collision  Front Collision
#
#       SeverityOfIncident AuthoritiesContacted IncidentState IncidentCity  \
# 0             Total Loss               Police        State7        City1
# 1             Total Loss               Police        State7        City5
# 2           Minor Damage                Other        State8        City6
# 3           Minor Damage                Other        State9        City6
# 4           Minor Damage                 Fire        State8        City6
# ...                  ...                  ...           ...          ...
# 28831     Trivial Damage               Police        State9        City4
# 28832       Minor Damage                 Fire        State8        City3
# 28833       Minor Damage                 Fire        State9        City7
# 28834       Minor Damage            Ambulance        State9        City3
# 28835         Total Loss                Other        State8        City3
#
#       IncidentAddress  IncidentTime  ...  InsurancePolicyState  \
# 0       Location 1311            17  ...                State1
# 1       Location 1311            10  ...                State1
# 2       Location 2081            22  ...                State3
# 3       Location 2081            22  ...                State2
# 4       Location 1695            10  ...                State2
# ...               ...           ...  ...                   ...
# 28831   Location 1890             3  ...                State1
# 28832   Location 2097            17  ...                State2
# 28833   Location 1452             1  ...                State3
# 28834   Location 1876             1  ...                State3
# 28835   Location 1874             9  ...                State2
#
#       Policy_CombinedSingleLimit  Policy_Deductible PolicyAnnualPremium  \
# 0                        100/300               1000             1632.73
# 1                        100/300               1000             1255.19
# 2                       500/1000                617             1373.38
# 3                       500/1000                722             1337.60
# 4                        100/300                500             1353.73
# ...                          ...                ...                 ...
# 28831                   500/1000                655             1276.01
# 28832                    100/300               1089             1273.38
# 28833                    250/500                787             1380.92
# 28834                    250/500                780             1389.29
# 28835                   500/1000               2000              928.43
#
#       UmbrellaLimit InsuredRelationship     VehicleID  VehicleMake  \
# 0                 0       not-in-family  Vehicle26917         Audi
# 1                 0       not-in-family  Vehicle15893         Audi
# 2                 0                wife   Vehicle5152   Volkswagen
# 3                 0           own-child  Vehicle37363   Volkswagen
# 4           4279863           unmarried  Vehicle28633       Toyota
# ...             ...                 ...           ...          ...
# 28831             0           unmarried  Vehicle13568       Suburu
# 28832             0           unmarried  Vehicle19810         Jeep
# 28833       3448735           own-child   Vehicle3339       Suburu
# 28834       3364301       not-in-family  Vehicle10240       Suburu
# 28835       2909175             husband  Vehicle39163       Suburu
#
#        VehicleModel  VehicleYOM
# 0                A5        2008
# 1                A5        2006
# 2             Jetta        1999
# 3             Jetta        2003
# 4               CRV        2010
# ...             ...         ...
# 28831       Impreza        2007
# 28832      Wrangler        2003
# 28833        Legacy        2004
# 28834     Forrestor        2004
# 28835          E400        2007
#
# [28836 rows x 41 columns]

# %%
Fraud_detect = pd.merge(claim_Demog_policy_vehicle, target, how='left', on=['CustomerID'])
Fraud_detect
# Out:
#       CustomerID DateOfIncident            TypeOfIncident TypeOfCollission  \
# 0      Cust10000     2015-02-03   Multi-vehicle Collision   Side Collision
# 1      Cust10001     2015-02-02   Multi-vehicle Collision   Side Collision
# 2      Cust10002     2015-01-15  Single Vehicle Collision   Side Collision
# 3      Cust10003     2015-01-19  Single Vehicle Collision   Side Collision
# 4      Cust10004     2015-01-09  Single Vehicle Collision   Rear Collision
# ...          ...            ...                       ...              ...
# 28831   Cust9993     2015-01-24             Vehicle Theft                ?
# 28832   Cust9994     2015-02-09  Single Vehicle Collision  Front Collision
# 28833   Cust9996     2015-01-28  Single Vehicle Collision   Rear Collision
# 28834   Cust9997     2015-01-28  Single Vehicle Collision   Rear Collision
# 28835   Cust9999     2015-01-13  Single Vehicle Collision  Front Collision
#
#       SeverityOfIncident AuthoritiesContacted IncidentState IncidentCity  \
# 0             Total Loss               Police        State7        City1
# 1             Total Loss               Police        State7        City5
# 2           Minor Damage                Other        State8        City6
# 3           Minor Damage                Other        State9        City6
# 4           Minor Damage                 Fire        State8        City6
# ...                  ...                  ...           ...          ...
# 28831     Trivial Damage               Police        State9        City4
# 28832       Minor Damage                 Fire        State8        City3
# 28833       Minor Damage                 Fire        State9        City7
# 28834       Minor Damage            Ambulance        State9        City3
# 28835         Total Loss                Other        State8        City3
#
#       IncidentAddress  IncidentTime  ...  Policy_CombinedSingleLimit  \
# 0       Location 1311            17  ...                     100/300
# 1       Location 1311            10  ...                     100/300
# 2       Location 2081            22  ...                    500/1000
# 3       Location 2081            22  ...                    500/1000
# 4       Location 1695            10  ...                     100/300
# ...               ...           ...  ...                         ...
# 28831   Location 1890             3  ...                    500/1000
# 28832   Location 2097            17  ...                     100/300
# 28833   Location 1452             1  ...                     250/500
# 28834   Location 1876             1  ...                     250/500
# 28835   Location 1874             9  ...                    500/1000
#
#       Policy_Deductible  PolicyAnnualPremium UmbrellaLimit  \
# 0                  1000              1632.73             0
# 1                  1000              1255.19             0
# 2                   617              1373.38             0
# 3                   722              1337.60             0
# 4                   500              1353.73       4279863
# ...                 ...                  ...           ...
# 28831               655              1276.01             0
# 28832              1089              1273.38             0
# 28833               787              1380.92       3448735
# 28834               780              1389.29       3364301
# 28835              2000               928.43       2909175
#
#       InsuredRelationship     VehicleID  VehicleMake  VehicleModel  \
# 0           not-in-family  Vehicle26917         Audi            A5
# 1           not-in-family  Vehicle15893         Audi            A5
# 2                    wife   Vehicle5152   Volkswagen         Jetta
# 3               own-child  Vehicle37363   Volkswagen         Jetta
# 4               unmarried  Vehicle28633       Toyota           CRV
# ...                   ...           ...          ...           ...
# 28831           unmarried  Vehicle13568       Suburu       Impreza
# 28832           unmarried  Vehicle19810         Jeep      Wrangler
# 28833           own-child   Vehicle3339       Suburu        Legacy
# 28834       not-in-family  Vehicle10240       Suburu     Forrestor
# 28835             husband  Vehicle39163       Suburu          E400
#
#        VehicleYOM  ReportedFraud
# 0            2008              N
# 1            2006              N
# 2            1999              N
# 3            2003              N
# 4            2010              N
# ...           ...            ...
# 28831        2007              N
# 28832        2003              N
# 28833        2004              N
# 28834        2004              N
# 28835        2007              N
#
# [28836 rows x 42 columns]

# %%
sns.countplot(x= Fraud_detect["AuthoritiesContacted"])
# Out:
# <Axes: xlabel='AuthoritiesContacted', ylabel='count'>

# %%
Fraud_detect.isnull().sum()
# Out:
# CustomerID                     0
# DateOfIncident                 0
# TypeOfIncident                 0
# TypeOfCollission               0
# SeverityOfIncident             0
# AuthoritiesContacted           0
# IncidentState                  0
# IncidentCity                   0
# IncidentAddress                0
# IncidentTime                   0
# NumberOfVehicles               0
# PropertyDamage                 0
# BodilyInjuries                 0
# Witnesses                      0
# PoliceReport                   0
# AmountOfTotalClaim             0
# AmountOfInjuryClaim            0
# AmountOfPropertyClaim          0
# AmountOfVehicleDamage          0
# InsuredAge                     0
# InsuredZipCode                 0
# InsuredGender                 30
# InsuredEducationLevel          0
# InsuredOccupation              0
# InsuredHobbies                 0
# CapitalGains                   0
# CapitalLoss                    0
# Country                        2
# InsurancePolicyNumber          0
# CustomerLoyaltyPeriod          0
# DateOfPolicyCoverage           0
# InsurancePolicyState           0
# Policy_CombinedSingleLimit     0
# Policy_Deductible              0
# PolicyAnnualPremium            0
# UmbrellaLimit                  0
# InsuredRelationship            0
# VehicleID                      0
# VehicleMake                    0
# VehicleModel                   0
# VehicleYOM                     0
# ReportedFraud                  0
# dtype: int64

# %%
sns.countplot(x= Fraud_detect["SeverityOfIncident"])
# Out:
# <Axes: xlabel='SeverityOfIncident', ylabel='count'>

# %%
for i in Fraud_detect.columns:
    print(i,Fraud_detect[i].unique())
# Out:
# CustomerID ['Cust10000' 'Cust10001' 'Cust10002' ... 'Cust9996' 'Cust9997' 'Cust9999']
# DateOfIncident ['2015-02-03' '2015-02-02' '2015-01-15' '2015-01-19' '2015-01-09'
#  '2015-02-07' '2015-01-30' '2015-01-12' '2015-02-06' '2015-01-25'
#  '2015-02-10' '2015-02-22' '2015-02-25' '2015-01-02' '2015-02-28'
#  '2015-01-03' '2015-01-29' '2015-02-23' '2015-01-28' '2015-02-26'
#  '2015-01-27' '2015-01-16' '2015-01-17' '2015-02-04' '2015-01-05'
#  '2015-01-10' '2015-02-11' '2015-01-13' '2015-01-06' '2015-01-07'
#  '2015-02-17' '2015-02-12' '2015-02-13' '2015-01-26' '2015-02-21'
#  '2015-02-14' '2015-02-15' '2015-01-20' '2015-01-24' '2015-01-08'
#  '2015-01-11' '2015-02-09' '2015-02-27' '2015-02-24' '2015-01-18'
#  '2015-02-08' '2015-01-22' '2015-02-19' '2015-02-18' '2015-02-16'
#  '2015-01-04' '2015-02-05' '2015-01-01' '2015-01-23' '2015-01-21'
#  '2015-01-14' '2015-02-20' '2015-01-31' '2015-03-06' '2015-03-01'
#  '2015-03-04' '2015-03-03' '2015-03-02' '2015-02-01' '2015-03-05'
#  '2015-03-09' '2015-03-11' '2015-03-07' '2015-03-08' '2015-03-12'
#  '2015-03-10' '2015-03-14']
# TypeOfIncident ['Multi-vehicle Collision' 'Single Vehicle Collision' 'Parked Car'
#  'Vehicle Theft']
# TypeOfCollission ['Side Collision' 'Rear Collision' 'Front Collision' '?']
# SeverityOfIncident ['Total Loss' 'Minor Damage' 'Major Damage' 'Trivial Damage']
# AuthoritiesContacted ['Police' 'Other' 'Fire' 'Ambulance' 'None']
# IncidentState ['State7' 'State8' 'State9' 'State5' 'State6' 'State4' 'State3']
# IncidentCity ['City1' 'City5' 'City6' 'City4' 'City3' 'City2' 'City7']
# IncidentAddress ['Location 1311' 'Location 2081' 'Location 1695' 'Location 1440'
#  'Location 1521' 'Location 1596' 'Location 2002' 'Location 1341'
#  'Location 1799' 'Location 2030' 'Location 1677' 'Location 1963'
#  'Location 1449' 'Location 1580' 'Location 1167' 'Location 1261'
#  'Location 1793' 'Location 1112' 'Location 2092' 'Location 1292'
#  'Location 1024' 'Location 1426' 'Location 1359' 'Location 1228'
#  'Location 1990' 'Location 2054' 'Location 1076' 'Location 1025'
#  'Location 1372' 'Location 1629' 'Location 1060' 'Location 1189'
#  'Location 1518' 'Location 1302' 'Location 1690' 'Location 1469'
#  'Location 1593' 'Location 1231' 'Location 2051' 'Location 1362'
#  'Location 1916' 'Location 1179' 'Location 1404' 'Location 1842'
#  254 188 478  73 128 338  51 206 126 177 249 240 366 441 287 264 194 227
#  365 337 316  13 424  83 132 174 427  47 218   5 284 261 421  58 139  31
#  444 339  82 456 464 221 207  50 103 117  88 108  92 183  25  29  26 233
#  378 417 416 224  57 122 406 453 402  69 291 300  19 386 446 353  20 133
#  452 112  24 297  46  23  66 377  55  22  71 398 361 279 309 258 423 445
#  405 191 323 277 388  14  18 437 475 354  95  34  53  16 426 322 380 336
#  374  68 359  43 449  36 360 443 459 468  77  39 376  48 362 372  32 315
#  448 397 350 341 458 435 403   2 461 382 317   6 422 314 420 451 344 429
#  410 455 473  10 436 438 409   1 373  12 415 393  35  21  40 462 466 433
#  457 387 472 308 442  44   9 469  17 467 463 407 401 329   4 391 383 465
#  479 474 392   3  28 363 476 477 418 326 470]
# DateOfPolicyCoverage ['1998-10-25' '2000-11-15' '2001-02-12' ... '2008-10-06' '2001-11-03'
#  '1998-11-03']
# InsurancePolicyState ['State1' 'State3' 'State2']
# Policy_CombinedSingleLimit ['100/300' '500/1000' '250/500' '250/1000' '500/300' '500/500' '100/500'
#  '250/300' '100/1000']
# Policy_Deductible [1000  617  722 ... 1104 1509 1711]
# PolicyAnnualPremium [1632.73 1255.19 1373.38 ... 1276.01 1380.92  928.43]
# UmbrellaLimit [      0 4279863 3921366 ... 3448735 3364301 2909175]
# InsuredRelationship ['not-in-family' 'wife' 'own-child' 'unmarried' 'husband' 'other-relative']
# VehicleID ['Vehicle26917' 'Vehicle15893' 'Vehicle5152' ... 'Vehicle3339'
#  'Vehicle10240' 'Vehicle39163']
# VehicleMake ['Audi' 'Volkswagen' 'Toyota' 'Mercedes' 'Suburu' 'Saab' 'Nissan' 'Ford'
#  'Accura' 'Dodge' 'Honda' 'Chevrolet' 'Jeep' 'BMW' '???']
# VehicleModel ['A5' 'Jetta' 'CRV' 'C300' 'Passat' '92x' 'Ultima' 'Fusion' 'Impreza' '93'
#  'Highlander' 'X5' 'Accord' 'Corolla' 'Forrestor' 'F150' 'Pathfinder'
#  'Neon' 'Tahoe' 'Wrangler' 'A3' 'RSX' 'Malibu' 'E400' 'Legacy' '95'
#  'Grand Cherokee' 'Escape' 'Civic' 'Silverado' 'RAM' 'Camry' 'M5'
#  '3 Series' 'ML350' 'Maxima' 'MDX' 'X6' 'TL']
# VehicleYOM ['2008' '2006' '1999' '2003' '2010' '2011' '2000' '1995' '2004' '2002'
#  '2001' '2005' '1997' '2015' '2012' '2007' '2014' '1998' '2009' '1996'
#  '2013']
# ReportedFraud ['N' 'Y']

# %%
Fraud_detect['TypeOfCollission']=Fraud_detect['TypeOfCollission'].replace('?',np.nan)
Fraud_detect['PropertyDamage']=Fraud_detect['PropertyDamage'].replace('?',np.nan)
Fraud_detect['PoliceReport']=Fraud_detect['PoliceReport'].replace('?',np.nan)
Fraud_detect['VehicleMake']=Fraud_detect['VehicleMake'].replace('???',np.nan)
Fraud_detect['Witnesses']=Fraud_detect['Witnesses'].replace('MISSINGVALUE',np.nan)

# %%
Fraud_detect['TypeOfCollission'].unique()
# Out:
# array(['Side Collision', 'Rear Collision', 'Front Collision', nan],
#       dtype=object)

# %%
Fraud_detect.isna().sum()
# Out:
# CustomerID                        0
# DateOfIncident                    0
# TypeOfIncident                    0
# TypeOfCollission               5162
# SeverityOfIncident                0
# AuthoritiesContacted              0
# IncidentState                     0
# IncidentCity                      0
# IncidentAddress                   0
# IncidentTime                      0
# NumberOfVehicles                  0
# PropertyDamage                10459
# BodilyInjuries                    0
# Witnesses                        46
# PoliceReport                   9805
# AmountOfTotalClaim                0
# AmountOfInjuryClaim               0
# AmountOfPropertyClaim             0
# AmountOfVehicleDamage             0
# InsuredAge                        0
# InsuredZipCode                    0
# InsuredGender                    30
# InsuredEducationLevel             0
# InsuredOccupation                 0
# InsuredHobbies                    0
# CapitalGains                      0
# CapitalLoss                       0
# Country                           2
# InsurancePolicyNumber             0
# CustomerLoyaltyPeriod             0
# DateOfPolicyCoverage              0
# InsurancePolicyState              0
# Policy_CombinedSingleLimit        0
# Policy_Deductible                 0
# PolicyAnnualPremium               0
# UmbrellaLimit                     0
# InsuredRelationship               0
# VehicleID                         0
# VehicleMake                      50
# VehicleModel                      0
# VehicleYOM                        0
# ReportedFraud                     0
# dtype: int64

# %%
Fraud_detect.isna().mean().sort_values()
# Out:
# CustomerID                    0.000000
# InsuredEducationLevel         0.000000
# InsuredOccupation             0.000000
# InsuredHobbies                0.000000
# CapitalGains                  0.000000
# CapitalLoss                   0.000000
# InsurancePolicyNumber         0.000000
# CustomerLoyaltyPeriod         0.000000
# VehicleYOM                    0.000000
# DateOfPolicyCoverage          0.000000
# Policy_CombinedSingleLimit    0.000000
# Policy_Deductible             0.000000
# PolicyAnnualPremium           0.000000
# UmbrellaLimit                 0.000000
# InsuredRelationship           0.000000
# VehicleID                     0.000000
# VehicleModel                  0.000000
# InsurancePolicyState          0.000000
# InsuredAge                    0.000000
# InsuredZipCode                0.000000
# AmountOfPropertyClaim         0.000000
# DateOfIncident                0.000000
# TypeOfIncident                0.000000
# SeverityOfIncident            0.000000
# AuthoritiesContacted          0.000000
# IncidentState                 0.000000
# IncidentCity                  0.000000
# IncidentAddress               0.000000
# AmountOfVehicleDamage         0.000000
# IncidentTime                  0.000000
# BodilyInjuries                0.000000
# AmountOfTotalClaim            0.000000
# AmountOfInjuryClaim           0.000000
# NumberOfVehicles              0.000000
# ReportedFraud                 0.000000
# Country                       0.000069
# InsuredGender                 0.001040
# Witnesses                     0.001595
# VehicleMake                   0.001734
# TypeOfCollission              0.179012
# PoliceReport                  0.340026
# PropertyDamage                0.362706
# dtype: float64

# %%
Fraud_detect.dtypes
# Out:
# CustomerID                     object
# DateOfIncident                 object
# TypeOfIncident                 object
# TypeOfCollission               object
# SeverityOfIncident             object
# AuthoritiesContacted           object
# IncidentState                  object
# IncidentCity                   object
# IncidentAddress                object
# IncidentTime                    int64
# NumberOfVehicles                int64
# PropertyDamage                 object
# BodilyInjuries                  int64
# Witnesses                      object
# PoliceReport                   object
# AmountOfTotalClaim             object
# AmountOfInjuryClaim             int64
# AmountOfPropertyClaim           int64
# AmountOfVehicleDamage           int64
# InsuredAge                      int64
# InsuredZipCode                  int64
# InsuredGender                  object
# InsuredEducationLevel          object
# InsuredOccupation              object
# InsuredHobbies                 object
# CapitalGains                    int64
# CapitalLoss                     int64
# Country                        object
# InsurancePolicyNumber           int64
# CustomerLoyaltyPeriod           int64
# DateOfPolicyCoverage           object
# InsurancePolicyState           object
# Policy_CombinedSingleLimit     object
# Policy_Deductible               int64
# PolicyAnnualPremium           float64
# UmbrellaLimit                   int64
# InsuredRelationship            object
# VehicleID                      object
# VehicleMake                    object
# VehicleModel                   object
# VehicleYOM                     object
# ReportedFraud                  object
# dtype: object

# %%
Fraud_detect['TypeOfCollission']=Fraud_detect['TypeOfCollission'].fillna(method="ffill")
Fraud_detect['PropertyDamage']=Fraud_detect['PropertyDamage'].fillna(method="bfill")
Fraud_detect['InsuredGender']=Fraud_detect['InsuredGender'].fillna(method="ffill")
Fraud_detect['PoliceReport']=Fraud_detect['PoliceReport'].fillna(method="bfill")
Fraud_detect['VehicleMake']=Fraud_detect['VehicleMake'].fillna(method="ffill")
Fraud_detect['Witnesses']=Fraud_detect['Witnesses'].fillna(method="ffill")
Fraud_detect['Country']=Fraud_detect['Country'].fillna(method="ffill")

# %%
Fraud_detect['PropertyDamage'].nunique()
# Out:
# 2

# %%
Fraud_detect['PropertyDamage'].unique()
# Out:
# array(['YES', 'NO'], dtype=object)

# %%
Fraud_detect.isna().sum()
# Out:
# CustomerID                    0
# DateOfIncident                0
# TypeOfIncident                0
# TypeOfCollission              0
# SeverityOfIncident            0
# AuthoritiesContacted          0
# IncidentState                 0
# IncidentCity                  0
# IncidentAddress               0
# IncidentTime                  0
# NumberOfVehicles              0
# PropertyDamage                0
# BodilyInjuries                0
# Witnesses                     0
# PoliceReport                  0
# AmountOfTotalClaim            0
# AmountOfInjuryClaim           0
# AmountOfPropertyClaim         0
# AmountOfVehicleDamage         0
# InsuredAge                    0
# InsuredZipCode                0
# InsuredGender                 0
# InsuredEducationLevel         0
# InsuredOccupation             0
# InsuredHobbies                0
# CapitalGains                  0
# CapitalLoss                   0
# Country                       0
# InsurancePolicyNumber         0
# CustomerLoyaltyPeriod         0
# DateOfPolicyCoverage          0
# InsurancePolicyState          0
# Policy_CombinedSingleLimit    0
# Policy_Deductible             0
# PolicyAnnualPremium           0
# UmbrellaLimit                 0
# InsuredRelationship           0
# VehicleID                     0
# VehicleMake                   0
# VehicleModel                  0
# VehicleYOM                    0
# ReportedFraud                 0
# dtype: int64

# %%
Fraud_detect.drop(Fraud_detect[['DateOfIncident','VehicleID' ,'InsuredHobbies','Country']], axis=1, inplace=True)

# %%
Fraud_detect['Witnesses'] = pd.to_numeric(Fraud_detect['Witnesses'], errors='coerce')
Fraud_detect['AmountOfTotalClaim'] = pd.to_numeric(Fraud_detect['AmountOfTotalClaim'], errors='coerce')
Fraud_detect['VehicleYOM'] = pd.to_numeric(Fraud_detect['VehicleYOM'], errors='coerce')

# %%
pd.set_option('display.max_columns', None)
obj=Fraud_detect.select_dtypes(include ='object')
obj.drop(obj[['CustomerID']], axis=1, inplace=True)

# %%
class LabelEncoder:
    def __init__(self):
        self.labels = {}

    def fit_transform(self, y):
        unique_labels = set(y)
        for i, label in enumerate(unique_labels):
            self.labels[label] = i

        encoded_labels = []
        for label in y:
            encoded_labels.append(self.labels[label])

        return encoded_labels

    def inverse_transform(self, y):
        inv_labels = {v: k for k, v in self.labels.items()}

        decoded_labels = []
        for label in y:
            decoded_labels.append(inv_labels[label])

        return decoded_labels

# %%
Fraud_detect.drop(Fraud_detect[['TypeOfIncident', 'TypeOfCollission', 'SeverityOfIncident',
       'AuthoritiesContacted', 'IncidentState', 'IncidentCity',
       'IncidentAddress', 'PropertyDamage', 'PoliceReport', 'InsuredGender',
       'InsuredEducationLevel', 'InsuredOccupation', 'DateOfPolicyCoverage',
       'InsurancePolicyState', 'Policy_CombinedSingleLimit',
       'InsuredRelationship', 'VehicleMake', 'VehicleModel', 'ReportedFraud']], axis=1, inplace=True)

# %%
Fraud_detect
# Out:
#       CustomerID  IncidentTime  NumberOfVehicles  BodilyInjuries  Witnesses  \
# 0      Cust10000            17                 3               1          0
# 1      Cust10001            10                 3               2          1
# 2      Cust10002            22                 1               2          3
# 3      Cust10003            22                 1               2          3
# 4      Cust10004            10                 1               2          1
# ...          ...           ...               ...             ...        ...
# 28831   Cust9993             3                 1               0          3
# 28832   Cust9994            17                 1               0          2
# 28833   Cust9996             1                 1               2          0
# 28834   Cust9997             1                 1               2          0
# 28835   Cust9999             9                 1               1          3
#
#        AmountOfTotalClaim  AmountOfInjuryClaim  AmountOfPropertyClaim  \
# 0                 65501.0                13417                   6071
# 1                 61382.0                15560                   5919
# 2                 66755.0                11630                  11630
# 3                 66243.0                12003                  12003
# 4                 53544.0                 8829                   7234
# ...                   ...                  ...                    ...
# 28831              6590.0                  870                   1078
# 28832             74547.0                14699                   7875
# 28833             55305.0                 7043                   7043
# 28834             55830.0                 7059                   7059
# 28835             68969.0                12075                   6038
#
#        AmountOfVehicleDamage  InsuredAge  InsuredZipCode  CapitalGains  \
# 0                      46013          35          454776         56700
# 1                      39903          36          454776         70600
# 2                      43495          33          603260         66400
# 3                      42237          36          474848         47900
# 4                      37481          29          457942             0
# ...                      ...         ...             ...           ...
# 28831                   4642          46          600561             0
# 28832                  51973          44          439304             0
# 28833                  41219          53          460722         63100
# 28834                  41712          53          472634         67400
# 28835                  50856          36          450730         46400
#
#        CapitalLoss  InsurancePolicyNumber  CustomerLoyaltyPeriod  \
# 0           -48500                 119121                     49
# 1           -48500                 119122                    114
# 2           -63700                 119123                    167
# 3           -73400                 119124                    190
# 4           -41500                 119125                    115
# ...            ...                    ...                    ...
# 28831            0                 119114                    321
# 28832       -28800                 119115                    237
# 28833       -43800                 119117                    392
# 28834       -43800                 119118                    391
# 28835       -74300                 119120                    191
#
#        Policy_Deductible  PolicyAnnualPremium  UmbrellaLimit  VehicleYOM
# 0                   1000              1632.73              0        2008
# 1                   1000              1255.19              0        2006
# 2                    617              1373.38              0        1999
# 3                    722              1337.60              0        2003
# 4                    500              1353.73        4279863        2010
# ...                  ...                  ...            ...         ...
# 28831                655              1276.01              0        2007
# 28832               1089              1273.38              0        2003
# 28833                787              1380.92        3448735        2004
# 28834                780              1389.29        3364301        2004
# 28835               2000               928.43        2909175        2007
#
# [28836 rows x 19 columns]

# %%
encoded={}
for i in obj.columns:
    le = LabelEncoder()
    encoded_data = le.fit_transform(obj[i])
    encoded[i]=encoded_data
encoded
df=pd.DataFrame(encoded)
pd.set_option('display.max_columns', None)
df.columns
# Out:
# Index(['TypeOfIncident', 'TypeOfCollission', 'SeverityOfIncident',
#        'AuthoritiesContacted', 'IncidentState', 'IncidentCity',
#        'IncidentAddress', 'PropertyDamage', 'PoliceReport', 'InsuredGender',
#        'InsuredEducationLevel', 'InsuredOccupation', 'DateOfPolicyCoverage',
#        'InsurancePolicyState', 'Policy_CombinedSingleLimit',
#        'InsuredRelationship', 'VehicleMake', 'VehicleModel', 'ReportedFraud'],
#       dtype='object')

# %%
int64=Fraud_detect.select_dtypes(include ='int64')
int64.columns
# Out:
# Index(['IncidentTime', 'NumberOfVehicles', 'BodilyInjuries', 'Witnesses',
#        'AmountOfInjuryClaim', 'AmountOfPropertyClaim', 'AmountOfVehicleDamage',
#        'InsuredAge', 'InsuredZipCode', 'CapitalGains', 'CapitalLoss',
#        'InsurancePolicyNumber', 'CustomerLoyaltyPeriod', 'Policy_Deductible',
#        'UmbrellaLimit', 'VehicleYOM'],
#       dtype='object')

# %%
feature =['IncidentTime', 'NumberOfVehicles', 'BodilyInjuries', 'Witnesses',
       'AmountOfInjuryClaim', 'AmountOfPropertyClaim', 'AmountOfVehicleDamage',
       'InsuredAge', 'InsuredZipCode', 'CapitalGains', 'CapitalLoss',
       'InsurancePolicyNumber', 'CustomerLoyaltyPeriod', 'Policy_Deductible',
       'UmbrellaLimit', 'VehicleYOM']

for i in feature:
    plt.figure(figsize=(4,4))
    sns.boxplot(x=df["ReportedFraud"], y=int64[i])
    plt.show()

# %%
final = pd.concat([Fraud_detect, df], axis=1)
final
# Out:
#       CustomerID  IncidentTime  NumberOfVehicles  BodilyInjuries  Witnesses  \
# 0      Cust10000            17                 3               1          0
# 1      Cust10001            10                 3               2          1
# 2      Cust10002            22                 1               2          3
# 3      Cust10003            22                 1               2          3
# 4      Cust10004            10                 1               2          1
# ...          ...           ...               ...             ...        ...
# 28831   Cust9993             3                 1               0          3
# 28832   Cust9994            17                 1               0          2
# 28833   Cust9996             1                 1               2          0
# 28834   Cust9997             1                 1               2          0
# 28835   Cust9999             9                 1               1          3
#
#        AmountOfTotalClaim  AmountOfInjuryClaim  AmountOfPropertyClaim  \
# 0                 65501.0                13417                   6071
# 1                 61382.0                15560                   5919
# 2                 66755.0                11630                  11630
# 3                 66243.0                12003                  12003
# 4                 53544.0                 8829                   7234
# ...                   ...                  ...                    ...
# 28831              6590.0                  870                   1078
# 28832             74547.0                14699                   7875
# 28833             55305.0                 7043                   7043
# 28834             55830.0                 7059                   7059
# 28835             68969.0                12075                   6038
#
#        AmountOfVehicleDamage  InsuredAge  InsuredZipCode  CapitalGains  \
# 0                      46013          35          454776         56700
# 1                      39903          36          454776         70600
# 2                      43495          33          603260         66400
# 3                      42237          36          474848         47900
# 4                      37481          29          457942             0
# ...                      ...         ...             ...           ...
# 28831                   4642          46          600561             0
# 28832                  51973          44          439304             0
# 28833                  41219          53          460722         63100
# 28834                  41712          53          472634         67400
# 28835                  50856          36          450730         46400
#
#        CapitalLoss  InsurancePolicyNumber  CustomerLoyaltyPeriod  \
# 0           -48500                 119121                     49
# 1           -48500                 119122                    114
# 2           -63700                 119123                    167
# 3           -73400                 119124                    190
# 4           -41500                 119125                    115
# ...            ...                    ...                    ...
# 28831            0                 119114                    321
# 28832       -28800                 119115                    237
# 28833       -43800                 119117                    392
# 28834       -43800                 119118                    391
# 28835       -74300                 119120                    191
#
#        Policy_Deductible  PolicyAnnualPremium  UmbrellaLimit  VehicleYOM  \
# 0                   1000              1632.73              0        2008
# 1                   1000              1255.19              0        2006
# 2                    617              1373.38              0        1999
# 3                    722              1337.60              0        2003
# 4                    500              1353.73        4279863        2010
# ...                  ...                  ...            ...         ...
# 28831                655              1276.01              0        2007
# 28832               1089              1273.38              0        2003
# 28833                787              1380.92        3448735        2004
# 28834                780              1389.29        3364301        2004
# 28835               2000               928.43        2909175        2007
#
#        TypeOfIncident  TypeOfCollission  SeverityOfIncident  \
# 0                   3                 0                   1
# 1                   3                 0                   1
# 2                   1                 0                   2
# 3                   1                 0                   2
# 4                   1                 2                   2
# ...               ...               ...                 ...
# 28831               0                 2                   3
# 28832               1                 1                   2
# 28833               1                 2                   2
# 28834               1                 2                   2
# 28835               1                 1                   1
#
#        AuthoritiesContacted  IncidentState  IncidentCity  IncidentAddress  \
# 0                         4              3             3              423
# 1                         4              3             5              423
# 2                         1              2             6              130
# 3                         1              1             6              130
# 4                         3              2             6              281
# ...                     ...            ...           ...              ...
# 28831                     4              1             4              824
# 28832                     3              2             2              290
# 28833                     3              1             1              710
# 28834                     2              1             2              273
# 28835                     1              2             2              693
#
#        PropertyDamage  PoliceReport  InsuredGender  InsuredEducationLevel  \
# 0                   0             0              0                      2
# 1                   0             0              0                      2
# 2                   0             1              0                      2
# 3                   0             1              0                      2
# 4                   1             0              1                      0
# ...               ...           ...            ...                    ...
# 28831               1             0              0                      5
# 28832               0             0              0                      5
# 28833               0             0              0                      6
# 28834               1             0              0                      3
# 28835               1             0              1                      6
#
#        InsuredOccupation  DateOfPolicyCoverage  InsurancePolicyState  \
# 0                      6                  4718                     1
# 1                     12                  2926                     1
# 2                      6                  5961                     0
# 3                      6                  4198                     2
# 4                      0                  3888                     2
# ...                  ...                   ...                   ...
# 28831                  2                  1097                     1
# 28832                 11                  3370                     2
# 28833                 13                  2274                     0
# 28834                 13                  2335                     0
# 28835                  7                  1757                     2
#
#        Policy_CombinedSingleLimit  InsuredRelationship  VehicleMake  \
# 0                               3                    2            0
# 1                               3                    2            0
# 2                               5                    3            2
# 3                               5                    0            2
# 4                               3                    1           10
# ...                           ...                  ...          ...
# 28831                           5                    1           13
# 28832                           3                    1            7
# 28833                           4                    0           13
# 28834                           4                    2           13
# 28835                           5                    4           13
#
#        VehicleModel  ReportedFraud
# 0                12              0
# 1                12              0
# 2                 0              0
# 3                 0              0
# 4                27              0
# ...             ...            ...
# 28831             3              0
# 28832             6              0
# 28833            14              0
# 28834            35              0
# 28835            24              0
#
# [28836 rows x 38 columns]

# %%
final.set_index('CustomerID',inplace=True)

# %%
final
# Out:
#             IncidentTime  NumberOfVehicles  BodilyInjuries  Witnesses  \
# CustomerID
# Cust10000             17                 3               1          0
# Cust10001             10                 3               2          1
# Cust10002             22                 1               2          3
# Cust10003             22                 1               2          3
# Cust10004             10                 1               2          1
# ...                  ...               ...             ...        ...
# Cust9993               3                 1               0          3
# Cust9994              17                 1               0          2
# Cust9996               1                 1               2          0
# Cust9997               1                 1               2          0
# Cust9999               9                 1               1          3
#
#             AmountOfTotalClaim  AmountOfInjuryClaim  AmountOfPropertyClaim  \
# CustomerID
# Cust10000              65501.0                13417                   6071
# Cust10001              61382.0                15560                   5919
# Cust10002              66755.0                11630                  11630
# Cust10003              66243.0                12003                  12003
# Cust10004              53544.0                 8829                   7234
# ...                        ...                  ...                    ...
# Cust9993                6590.0                  870                   1078
# Cust9994               74547.0                14699                   7875
# Cust9996               55305.0                 7043                   7043
# Cust9997               55830.0                 7059                   7059
# Cust9999               68969.0                12075                   6038
#
#             AmountOfVehicleDamage  InsuredAge  InsuredZipCode  CapitalGains  \
# CustomerID
# Cust10000                   46013          35          454776         56700
# Cust10001                   39903          36          454776         70600
# Cust10002                   43495          33          603260         66400
# Cust10003                   42237          36          474848         47900
# Cust10004                   37481          29          457942             0
# ...                           ...         ...             ...           ...
# Cust9993                     4642          46          600561             0
# Cust9994                    51973          44          439304             0
# Cust9996                    41219          53          460722         63100
# Cust9997                    41712          53          472634         67400
# Cust9999                    50856          36          450730         46400
#
#             CapitalLoss  InsurancePolicyNumber  CustomerLoyaltyPeriod  \
# CustomerID
# Cust10000        -48500                 119121                     49
# Cust10001        -48500                 119122                    114
# Cust10002        -63700                 119123                    167
# Cust10003        -73400                 119124                    190
# Cust10004        -41500                 119125                    115
# ...                 ...                    ...                    ...
# Cust9993              0                 119114                    321
# Cust9994         -28800                 119115                    237
# Cust9996         -43800                 119117                    392
# Cust9997         -43800                 119118                    391
# Cust9999         -74300                 119120                    191
#
#             Policy_Deductible  PolicyAnnualPremium  UmbrellaLimit  VehicleYOM  \
# CustomerID
# Cust10000                1000              1632.73              0        2008
# Cust10001                1000              1255.19              0        2006
# Cust10002                 617              1373.38              0        1999
# Cust10003                 722              1337.60              0        2003
# Cust10004                 500              1353.73        4279863        2010
# ...                       ...                  ...            ...         ...
# Cust9993                  655              1276.01              0        2007
# Cust9994                 1089              1273.38              0        2003
# Cust9996                  787              1380.92        3448735        2004
# Cust9997                  780              1389.29        3364301        2004
# Cust9999                 2000               928.43        2909175        2007
#
#             TypeOfIncident  TypeOfCollission  SeverityOfIncident  \
# CustomerID
# Cust10000                3                 0                   1
# Cust10001                3                 0                   1
# Cust10002                1                 0                   2
# Cust10003                1                 0                   2
# Cust10004                1                 2                   2
# ...                    ...               ...                 ...
# Cust9993                 0                 2                   3
# Cust9994                 1                 1                   2
# Cust9996                 1                 2                   2
# Cust9997                 1                 2                   2
# Cust9999                 1                 1                   1
#
#             AuthoritiesContacted  IncidentState  IncidentCity  \
# CustomerID
# Cust10000                      4              3             3
# Cust10001                      4              3             5
# Cust10002                      1              2             6
# Cust10003                      1              1             6
# Cust10004                      3              2             6
# ...                          ...            ...           ...
# Cust9993                       4              1             4
# Cust9994                       3              2             2
# Cust9996                       3              1             1
# Cust9997                       2              1             2
# Cust9999                       1              2             2
#
#             IncidentAddress  PropertyDamage  PoliceReport  InsuredGender  \
# CustomerID
# Cust10000               423               0             0              0
# Cust10001               423               0             0              0
# Cust10002               130               0             1              0
# Cust10003               130               0             1              0
# Cust10004               281               1             0              1
# ...                     ...             ...           ...            ...
# Cust9993                824               1             0              0
# Cust9994                290               0             0              0
# Cust9996                710               0             0              0
# Cust9997                273               1             0              0
# Cust9999                693               1             0              1
#
#             InsuredEducationLevel  InsuredOccupation  DateOfPolicyCoverage  \
# CustomerID
# Cust10000                       2                  6                  4718
# Cust10001                       2                 12                  2926
# Cust10002                       2                  6                  5961
# Cust10003                       2                  6                  4198
# Cust10004                       0                  0                  3888
# ...                           ...                ...                   ...
# Cust9993                        5                  2                  1097
# Cust9994                        5                 11                  3370
# Cust9996                        6                 13                  2274
# Cust9997                        3                 13                  2335
# Cust9999                        6                  7                  1757
#
#             InsurancePolicyState  Policy_CombinedSingleLimit  \
# CustomerID
# Cust10000                      1                           3
# Cust10001                      1                           3
# Cust10002                      0                           5
# Cust10003                      2                           5
# Cust10004                      2                           3
# ...                          ...                         ...
# Cust9993                       1                           5
# Cust9994                       2                           3
# Cust9996                       0                           4
# Cust9997                       0                           4
# Cust9999                       2                           5
#
#             InsuredRelationship  VehicleMake  VehicleModel  ReportedFraud
# CustomerID
# Cust10000                     2            0            12              0
# Cust10001                     2            0            12              0
# Cust10002                     3            2             0              0
# Cust10003                     0            2             0              0
# Cust10004                     1           10            27              0
# ...                         ...          ...           ...            ...
# Cust9993                      1           13             3              0
# Cust9994                      1            7             6              0
# Cust9996                      0           13            14              0
# Cust9997                      2           13            35              0
# Cust9999                      4           13            24              0
#
# [28836 rows x 37 columns]

# %%
#first of all let us evaluate the target and find out if our data is imbalanced or not
sns.countplot(x= final["ReportedFraud"])
# Out:
# <Axes: xlabel='ReportedFraud', ylabel='count'>

# %%
final.dtypes
# Out:
# IncidentTime                    int64
# NumberOfVehicles                int64
# BodilyInjuries                  int64
# Witnesses                       int64
# AmountOfTotalClaim            float64
# AmountOfInjuryClaim             int64
# AmountOfPropertyClaim           int64
# AmountOfVehicleDamage           int64
# InsuredAge                      int64
# InsuredZipCode                  int64
# CapitalGains                    int64
# CapitalLoss                     int64
# InsurancePolicyNumber           int64
# CustomerLoyaltyPeriod           int64
# Policy_Deductible               int64
# PolicyAnnualPremium           float64
# UmbrellaLimit                   int64
# VehicleYOM                      int64
# TypeOfIncident                  int64
# TypeOfCollission                int64
# SeverityOfIncident              int64
# AuthoritiesContacted            int64
# IncidentState                   int64
# IncidentCity                    int64
# IncidentAddress                 int64
# PropertyDamage                  int64
# PoliceReport                    int64
# InsuredGender                   int64
# InsuredEducationLevel           int64
# InsuredOccupation               int64
# DateOfPolicyCoverage            int64
# InsurancePolicyState            int64
# Policy_CombinedSingleLimit      int64
# InsuredRelationship             int64
# VehicleMake                     int64
# VehicleModel                    int64
# ReportedFraud                   int64
# dtype: object

# %%
#Examaning a corelation matrix of all the features 
corrmat = final.corr()
plt.subplots(figsize=(30,30))
sns.heatmap(corrmat,annot=True, square=True);

# %%
#Evauating age distrivution 
plt.figure(figsize=(20,12))
Days_of_week=sns.countplot(x=final['NumberOfVehicles'],data=final, hue ="ReportedFraud")
Days_of_week.set_title("Number of vehicles involved", color="#774571")
# Out:
# Text(0.5, 1.0, 'Number of vehicles involved')

# %%
#Evauating age distrivution 
plt.figure(figsize=(20,12))
Days_of_week=sns.countplot(x=final['Witnesses'],data=final, hue ="ReportedFraud")
Days_of_week.set_title("Number of Witnesses", color="#774571")
# Out:
# Text(0.5, 1.0, 'Number of Witnesses')

# %%
y=final['ReportedFraud']
x=final.drop('ReportedFraud',axis=1)

# %%
x
# Out:
#             IncidentTime  NumberOfVehicles  BodilyInjuries  Witnesses  \
# CustomerID
# Cust10000             17                 3               1          0
# Cust10001             10                 3               2          1
# Cust10002             22                 1               2          3
# Cust10003             22                 1               2          3
# Cust10004             10                 1               2          1
# ...                  ...               ...             ...        ...
# Cust9993               3                 1               0          3
# Cust9994              17                 1               0          2
# Cust9996               1                 1               2          0
# Cust9997               1                 1               2          0
# Cust9999               9                 1               1          3
#
#             AmountOfTotalClaim  AmountOfInjuryClaim  AmountOfPropertyClaim  \
# CustomerID
# Cust10000              65501.0                13417                   6071
# Cust10001              61382.0                15560                   5919
# Cust10002              66755.0                11630                  11630
# Cust10003              66243.0                12003                  12003
# Cust10004              53544.0                 8829                   7234
# ...                        ...                  ...                    ...
# Cust9993                6590.0                  870                   1078
# Cust9994               74547.0                14699                   7875
# Cust9996               55305.0                 7043                   7043
# Cust9997               55830.0                 7059                   7059
# Cust9999               68969.0                12075                   6038
#
#             AmountOfVehicleDamage  InsuredAge  InsuredZipCode  CapitalGains  \
# CustomerID
# Cust10000                   46013          35          454776         56700
# Cust10001                   39903          36          454776         70600
# Cust10002                   43495          33          603260         66400
# Cust10003                   42237          36          474848         47900
# Cust10004                   37481          29          457942             0
# ...                           ...         ...             ...           ...
# Cust9993                     4642          46          600561             0
# Cust9994                    51973          44          439304             0
# Cust9996                    41219          53          460722         63100
# Cust9997                    41712          53          472634         67400
# Cust9999                    50856          36          450730         46400
#
#             CapitalLoss  InsurancePolicyNumber  CustomerLoyaltyPeriod  \
# CustomerID
# Cust10000        -48500                 119121                     49
# Cust10001        -48500                 119122                    114
# Cust10002        -63700                 119123                    167
# Cust10003        -73400                 119124                    190
# Cust10004        -41500                 119125                    115
# ...                 ...                    ...                    ...
# Cust9993              0                 119114                    321
# Cust9994         -28800                 119115                    237
# Cust9996         -43800                 119117                    392
# Cust9997         -43800                 119118                    391
# Cust9999         -74300                 119120                    191
#
#             Policy_Deductible  PolicyAnnualPremium  UmbrellaLimit  VehicleYOM  \
# CustomerID
# Cust10000                1000              1632.73              0        2008
# Cust10001                1000              1255.19              0        2006
# Cust10002                 617              1373.38              0        1999
# Cust10003                 722              1337.60              0        2003
# Cust10004                 500              1353.73        4279863        2010
# ...                       ...                  ...            ...         ...
# Cust9993                  655              1276.01              0        2007
# Cust9994                 1089              1273.38              0        2003
# Cust9996                  787              1380.92        3448735        2004
# Cust9997                  780              1389.29        3364301        2004
# Cust9999                 2000               928.43        2909175        2007
#
#             TypeOfIncident  TypeOfCollission  SeverityOfIncident  \
# CustomerID
# Cust10000                3                 0                   1
# Cust10001                3                 0                   1
# Cust10002                1                 0                   2
# Cust10003                1                 0                   2
# Cust10004                1                 2                   2
# ...                    ...               ...                 ...
# Cust9993                 0                 2                   3
# Cust9994                 1                 1                   2
# Cust9996                 1                 2                   2
# Cust9997                 1                 2                   2
# Cust9999                 1                 1                   1
#
#             AuthoritiesContacted  IncidentState  IncidentCity  \
# CustomerID
# Cust10000                      4              3             3
# Cust10001                      4              3             5
# Cust10002                      1              2             6
# Cust10003                      1              1             6
# Cust10004                      3              2             6
# ...                          ...            ...           ...
# Cust9993                       4              1             4
# Cust9994                       3              2             2
# Cust9996                       3              1             1
# Cust9997                       2              1             2
# Cust9999                       1              2             2
#
#             IncidentAddress  PropertyDamage  PoliceReport  InsuredGender  \
# CustomerID
# Cust10000               423               0             0              0
# Cust10001               423               0             0              0
# Cust10002               130               0             1              0
# Cust10003               130               0             1              0
# Cust10004               281               1             0              1
# ...                     ...             ...           ...            ...
# Cust9993                824               1             0              0
# Cust9994                290               0             0              0
# Cust9996                710               0             0              0
# Cust9997                273               1             0              0
# Cust9999                693               1             0              1
#
#             InsuredEducationLevel  InsuredOccupation  DateOfPolicyCoverage  \
# CustomerID
# Cust10000                       2                  6                  4718
# Cust10001                       2                 12                  2926
# Cust10002                       2                  6                  5961
# Cust10003                       2                  6                  4198
# Cust10004                       0                  0                  3888
# ...                           ...                ...                   ...
# Cust9993                        5                  2                  1097
# Cust9994                        5                 11                  3370
# Cust9996                        6                 13                  2274
# Cust9997                        3                 13                  2335
# Cust9999                        6                  7                  1757
#
#             InsurancePolicyState  Policy_CombinedSingleLimit  \
# CustomerID
# Cust10000                      1                           3
# Cust10001                      1                           3
# Cust10002                      0                           5
# Cust10003                      2                           5
# Cust10004                      2                           3
# ...                          ...                         ...
# Cust9993                       1                           5
# Cust9994                       2                           3
# Cust9996                       0                           4
# Cust9997                       0                           4
# Cust9999                       2                           5
#
#             InsuredRelationship  VehicleMake  VehicleModel
# CustomerID
# Cust10000                     2            0            12
# Cust10001                     2            0            12
# Cust10002                     3            2             0
# Cust10003                     0            2             0
# Cust10004                     1           10            27
# ...                         ...          ...           ...
# Cust9993                      1           13             3
# Cust9994                      1            7             6
# Cust9996                      0           13            14
# Cust9997                      2           13            35
# Cust9999                      4           13            24
#
# [28836 rows x 36 columns]

# %%
y
# Out:
# CustomerID
# Cust10000    0
# Cust10001    0
# Cust10002    0
# Cust10003    0
# Cust10004    0
#             ..
# Cust9993     0
# Cust9994     0
# Cust9996     0
# Cust9997     0
# Cust9999     0
# Name: ReportedFraud, Length: 28836, dtype: int64

# %%
def StandardScaler(X):
    mean = np.mean(X, axis=0)
    std = np.std(X, axis=0)
    a=((X - mean) / std)
    return a

# %%
StandardScaler(x)
# Out:
#             IncidentTime  NumberOfVehicles  BodilyInjuries  Witnesses  \
# CustomerID
# Cust10000       0.851537          1.200709        0.018118  -1.430435
# Cust10001      -0.282991          1.200709        1.292409  -0.469547
# Cust10002       1.661915         -0.839937        1.292409   1.452228
# Cust10003       1.661915         -0.839937        1.292409   1.452228
# Cust10004      -0.282991         -0.839937        1.292409  -0.469547
# ...                  ...               ...             ...        ...
# Cust9993       -1.417520         -0.839937       -1.256172   1.452228
# Cust9994        0.851537         -0.839937       -1.256172   0.491340
# Cust9996       -1.741671         -0.839937        1.292409  -1.430435
# Cust9997       -1.741671         -0.839937        1.292409  -1.430435
# Cust9999       -0.445067         -0.839937        0.018118   1.452228
#
#             AmountOfTotalClaim  AmountOfInjuryClaim  AmountOfPropertyClaim  \
# CustomerID
# Cust10000             0.525580             1.373190              -0.277179
# Cust10001             0.361482             1.857203              -0.311916
# Cust10002             0.575539             0.969581               0.993227
# Cust10003             0.555141             1.053826               1.078469
# Cust10004             0.049220             0.336953              -0.011397
# ...                        ...                  ...                    ...
# Cust9993             -1.821403            -1.460650              -1.418236
# Cust9994              0.885968             1.662739               0.135092
# Cust9996              0.119377            -0.066429              -0.055046
# Cust9997              0.140293            -0.062815              -0.051390
# Cust9999              0.663744             1.070088              -0.284720
#
#             AmountOfVehicleDamage  InsuredAge  InsuredZipCode  CapitalGains  \
# CustomerID
# Cust10000                0.463147   -0.477146       -0.659665      1.216956
# Cust10001                0.123263   -0.352087       -0.659665      1.719899
# Cust10002                0.323077   -0.727263        1.395487      1.567931
# Cust10003                0.253098   -0.352087       -0.381851      0.898547
# Cust10004               -0.011466   -1.227498       -0.615845     -0.834616
# ...                           ...         ...             ...           ...
# Cust9993                -1.838216    0.898501        1.358131     -0.834616
# Cust9994                 0.794687    0.648384       -0.873812     -0.834616
# Cust9996                 0.196469    1.773913       -0.577367      1.448527
# Cust9997                 0.223893    1.773913       -0.412495      1.604114
# Cust9999                 0.732551   -0.352087       -0.715666      0.844272
#
#             CapitalLoss  InsurancePolicyNumber  CustomerLoyaltyPeriod  \
# CustomerID
# Cust10000     -0.844038              -0.917009              -1.541739
# Cust10001     -0.844038              -0.916919              -0.891292
# Cust10002     -1.388592              -0.916829              -0.360927
# Cust10003     -1.736104              -0.916739              -0.130769
# Cust10004     -0.593256              -0.916649              -0.881285
# ...                 ...                    ...                    ...
# Cust10003               -0.424959          -0.102984              0.399202
# Cust10004               -1.430673          -1.581155              0.240968
# ...                           ...                ...                   ...
# Cust9993                 1.083612          -1.088432             -1.183642
# Cust9994                 1.083612           1.128825             -0.023435
# Cust9996                 1.586469           1.621549             -0.582866
# Cust9997                 0.077898           1.621549             -0.551730
# Cust9999                 1.586469           0.143378             -0.846758
#
#             InsurancePolicyState  Policy_CombinedSingleLimit  \
# CustomerID
# Cust10000               0.049976                   -0.624739
# Cust10001               0.049976                   -0.624739
# Cust10002              -1.179628                    0.664024
# Cust10003               1.279579                    0.664024
# Cust10004               1.279579                   -0.624739
# ...                          ...                         ...
# Cust9993                0.049976                    0.664024
# Cust9994                1.279579                   -0.624739
# Cust9996               -1.179628                    0.019643
# Cust9997               -1.179628                    0.019643
# Cust9999                1.279579                    0.664024
#
#             InsuredRelationship  VehicleMake  VehicleModel
# CustomerID
# Cust10000             -0.302720    -1.629847     -0.558872
# Cust10001             -0.302720    -1.629847     -0.558872
# Cust10002              0.271194    -1.138934     -1.612978
# Cust10003             -1.450546    -1.138934     -1.612978
# Cust10004             -0.876633     0.824717      0.758762
# ...                         ...          ...           ...
# Cust9993              -0.876633     1.561086     -1.349452
# Cust9994              -0.876633     0.088348     -1.085925
# Cust9996              -1.450546     1.561086     -0.383187
# Cust9997              -0.302720     1.561086      1.461499
# Cust9999               0.845107     1.561086      0.495235
#
# [28836 rows x 36 columns]

# %% [markdown]
# # Test preprocessing

# %%
claim_test = pd.read_csv("Test_Claim.csv")
Demog_test=pd.read_csv("Test_Demographics.csv")
policy_test=pd.read_csv("Test_Policy.csv")
vehicle_test=pd.read_csv("Test_Vehicle.csv")
target_test= pd.read_csv("Test.csv")

# %%
claim_test
# Out:
#      CustomerID DateOfIncident            TypeOfIncident TypeOfCollission  \
# 0     Cust10008     2015-02-05   Multi-vehicle Collision  Front Collision
# 1     Cust10010     2015-01-13  Single Vehicle Collision   Rear Collision
# 2     Cust10015     2015-01-05   Multi-vehicle Collision   Rear Collision
# 3     Cust10020     2015-01-03             Vehicle Theft                ?
# 4      Cust1003     2015-02-22   Multi-vehicle Collision   Rear Collision
# ...         ...            ...                       ...              ...
# 8907   Cust9984     2015-01-17  Single Vehicle Collision   Rear Collision
# 8908   Cust9986     2015-02-09  Single Vehicle Collision  Front Collision
# 8909   Cust9990     2015-02-20  Single Vehicle Collision   Rear Collision
# 8910   Cust9995     2015-02-22  Single Vehicle Collision   Side Collision
# 8911   Cust9998     2015-01-14  Single Vehicle Collision  Front Collision
#
#      SeverityOfIncident AuthoritiesContacted IncidentState IncidentCity  \
# 0          Minor Damage            Ambulance        State5        City2
# 1          Minor Damage                 Fire        State9        City5
# 2          Minor Damage               Police        State5        City2
# 3        Trivial Damage                 None        State7        City5
# 4          Minor Damage               Police        State5        City2
# ...                 ...                  ...           ...          ...
# 8907         Total Loss               Police        State5        City4
# 8908         Total Loss                Other        State5        City2
# 8909       Minor Damage                Other        State5        City2
# 8910       Minor Damage               Police        State8        City3
# 8911         Total Loss                Other        State7        City3
#
#      IncidentAddress  IncidentTime  NumberOfVehicles PropertyDamage  \
# 0      Location 1354             4                 3             NO
# 1      Location 1383            16                 1              ?
# 2      Location 2030            20                 3             NO
# 3      Location 1449            10                 1              ?
# 4      Location 1916             7                 3             NO
# ...              ...           ...               ...            ...
# 8907   Location 1958            10                 1            YES
# 8908   Location 1035            19                 1              ?
# 8909   Location 2037             9                 1            YES
# 8910   Location 2097            19                 1            YES
# 8911   Location 1024            10                 1              ?
#
#       BodilyInjuries Witnesses PoliceReport AmountOfTotalClaim  \
# 0                  0         0            ?              68354
# 1                  1         1            ?              55270
# 2                  0         1            ?              59515
# 3                  2         1            ?               4941
# 4                  2         3           NO              34650
# ...              ...       ...          ...                ...
# 8907               1         0           NO              61296
# 8908               1         1          YES              86729
# 8909               1         2           NO              65328
# 8910               0         2          YES              71118
# 8911               2         2            ?              67499
#
#       AmountOfInjuryClaim  AmountOfPropertyClaim  AmountOfVehicleDamage
# 0                    6835                   8059                  53460
# 1                    8113                   5240                  41917
# 2                    7490                   9110                  42915
# 3                     494                    866                   3581
# 4                    7700                   3850                  23100
# ...                   ...                    ...                    ...
# 8907                 5785                   8861                  46650
# 8908                 9698                   9698                  67333
# 8909                12455                   9281                  43592
# 8910                11977                  11604                  47537
# 8911                11681                   5841                  49977
#
# [8912 rows x 19 columns]

# %%
Demog_test
# Out:
#      CustomerID  InsuredAge  InsuredZipCode InsuredGender  \
# 0     Cust10008          27          471704        FEMALE
# 1     Cust10010          40          455810        FEMALE
# 2     Cust10015          39          461919          MALE
# 3     Cust10020          38          600904        FEMALE
# 4      Cust1003          29          430632        FEMALE
# ...         ...         ...             ...           ...
# 8907   Cust9984          28          446435          MALE
# 8908   Cust9986          30          438237        FEMALE
# 8909   Cust9990          44          450339        FEMALE
# 8910   Cust9995          29          439304          MALE
# 8911   Cust9998          38          450730        FEMALE
#
#      InsuredEducationLevel  InsuredOccupation InsuredHobbies  CapitalGains  \
# 0              High School       adm-clerical   base-jumping         56400
# 1                       MD     prof-specialty           golf         56700
# 2                       JD      other-service         movies         30400
# 3                  Masters    exec-managerial    video-games         68500
# 4                      PhD              sales    board-games         35100
# ...                    ...                ...            ...           ...
# 8907             Associate       tech-support        camping             0
# 8908             Associate       craft-repair         movies         39600
# 8909           High School       armed-forces        dancing         25000
# 8910                   PhD   transport-moving         hiking         75800
# 8911                   PhD  handlers-cleaners    video-games         51500
#
#       CapitalLoss Country
# 0          -57000   India
# 1          -65600   India
# 2               0   India
# 3               0   India
# 4               0   India
# ...           ...     ...
# 8907       -53700   India
# 8908       -64300   India
# 8909            0   India
# 8910       -28800   India
# 8911       -74300   India
#
# [8912 rows x 10 columns]

# %%
policy_test
# Out:
#       InsurancePolicyNumber  CustomerLoyaltyPeriod DateOfPolicyCoverage  \
# 0                    110124                    134           2000-09-06
# 1                    110129                    165           1990-02-03
# 2                    110137                    473           1992-10-19
# 3                    110140                    160           2014-12-28
# 4                    110141                    196           1992-08-02
# ...                     ...                    ...                  ...
# 8907                 148598                    155           2000-03-19
# 8908                 148599                    215           1993-07-23
# 8909                 148609                    245           2009-12-11
# 8910                 148610                    437           2011-11-17
# 8911                 148617                    200           1995-12-04
#
#      InsurancePolicyState Policy_CombinedSingleLimit  Policy_Deductible  \
# 0                  State3                    100/300               2000
# 1                  State1                    100/300               1000
# 2                  State2                    100/300               2000
# 3                  State3                   500/1000                500
# 4                  State2                   500/1000               2000
# ...                   ...                        ...                ...
# 8907               State3                    250/500                616
# 8908               State3                    250/500                892
# 8909               State1                   500/1000               1002
# 8910               State1                   500/1000               1902
# 8911               State3                    250/500               1000
#
#       PolicyAnnualPremium  UmbrellaLimit InsuredRelationship CustomerID
# 0                 1413.14        5000000           own-child   Cust1003
# 1                 1137.03              0           unmarried   Cust1008
# 2                 1131.40              0      other-relative   Cust1016
# 3                 1374.22              0      other-relative   Cust1019
# 4                 1475.73              0           own-child   Cust1020
# ...                   ...            ...                 ...        ...
# 8907              1358.80        3462442      other-relative  Cust39477
# 8908              1299.82        4567362      other-relative  Cust39478
# 8909              1361.44           9580                wife  Cust39488
# 8910              1357.36        4510498                wife  Cust39489
# 8911               895.49              0             husband  Cust39496
#
# [8912 rows x 10 columns]

# %%
vehicle_test
# Out:
#       CustomerID VehicleAttribute VehicleAttributeDetails
# 0      Cust28465     VehicleModel                     92x
# 1      Cust20319     VehicleModel                   Jetta
# 2       Cust3683        VehicleID            Vehicle22709
# 3      Cust29385        VehicleID            Vehicle20347
# 4      Cust34403     VehicleModel                   Camry
# ...          ...              ...                     ...
# 35643   Cust1980     VehicleModel                      95
# 35644  Cust17773     VehicleModel               Silverado
# 35645  Cust24313        VehicleID            Vehicle33407
# 35646   Cust5061       VehicleYOM                    2003
# 35647  Cust13782      VehicleMake               Chevrolet
#
# [35648 rows x 3 columns]

# %%
target_test
# Out:
#      CustomerID
# 0     Cust10008
# 1     Cust10010
# 2     Cust10015
# 3     Cust10020
# 4      Cust1003
# ...         ...
# 8907  Cust37942
# 8908  Cust20528
# 8909  Cust36797
# 8910  Cust28499
# 8911  Cust21356
#
# [8912 rows x 1 columns]

# %%
vehicle_test = vehicle_test.pivot(index='CustomerID', columns='VehicleAttribute', values='VehicleAttributeDetails').reset_index()
vehicle_test.columns.name = None  # To remove the "VehicleAttribute" label from the top row
vehicle_test
# Out:
#      CustomerID     VehicleID VehicleMake    VehicleModel VehicleYOM
# 0     Cust10008  Vehicle34362  Volkswagen          Passat       1995
# 1     Cust10010  Vehicle17046      Nissan          Ultima       2006
# 2     Cust10015  Vehicle11038      Suburu         Impreza       2010
# 3     Cust10020  Vehicle37114      Accura              TL       2009
# 4      Cust1003  Vehicle16771       Dodge             RAM       2007
# ...         ...           ...         ...             ...        ...
# 8907   Cust9984  Vehicle19062        Saab              95       2000
# 8908   Cust9986  Vehicle18191        Saab             92x       2000
# 8909   Cust9990  Vehicle11032         BMW           Civic       1998
# 8910   Cust9995  Vehicle30412        Jeep  Grand Cherokee       2002
# 8911   Cust9998   Vehicle2349      Suburu            E400       2007
#
# [8912 rows x 5 columns]

# %%
claim_Demog_test = pd.merge(claim_test, Demog_test, how='left', on=['CustomerID'])
claim_Demog_test
# Out:
#      CustomerID DateOfIncident            TypeOfIncident TypeOfCollission  \
# 0     Cust10008     2015-02-05   Multi-vehicle Collision  Front Collision
# 1     Cust10010     2015-01-13  Single Vehicle Collision   Rear Collision
# 2     Cust10015     2015-01-05   Multi-vehicle Collision   Rear Collision
# 3     Cust10020     2015-01-03             Vehicle Theft                ?
# 4      Cust1003     2015-02-22   Multi-vehicle Collision   Rear Collision
# ...         ...            ...                       ...              ...
# 8907   Cust9984     2015-01-17  Single Vehicle Collision   Rear Collision
# 8908   Cust9986     2015-02-09  Single Vehicle Collision  Front Collision
# 8909   Cust9990     2015-02-20  Single Vehicle Collision   Rear Collision
# 8910   Cust9995     2015-02-22  Single Vehicle Collision   Side Collision
# 8911   Cust9998     2015-01-14  Single Vehicle Collision  Front Collision
#
#      SeverityOfIncident AuthoritiesContacted IncidentState IncidentCity  \
# 0          Minor Damage            Ambulance        State5        City2
# 1          Minor Damage                 Fire        State9        City5
# 2          Minor Damage               Police        State5        City2
# 3        Trivial Damage                 None        State7        City5
# 4          Minor Damage               Police        State5        City2
# ...                 ...                  ...           ...          ...
# 8907         Total Loss               Police        State5        City4
# 8908         Total Loss                Other        State5        City2
# 8909       Minor Damage                Other        State5        City2
# 8910       Minor Damage               Police        State8        City3
# 8911         Total Loss                Other        State7        City3
#
#      IncidentAddress  IncidentTime  NumberOfVehicles PropertyDamage  \
# 0      Location 1354             4                 3             NO
# 1      Location 1383            16                 1              ?
# 2      Location 2030            20                 3             NO
# 3      Location 1449            10                 1              ?
# 4      Location 1916             7                 3             NO
# ...              ...           ...               ...            ...
# 8907   Location 1958            10                 1            YES
# 8908   Location 1035            19                 1              ?
# 8909   Location 2037             9                 1            YES
# 8910   Location 2097            19                 1            YES
# 8911   Location 1024            10                 1              ?
#
#       BodilyInjuries Witnesses PoliceReport AmountOfTotalClaim  \
# 0                  0         0            ?              68354
# 1                  1         1            ?              55270
# 2                  0         1            ?              59515
# 3                  2         1            ?               4941
# 4                  2         3           NO              34650
# ...              ...       ...          ...                ...
# 8907               1         0           NO              61296
# 8908               1         1          YES              86729
# 8909               1         2           NO              65328
# 8910               0         2          YES              71118
# 8911               2         2            ?              67499
#
#       AmountOfInjuryClaim  AmountOfPropertyClaim  AmountOfVehicleDamage  \
# 0                    6835                   8059                  53460
# 1                    8113                   5240                  41917
# 2                    7490                   9110                  42915
# 3                     494                    866                   3581
# 4                    7700                   3850                  23100
# ...                   ...                    ...                    ...
# 8907                 5785                   8861                  46650
# 8908                 9698                   9698                  67333
# 8909                12455                   9281                  43592
# 8910                11977                  11604                  47537
# 8911                11681                   5841                  49977
#
#       InsuredAge  InsuredZipCode InsuredGender InsuredEducationLevel  \
# 0             27          471704        FEMALE           High School
# 1             40          455810        FEMALE                    MD
# 2             39          461919          MALE                    JD
# 3             38          600904        FEMALE               Masters
# 4             29          430632        FEMALE                   PhD
# ...          ...             ...           ...                   ...
# 8907          28          446435          MALE             Associate
# 8908          30          438237        FEMALE             Associate
# 8909          44          450339        FEMALE           High School
# 8910          29          439304          MALE                   PhD
# 8911          38          450730        FEMALE                   PhD
#
#       InsuredOccupation InsuredHobbies  CapitalGains  CapitalLoss Country
# 0          adm-clerical   base-jumping         56400       -57000   India
# 1        prof-specialty           golf         56700       -65600   India
# 2         other-service         movies         30400            0   India
# 3       exec-managerial    video-games         68500            0   India
# 4                 sales    board-games         35100            0   India
# ...                 ...            ...           ...          ...     ...
# 8907       tech-support        camping             0       -53700   India
# 8908       craft-repair         movies         39600       -64300   India
# 8909       armed-forces        dancing         25000            0   India
# 8910   transport-moving         hiking         75800       -28800   India
# 8911  handlers-cleaners    video-games         51500       -74300   India
#
# [8912 rows x 28 columns]

# %%
claim_Demog_policy_test = pd.merge(claim_Demog_test, policy_test, how='left', on=['CustomerID'])
claim_Demog_policy_test
# Out:
#      CustomerID DateOfIncident            TypeOfIncident TypeOfCollission  \
# 0     Cust10008     2015-02-05   Multi-vehicle Collision  Front Collision
# 1     Cust10010     2015-01-13  Single Vehicle Collision   Rear Collision
# 2     Cust10015     2015-01-05   Multi-vehicle Collision   Rear Collision
# 3     Cust10020     2015-01-03             Vehicle Theft                ?
# 4      Cust1003     2015-02-22   Multi-vehicle Collision   Rear Collision
# ...         ...            ...                       ...              ...
# 8907   Cust9984     2015-01-17  Single Vehicle Collision   Rear Collision
# 8908   Cust9986     2015-02-09  Single Vehicle Collision  Front Collision
# 8909   Cust9990     2015-02-20  Single Vehicle Collision   Rear Collision
# 8910   Cust9995     2015-02-22  Single Vehicle Collision   Side Collision
# 8911   Cust9998     2015-01-14  Single Vehicle Collision  Front Collision
#
#      SeverityOfIncident AuthoritiesContacted IncidentState IncidentCity  \
# 0          Minor Damage            Ambulance        State5        City2
# 1          Minor Damage                 Fire        State9        City5
# 2          Minor Damage               Police        State5        City2
# 3        Trivial Damage                 None        State7        City5
# 4          Minor Damage               Police        State5        City2
# ...                 ...                  ...           ...          ...
# 8907         Total Loss               Police        State5        City4
# 8908         Total Loss                Other        State5        City2
# 8909       Minor Damage                Other        State5        City2
# 8910       Minor Damage               Police        State8        City3
# 8911         Total Loss                Other        State7        City3
#
#      IncidentAddress  IncidentTime  NumberOfVehicles PropertyDamage  \
# 0      Location 1354             4                 3             NO
# 1      Location 1383            16                 1              ?
# 2      Location 2030            20                 3             NO
# 3      Location 1449            10                 1              ?
# 4      Location 1916             7                 3             NO
# ...              ...           ...               ...            ...
# 8907   Location 1958            10                 1            YES
# 8908   Location 1035            19                 1              ?
# 8909   Location 2037             9                 1            YES
# 8910   Location 2097            19                 1            YES
# 8911   Location 1024            10                 1              ?
#
#       BodilyInjuries Witnesses PoliceReport AmountOfTotalClaim  \
# 0                  0         0            ?              68354
# 1                  1         1            ?              55270
# 2                  0         1            ?              59515
# 3                  2         1            ?               4941
# 4                  2         3           NO              34650
# ...              ...       ...          ...                ...
# 8907               1         0           NO              61296
# 8908               1         1          YES              86729
# 8909               1         2           NO              65328
# 8910               0         2          YES              71118
# 8911               2         2            ?              67499
#
#       AmountOfInjuryClaim  AmountOfPropertyClaim  AmountOfVehicleDamage  \
# 0                    6835                   8059                  53460
# 1                    8113                   5240                  41917
# 2                    7490                   9110                  42915
# 3                     494                    866                   3581
# 4                    7700                   3850                  23100
# ...                   ...                    ...                    ...
# 8907                 5785                   8861                  46650
# 8908                 9698                   9698                  67333
# 8909                12455                   9281                  43592
# 8910                11977                  11604                  47537
# 8911                11681                   5841                  49977
#
#       InsuredAge  InsuredZipCode InsuredGender InsuredEducationLevel  \
# 0             27          471704        FEMALE           High School
# 1             40          455810        FEMALE                    MD
# 2             39          461919          MALE                    JD
# 3             38          600904        FEMALE               Masters
# 4             29          430632        FEMALE                   PhD
# ...          ...             ...           ...                   ...
# 8907          28          446435          MALE             Associate
# 8908          30          438237        FEMALE             Associate
# 8909          44          450339        FEMALE           High School
# 8910          29          439304          MALE                   PhD
# 8911          38          450730        FEMALE                   PhD
#
#       InsuredOccupation InsuredHobbies  CapitalGains  CapitalLoss Country  \
# 0          adm-clerical   base-jumping         56400       -57000   India
# 1        prof-specialty           golf         56700       -65600   India
# 2         other-service         movies         30400            0   India
# 3       exec-managerial    video-games         68500            0   India
# 4                 sales    board-games         35100            0   India
# ...                 ...            ...           ...          ...     ...
# 8907       tech-support        camping             0       -53700   India
# 8908       craft-repair         movies         39600       -64300   India
# 8909       armed-forces        dancing         25000            0   India
# 8910   transport-moving         hiking         75800       -28800   India
# 8911  handlers-cleaners    video-games         51500       -74300   India
#
#       InsurancePolicyNumber  CustomerLoyaltyPeriod DateOfPolicyCoverage  \
# 0                    119129                     84           1998-05-10
# 1                    119131                    232           2011-11-10
# 2                    119136                    218           2010-07-17
# 3                    119141                    205           2000-09-10
# 4                    110124                    134           2000-09-06
# ...                     ...                    ...                  ...
# 8907                 119105                     94           1997-10-23
# 8908                 119107                    115           2001-08-16
# 8909                 119111                    297           2003-04-14
# 8910                 119116                     94           1992-08-21
# 8911                 119119                    208           2002-03-13
#
#      InsurancePolicyState Policy_CombinedSingleLimit  Policy_Deductible  \
# 0                  State2                   500/1000               2000
# 1                  State3                    100/300                500
# 2                  State2                    250/500               1000
# 3                  State3                    500/500               2000
# 4                  State3                    100/300               2000
# ...                   ...                        ...                ...
# 8907               State3                   500/1000                673
# 8908               State2                    250/500                574
# 8909               State2                    100/300               1216
# 8910               State2                    100/300               1950
# 8911               State2                   500/1000               2000
#
#       PolicyAnnualPremium  UmbrellaLimit InsuredRelationship
# 0                 1006.00              0           own-child
# 1                 1279.17              0           unmarried
# 2                 1454.67        1235986      other-relative
# 3                 1287.76        5873212                wife
# 4                 1413.14        5000000           own-child
# ...                   ...            ...                 ...
# 8907              1104.02        1959277                wife
# 8908               961.46              0             husband
# 8909              1560.49              0                wife
# 8910              1577.48              0                wife
# 8911               928.75        3701890             husband
#
# [8912 rows x 37 columns]

# %%
Fraud_detect_test = pd.merge(claim_Demog_policy_test, vehicle_test, how='left', on=['CustomerID'])
Fraud_detect_test
# Out:
#      CustomerID DateOfIncident            TypeOfIncident TypeOfCollission  \
# 0     Cust10008     2015-02-05   Multi-vehicle Collision  Front Collision
# 1     Cust10010     2015-01-13  Single Vehicle Collision   Rear Collision
# 2     Cust10015     2015-01-05   Multi-vehicle Collision   Rear Collision
# 3     Cust10020     2015-01-03             Vehicle Theft                ?
# 4      Cust1003     2015-02-22   Multi-vehicle Collision   Rear Collision
# ...         ...            ...                       ...              ...
# 8907   Cust9984     2015-01-17  Single Vehicle Collision   Rear Collision
# 8908   Cust9986     2015-02-09  Single Vehicle Collision  Front Collision
# 8909   Cust9990     2015-02-20  Single Vehicle Collision   Rear Collision
# 8910   Cust9995     2015-02-22  Single Vehicle Collision   Side Collision
# 8911   Cust9998     2015-01-14  Single Vehicle Collision  Front Collision
#
#      SeverityOfIncident AuthoritiesContacted IncidentState IncidentCity  \
# 0          Minor Damage            Ambulance        State5        City2
# 1          Minor Damage                 Fire        State9        City5
# 2          Minor Damage               Police        State5        City2
# 3        Trivial Damage                 None        State7        City5
# 4          Minor Damage               Police        State5        City2
# ...                 ...                  ...           ...          ...
# 8907         Total Loss               Police        State5        City4
# 8908         Total Loss                Other        State5        City2
# 8909       Minor Damage                Other        State5        City2
# 8910       Minor Damage               Police        State8        City3
# 8911         Total Loss                Other        State7        City3
#
#      IncidentAddress  IncidentTime  NumberOfVehicles PropertyDamage  \
# 0      Location 1354             4                 3             NO
# 1      Location 1383            16                 1              ?
# 2      Location 2030            20                 3             NO
# 3      Location 1449            10                 1              ?
# 4      Location 1916             7                 3             NO
# ...              ...           ...               ...            ...
# 8907   Location 1958            10                 1            YES
# 8908   Location 1035            19                 1              ?
# 8909   Location 2037             9                 1            YES
# 8910   Location 2097            19                 1            YES
# 8911   Location 1024            10                 1              ?
#
#       BodilyInjuries Witnesses PoliceReport AmountOfTotalClaim  \
# 0                  0         0            ?              68354
# 1                  1         1            ?              55270
# 2                  0         1            ?              59515
# 3                  2         1            ?               4941
# 4                  2         3           NO              34650
# ...              ...       ...          ...                ...
# 8907               1         0           NO              61296
# 8908               1         1          YES              86729
# 8909               1         2           NO              65328
# 8910               0         2          YES              71118
# 8911               2         2            ?              67499
#
#       AmountOfInjuryClaim  AmountOfPropertyClaim  AmountOfVehicleDamage  \
# 0                    6835                   8059                  53460
# 1                    8113                   5240                  41917
# 2                    7490                   9110                  42915
# 3                     494                    866                   3581
# 4                    7700                   3850                  23100
# ...                   ...                    ...                    ...
# 8907                 5785                   8861                  46650
# 8908                 9698                   9698                  67333
# 8909                12455                   9281                  43592
# 8910                11977                  11604                  47537
# 8911                11681                   5841                  49977
#
#       InsuredAge  InsuredZipCode InsuredGender InsuredEducationLevel  \
# 0             27          471704        FEMALE           High School
# 1             40          455810        FEMALE                    MD
# 2             39          461919          MALE                    JD
# 3             38          600904        FEMALE               Masters
# 4             29          430632        FEMALE                   PhD
# ...          ...             ...           ...                   ...
# 8907          28          446435          MALE             Associate
# 8908          30          438237        FEMALE             Associate
# 8909          44          450339        FEMALE           High School
# 8910          29          439304          MALE                   PhD
# 8911          38          450730        FEMALE                   PhD
#
#       InsuredOccupation InsuredHobbies  CapitalGains  CapitalLoss Country  \
# 0          adm-clerical   base-jumping         56400       -57000   India
# 1        prof-specialty           golf         56700       -65600   India
# 2         other-service         movies         30400            0   India
# 3       exec-managerial    video-games         68500            0   India
# 4                 sales    board-games         35100            0   India
# ...                 ...            ...           ...          ...     ...
# 8907       tech-support        camping             0       -53700   India
# 8908       craft-repair         movies         39600       -64300   India
# 8909       armed-forces        dancing         25000            0   India
# 8910   transport-moving         hiking         75800       -28800   India
# 8911  handlers-cleaners    video-games         51500       -74300   India
#
#       InsurancePolicyNumber  CustomerLoyaltyPeriod DateOfPolicyCoverage  \
# 0                    119129                     84           1998-05-10
# 1                    119131                    232           2011-11-10
# 2                    119136                    218           2010-07-17
# 3                    119141                    205           2000-09-10
# 4                    110124                    134           2000-09-06
# ...                     ...                    ...                  ...
# 8907                 119105                     94           1997-10-23
# 8908                 119107                    115           2001-08-16
# 8909                 119111                    297           2003-04-14
# 8910                 119116                     94           1992-08-21
# 8911                 119119                    208           2002-03-13
#
#      InsurancePolicyState Policy_CombinedSingleLimit  Policy_Deductible  \
# 0                  State2                   500/1000               2000
# 1                  State3                    100/300                500
# 2                  State2                    250/500               1000
# 3                  State3                    500/500               2000
# 4                  State3                    100/300               2000
# ...                   ...                        ...                ...
# 8907               State3                   500/1000                673
# 8908               State2                    250/500                574
# 8909               State2                    100/300               1216
# 8910               State2                    100/300               1950
# 8911               State2                   500/1000               2000
#
#       PolicyAnnualPremium  UmbrellaLimit InsuredRelationship     VehicleID  \
# 0                 1006.00              0           own-child  Vehicle34362
# 1                 1279.17              0           unmarried  Vehicle17046
# 2                 1454.67        1235986      other-relative  Vehicle11038
# 3                 1287.76        5873212                wife  Vehicle37114
# 4                 1413.14        5000000           own-child  Vehicle16771
# ...                   ...            ...                 ...           ...
# 8907              1104.02        1959277                wife  Vehicle19062
# 8908               961.46              0             husband  Vehicle18191
# 8909              1560.49              0                wife  Vehicle11032
# 8910              1577.48              0                wife  Vehicle30412
# 8911               928.75        3701890             husband   Vehicle2349
#
#      VehicleMake    VehicleModel VehicleYOM
# 0     Volkswagen          Passat       1995
# 1         Nissan          Ultima       2006
# 2         Suburu         Impreza       2010
# 3         Accura              TL       2009
# 4          Dodge             RAM       2007
# ...          ...             ...        ...
# 8907        Saab              95       2000
# 8908        Saab             92x       2000
# 8909         BMW           Civic       1998
# 8910        Jeep  Grand Cherokee       2002
# 8911      Suburu            E400       2007
#
# [8912 rows x 41 columns]

# %%
target_test
# Out:
#      CustomerID
# 0     Cust10008
# 1     Cust10010
# 2     Cust10015
# 3     Cust10020
# 4      Cust1003
# ...         ...
# 8907  Cust37942
# 8908  Cust20528
# 8909  Cust36797
# 8910  Cust28499
# 8911  Cust21356
#
# [8912 rows x 1 columns]

# %%
Fraud_detect_test.isnull().sum()
# Out:
# CustomerID                    0
# DateOfIncident                0
# TypeOfIncident                0
# TypeOfCollission              0
# SeverityOfIncident            0
# AuthoritiesContacted          0
# IncidentState                 0
# IncidentCity                  0
# IncidentAddress               0
# IncidentTime                  0
# NumberOfVehicles              0
# PropertyDamage                0
# BodilyInjuries                0
# Witnesses                     0
# PoliceReport                  0
# AmountOfTotalClaim            0
# AmountOfInjuryClaim           0
# AmountOfPropertyClaim         0
# AmountOfVehicleDamage         0
# InsuredAge                    0
# InsuredZipCode                0
# InsuredGender                 8
# InsuredEducationLevel         0
# InsuredOccupation             0
# InsuredHobbies                0
# CapitalGains                  0
# CapitalLoss                   0
# Country                       4
# InsurancePolicyNumber         0
# CustomerLoyaltyPeriod         0
# DateOfPolicyCoverage          0
# InsurancePolicyState          0
# Policy_CombinedSingleLimit    0
# Policy_Deductible             0
# PolicyAnnualPremium           0
# UmbrellaLimit                 0
# InsuredRelationship           0
# VehicleID                     0
# VehicleMake                   0
# VehicleModel                  0
# VehicleYOM                    0
# dtype: int64

# %%
for i in Fraud_detect_test.columns:
    print(i,Fraud_detect_test[i].unique())
# Out:
# CustomerID ['Cust10008' 'Cust10010' 'Cust10015' ... 'Cust9990' 'Cust9995' 'Cust9998']
# DateOfIncident ['2015-02-05' '2015-01-13' '2015-01-05' '2015-01-03' '2015-02-22'
#  '2015-02-06' '2015-01-18' '2015-01-24' '2015-02-26' '2015-01-09'
#  '2015-02-03' '2015-02-23' '2015-01-10' '2015-01-12' '2015-01-16'
#  '2015-02-08' '2015-01-07' '2015-02-12' '2015-02-09' '2015-02-27'
#  '2015-02-13' '2015-01-06' '2015-01-08' '2015-01-17' '2015-01-15'
#  '2015-02-10' '2015-01-11' '2015-02-20' '2015-02-18' '2015-02-17'
#  '2015-01-22' '2015-01-28' '2015-01-29' '2015-02-24' '2015-01-19'
#  '2015-02-04' '2015-01-01' '2015-01-21' '2015-01-20' '2015-02-15'
#  '2015-02-14' '2015-02-25' '2015-01-27' '2015-01-25' '2015-02-28'
#  '2015-01-14' '2015-01-30' '2015-02-19' '2015-02-21' '2015-02-07'
#  '2015-02-02' '2015-01-23' '2015-01-02' '2015-03-03' '2015-03-04'
#  '2015-01-04' '2015-01-31' '2015-03-01' '2015-02-11' '2015-01-26'
#  '2015-02-16' '2015-03-02' '2015-02-01' '2015-03-07' '2015-03-09'
#  '2015-03-05' '2015-03-06']
# TypeOfIncident ['Multi-vehicle Collision' 'Single Vehicle Collision' 'Vehicle Theft'
#  'Parked Car']
# TypeOfCollission ['Front Collision' 'Rear Collision' '?' 'Side Collision']
# SeverityOfIncident ['Minor Damage' 'Trivial Damage' 'Major Damage' 'Total Loss']
# AuthoritiesContacted ['Ambulance' 'Fire' 'Police' 'None' 'Other']
# IncidentState ['State5' 'State9' 'State7' 'State8' 'State3' 'State4' 'State6']
# IncidentCity ['City2' 'City5' 'City4' 'City1' 'City3' 'City7' 'City6']
# IncidentAddress ['Location 1354' 'Location 1383' 'Location 2030' 'Location 1449'
#  'Location 1916' 'Location 1359' 'Location 1781' 'Location 1158'
#  'Location 1629' 'Location 1911' 'Location 1339' 'Location 1469'
#  164 107 395  32 363 283 295 339 279 350 234 135 179  87 385 192 195 219
#  398 453 176 390 411 333 364 123 284  51 251 407  64 277 290 106 146 174
#   49 402 301 418 299  35 309 347 282 125 249 268 104 345 193  54  72 184
#   55 431 212 188 461  34 274  75 331 351  59 252  77 355 356 172  66 108
#   24 412  60  47 203  69 464 293  46  70 120 419 360 423  36 292 414 338
#  117 173 264 105  61 359 142 285 328 181  92 237 330 154 159 263 410 401
#  332 323   8 213  41 340  79 265 217 300 425 297 377 235 372  17 358  67
#  151 183 202 413  20 148 298 369 310  95  82 122 319 448 207 334 220 197
#  115 225  44 267  80  40  62 307 406 109 229  28 380   3 311 342  53 469
#  394 275 422  15  68 189 239 421 261 400  19 257  11 136 449 158  23  88
#  315 386  50 381 126 439  48 409 474 430 455 434  56  57  26   4  97 317
#  451 460 478 470 312 260 379 354 438 432   0 314  12  86   9 472  83  31
#   27 405 424  14  38 463 452 352  42 341 374 456 329 344 426 388 343 446
#  357 373 171  30  25 100 393 111 440 436 326 476 444 370  45 288 382  10
#  450 443 445 465  21 389 335 457 475 403 427 454 437 408 399 416 384  33
#  348 316 305 337 392 376 420 435 441 391 365 366 417   5   2   6 362 471
#   18 468 387 429   1 442 462 428]
# DateOfPolicyCoverage ['1998-05-10' '2011-11-10' '2010-07-17' ... '1993-09-12' '1995-11-03'
#  '2002-03-13']
# InsurancePolicyState ['State2' 'State3' 'State1']
# Policy_CombinedSingleLimit ['500/1000' '100/300' '250/500' '500/500' '100/1000' '100/500' '250/300'
#  '500/300' '250/1000']
# Policy_Deductible [2000  500 1000 ... 1008  869 1094]
# PolicyAnnualPremium [1006.   1279.17 1454.67 ... 1560.49 1577.48  928.75]
# UmbrellaLimit [      0 1235986 5873212 ... 3576899 1959277 3701890]
# InsuredRelationship ['own-child' 'unmarried' 'other-relative' 'wife' 'not-in-family' 'husband']
# VehicleID ['Vehicle34362' 'Vehicle17046' 'Vehicle11038' ... 'Vehicle11032'
#  'Vehicle30412' 'Vehicle2349']
# VehicleMake ['Volkswagen' 'Nissan' 'Suburu' 'Accura' 'Dodge' 'Toyota' 'Ford' 'Audi'
#  'Saab' 'Jeep' 'Chevrolet' 'BMW' 'Honda' 'Mercedes' '???']
# VehicleModel ['Passat' 'Ultima' 'Impreza' 'TL' 'RAM' 'Forrestor' 'Neon' 'Corolla'
#  'Malibu' 'Escape' 'E400' 'A3' 'Legacy' '95' 'MDX' 'Fusion'
#  'Grand Cherokee' 'Wrangler' 'A5' '92x' 'F150' 'Maxima' 'C300' 'Tahoe'
#  'Pathfinder' 'Highlander' 'Jetta' 'Silverado' 'Civic' 'ML350' 'Camry'
#  'CRV' 'X5' '93' 'M5' 'Accord' 'X6' '3 Series']
# VehicleYOM ['1995' '2006' '2010' '2009' '2007' '2012' '2014' '2008' '2000' '2013'
#  '2002' '2015' '2005' '1998' '2004' '2001' '1997' '2003' '2011' '1999'
#  '1996']

# %%
Fraud_detect_test['TypeOfCollission']=Fraud_detect_test['TypeOfCollission'].replace('?',np.nan)
Fraud_detect_test['PropertyDamage']=Fraud_detect_test['PropertyDamage'].replace('?',np.nan)
Fraud_detect_test['PoliceReport']=Fraud_detect_test['PoliceReport'].replace('?',np.nan)
Fraud_detect_test['VehicleMake']=Fraud_detect_test['VehicleMake'].replace('???',np.nan)
Fraud_detect_test['Witnesses']=Fraud_detect_test['Witnesses'].replace('MISSINGVALUE',np.nan)

# %%
Fraud_detect_test['TypeOfCollission'].unique()
# Out:
# array(['Front Collision', 'Rear Collision', nan, 'Side Collision'],
#       dtype=object)

# %%
Fraud_detect_test.isna().sum()
# Out:
# CustomerID                       0
# DateOfIncident                   0
# TypeOfIncident                   0
# TypeOfCollission              1763
# SeverityOfIncident               0
# AuthoritiesContacted             0
# IncidentState                    0
# IncidentCity                     0
# IncidentAddress                  0
# IncidentTime                     0
# NumberOfVehicles                 0
# PropertyDamage                3199
# BodilyInjuries                   0
# Witnesses                       12
# PoliceReport                  3014
# AmountOfTotalClaim               0
# AmountOfInjuryClaim              0
# AmountOfPropertyClaim            0
# AmountOfVehicleDamage            0
# InsuredAge                       0
# InsuredZipCode                   0
# InsuredGender                    8
# InsuredEducationLevel            0
# InsuredOccupation                0
# InsuredHobbies                   0
# CapitalGains                     0
# CapitalLoss                      0
# Country                          4
# InsurancePolicyNumber            0
# CustomerLoyaltyPeriod            0
# DateOfPolicyCoverage             0
# InsurancePolicyState             0
# Policy_CombinedSingleLimit       0
# Policy_Deductible                0
# PolicyAnnualPremium              0
# UmbrellaLimit                    0
# InsuredRelationship              0
# VehicleID                        0
# VehicleMake                      8
# VehicleModel                     0
# VehicleYOM                       0
# dtype: int64

# %%
Fraud_detect_test.isna().mean().sort_values()
# Out:
# CustomerID                    0.000000
# InsuredEducationLevel         0.000000
# InsuredOccupation             0.000000
# InsuredHobbies                0.000000
# CapitalGains                  0.000000
# CapitalLoss                   0.000000
# InsurancePolicyNumber         0.000000
# CustomerLoyaltyPeriod         0.000000
# DateOfPolicyCoverage          0.000000
# InsurancePolicyState          0.000000
# Policy_CombinedSingleLimit    0.000000
# Policy_Deductible             0.000000
# PolicyAnnualPremium           0.000000
# UmbrellaLimit                 0.000000
# InsuredRelationship           0.000000
# VehicleID                     0.000000
# VehicleModel                  0.000000
# InsuredAge                    0.000000
# InsuredZipCode                0.000000
# AmountOfPropertyClaim         0.000000
# DateOfIncident                0.000000
# TypeOfIncident                0.000000
# SeverityOfIncident            0.000000
# AuthoritiesContacted          0.000000
# IncidentState                 0.000000
# IncidentCity                  0.000000
# IncidentAddress               0.000000
# AmountOfVehicleDamage         0.000000
# IncidentTime                  0.000000
# BodilyInjuries                0.000000
# AmountOfTotalClaim            0.000000
# AmountOfInjuryClaim           0.000000
# NumberOfVehicles              0.000000
# VehicleYOM                    0.000000
# Country                       0.000449
# InsuredGender                 0.000898
# VehicleMake                   0.000898
# Witnesses                     0.001346
# TypeOfCollission              0.197823
# PoliceReport                  0.338196
# PropertyDamage                0.358954
# dtype: float64

# %%
Fraud_detect_test.dtypes
# Out:
# CustomerID                     object
# DateOfIncident                 object
# TypeOfIncident                 object
# TypeOfCollission               object
# SeverityOfIncident             object
# AuthoritiesContacted           object
# IncidentState                  object
# IncidentCity                   object
# IncidentAddress                object
# IncidentTime                    int64
# NumberOfVehicles                int64
# PropertyDamage                 object
# BodilyInjuries                  int64
# Witnesses                      object
# PoliceReport                   object
# AmountOfTotalClaim             object
# AmountOfInjuryClaim             int64
# AmountOfPropertyClaim           int64
# AmountOfVehicleDamage           int64
# InsuredAge                      int64
# InsuredZipCode                  int64
# InsuredGender                  object
# InsuredEducationLevel          object
# InsuredOccupation              object
# InsuredHobbies                 object
# CapitalGains                    int64
# CapitalLoss                     int64
# Country                        object
# InsurancePolicyNumber           int64
# CustomerLoyaltyPeriod           int64
# DateOfPolicyCoverage           object
# InsurancePolicyState           object
# Policy_CombinedSingleLimit     object
# Policy_Deductible               int64
# PolicyAnnualPremium           float64
# UmbrellaLimit                   int64
# InsuredRelationship            object
# VehicleID                      object
# VehicleMake                    object
# VehicleModel                   object
# VehicleYOM                     object
# dtype: object

# %%
Fraud_detect_test['TypeOfCollission']=Fraud_detect_test['TypeOfCollission'].fillna(method="ffill")
Fraud_detect_test['PropertyDamage']=Fraud_detect_test['PropertyDamage'].fillna(method="bfill")
Fraud_detect_test['InsuredGender']=Fraud_detect_test['InsuredGender'].fillna(method="ffill")
Fraud_detect_test['PoliceReport']=Fraud_detect_test['PoliceReport'].fillna(method="bfill")
Fraud_detect_test['VehicleMake']=Fraud_detect_test['VehicleMake'].fillna(method="ffill")
Fraud_detect_test['Witnesses']=Fraud_detect_test['Witnesses'].fillna(method="ffill")
Fraud_detect_test['Country']=Fraud_detect_test['Country'].fillna(method="ffill")

# %%
Fraud_detect_test['PropertyDamage'].nunique()
# Out:
# 2

# %%
Fraud_detect_test['PropertyDamage'].unique()
# Out:
# array(['NO', 'YES', nan], dtype=object)

# %%
Fraud_detect_test.isna().sum()
# Out:
# CustomerID                    0
# DateOfIncident                0
# TypeOfIncident                0
# TypeOfCollission              0
# SeverityOfIncident            0
# AuthoritiesContacted          0
# IncidentState                 0
# IncidentCity                  0
# IncidentAddress               0
# IncidentTime                  0
# NumberOfVehicles              0
# PropertyDamage                1
# BodilyInjuries                0
# Witnesses                     0
# PoliceReport                  1
# AmountOfTotalClaim            0
# AmountOfInjuryClaim           0
# AmountOfPropertyClaim         0
# AmountOfVehicleDamage         0
# InsuredAge                    0
# InsuredZipCode                0
# InsuredGender                 0
# InsuredEducationLevel         0
# InsuredOccupation             0
# InsuredHobbies                0
# CapitalGains                  0
# CapitalLoss                   0
# Country                       0
# InsurancePolicyNumber         0
# CustomerLoyaltyPeriod         0
# DateOfPolicyCoverage          0
# InsurancePolicyState          0
# Policy_CombinedSingleLimit    0
# Policy_Deductible             0
# PolicyAnnualPremium           0
# UmbrellaLimit                 0
# InsuredRelationship           0
# VehicleID                     0
# VehicleMake                   0
# VehicleModel                  0
# VehicleYOM                    0
# dtype: int64

# %%
Fraud_detect_test.drop(Fraud_detect_test[['DateOfIncident','VehicleID' ,'InsuredHobbies','Country']], axis=1, inplace=True)

# %%
Fraud_detect_test['Witnesses'] = pd.to_numeric(Fraud_detect_test['Witnesses'], errors='coerce')
Fraud_detect_test['AmountOfTotalClaim'] = pd.to_numeric(Fraud_detect_test['AmountOfTotalClaim'], errors='coerce')
Fraud_detect_test['VehicleYOM'] = pd.to_numeric(Fraud_detect_test['VehicleYOM'], errors='coerce')

# %%
pd.set_option('display.max_columns', None)
obj_test=Fraud_detect_test.select_dtypes(include ='object')
obj_test.drop(obj_test[['CustomerID']], axis=1, inplace=True)

# %%
class LabelEncoder:
    def __init__(self):
        self.labels = {}

    def fit_transform(self, y):
        unique_labels = set(y)
        for i, label in enumerate(unique_labels):
            self.labels[label] = i

        encoded_labels = []
        for label in y:
            encoded_labels.append(self.labels[label])

        return encoded_labels

    def inverse_transform(self, y):
        inv_labels = {v: k for k, v in self.labels.items()}

        decoded_labels = []
        for label in y:
            decoded_labels.append(inv_labels[label])

        return decoded_labels

# %%
encoded_test={}
for i in obj_test.columns:
    le = LabelEncoder()
    encoded_data_test = le.fit_transform(obj_test[i])
    encoded_test[i]=encoded_data_test
encoded_test
df_test=pd.DataFrame(encoded_test)
pd.set_option('display.max_columns', None)
df_test
# Out:
#       TypeOfIncident  TypeOfCollission  SeverityOfIncident  \
# 0                  3                 1                   2
# 1                  1                 2                   2
# 2                  3                 2                   2
# 3                  2                 2                   3
# 4                  3                 2                   2
# ...              ...               ...                 ...
# 8907               1                 2                   1
# 8908               1                 1                   1
# 8909               1                 2                   2
# 8910               1                 0                   2
# 8911               1                 1                   1
#
#       AuthoritiesContacted  IncidentState  IncidentCity  IncidentAddress  \
# 0                        2              4             0              258
# 1                        3              1             5              152
# 2                        4              4             0              639
# 3                        0              3             5              640
# 4                        4              4             0              385
# ...                    ...            ...           ...              ...
# 8907                     4              4             3              894
# 8908                     1              4             0              186
# 8909                     1              4             0              171
# 8910                     4              2             2              289
# 8911                     1              3             2              790
#
#       PropertyDamage  PoliceReport  InsuredGender  InsuredEducationLevel  \
# 0                  2             2              1                      0
# 1                  2             2              1                      1
# 2                  2             2              0                      2
# 3                  2             2              1                      5
# 4                  2             2              1                      6
# ...              ...           ...            ...                    ...
# 8907               1             2              0                      3
# 8908               1             1              1                      3
# 8909               1             2              1                      0
# 8910               1             1              0                      6
# 8911               0             0              1                      6
#
#       InsuredOccupation  DateOfPolicyCoverage  InsurancePolicyState  \
# 0                    11                  3554                     0
# 1                     1                  1880                     1
# 2                     3                  1590                     0
# 3                     0                  1054                     1
# 4                     2                  2718                     1
# ...                 ...                   ...                   ...
# 8907                 12                   411                     1
# 8908                  8                  4147                     0
# 8909                  6                  2544                     0
# 8910                 13                  1872                     0
# 8911                  7                   989                     0
#
#       Policy_CombinedSingleLimit  InsuredRelationship  VehicleMake  \
# 0                              5                    0            2
# 1                              3                    2            1
# 2                              4                    5           13
# 3                              6                    3            9
# 4                              3                    0           11
# ...                          ...                  ...          ...
# 8907                           5                    3            4
# 8908                           4                    4            4
# 8909                           3                    3           12
# 8910                           3                    3            7
# 8911                           5                    4           13
#
#       VehicleModel
# 0               30
# 1               16
# 2                4
# 3               25
# 4               10
# ...            ...
# 8907             5
# 8908            29
# 8909             9
# 8910            17
# 8911            24
#
# [8912 rows x 18 columns]

# %%
Fraud_detect_test.drop(Fraud_detect_test[['TypeOfIncident', 'TypeOfCollission', 'SeverityOfIncident',
       'AuthoritiesContacted', 'IncidentState', 'IncidentCity',
       'IncidentAddress', 'PropertyDamage', 'PoliceReport', 'InsuredGender',
       'InsuredEducationLevel', 'InsuredOccupation', 'DateOfPolicyCoverage',
       'InsurancePolicyState', 'Policy_CombinedSingleLimit',
       'InsuredRelationship', 'VehicleMake', 'VehicleModel']], axis=1, inplace=True)

# %%
Fraud_detect_test
# Out:
#      CustomerID  IncidentTime  NumberOfVehicles  BodilyInjuries  Witnesses  \
# 0     Cust10008             4                 3               0          0
# 1     Cust10010            16                 1               1          1
# 2     Cust10015            20                 3               0          1
# 3     Cust10020            10                 1               2          1
# 4      Cust1003             7                 3               2          3
# ...         ...           ...               ...             ...        ...
# 8907   Cust9984            10                 1               1          0
# 8908   Cust9986            19                 1               1          1
# 8909   Cust9990             9                 1               1          2
# 8910   Cust9995            19                 1               0          2
# 8911   Cust9998            10                 1               2          2
#
#       AmountOfTotalClaim  AmountOfInjuryClaim  AmountOfPropertyClaim  \
# 0                68354.0                 6835                   8059
# 1                55270.0                 8113                   5240
# 2                59515.0                 7490                   9110
# 3                 4941.0                  494                    866
# 4                34650.0                 7700                   3850
# ...                  ...                  ...                    ...
# 8907             61296.0                 5785                   8861
# 8908             86729.0                 9698                   9698
# 8909             65328.0                12455                   9281
# 8910             71118.0                11977                  11604
# 8911             67499.0                11681                   5841
#
#       AmountOfVehicleDamage  InsuredAge  InsuredZipCode  CapitalGains  \
# 0                     53460          27          471704         56400
# 1                     41917          40          455810         56700
# 2                     42915          39          461919         30400
# 3                      3581          38          600904         68500
# 4                     23100          29          430632         35100
# ...                     ...         ...             ...           ...
# 8907                  46650          28          446435             0
# 8908                  67333          30          438237         39600
# 8909                  43592          44          450339         25000
# 8910                  47537          29          439304         75800
# 8911                  49977          38          450730         51500
#
#       CapitalLoss  InsurancePolicyNumber  CustomerLoyaltyPeriod  \
# 0          -57000                 119129                     84
# 1          -65600                 119131                    232
# 2               0                 119136                    218
# 3               0                 119141                    205
# 4               0                 110124                    134
# ...           ...                    ...                    ...
# 8907       -53700                 119105                     94
# 8908       -64300                 119107                    115
# 8909            0                 119111                    297
# 8910       -28800                 119116                     94
# 8911       -74300                 119119                    208
#
#       Policy_Deductible  PolicyAnnualPremium  UmbrellaLimit  VehicleYOM
# 0                  2000              1006.00              0        1995
# 1                   500              1279.17              0        2006
# 2                  1000              1454.67        1235986        2010
# 3                  2000              1287.76        5873212        2009
# 4                  2000              1413.14        5000000        2007
# ...                 ...                  ...            ...         ...
# 8907                673              1104.02        1959277        2000
# 8908                574               961.46              0        2000
# 8909               1216              1560.49              0        1998
# 8910               1950              1577.48              0        2002
# 8911               2000               928.75        3701890        2007
#
# [8912 rows x 19 columns]

# %%
final_test = pd.concat([Fraud_detect_test, df_test], axis=1)
final_test
# Out:
#      CustomerID  IncidentTime  NumberOfVehicles  BodilyInjuries  Witnesses  \
# 0     Cust10008             4                 3               0          0
# 1     Cust10010            16                 1               1          1
# 2     Cust10015            20                 3               0          1
# 3     Cust10020            10                 1               2          1
# 4      Cust1003             7                 3               2          3
# ...         ...           ...               ...             ...        ...
# 8907   Cust9984            10                 1               1          0
# 8908   Cust9986            19                 1               1          1
# 8909   Cust9990             9                 1               1          2
# 8910   Cust9995            19                 1               0          2
# 8911   Cust9998            10                 1               2          2
#
#       AmountOfTotalClaim  AmountOfInjuryClaim  AmountOfPropertyClaim  \
# 0                68354.0                 6835                   8059
# 1                55270.0                 8113                   5240
# 2                59515.0                 7490                   9110
# 3                 4941.0                  494                    866
# 4                34650.0                 7700                   3850
# ...                  ...                  ...                    ...
# 8907             61296.0                 5785                   8861
# 8908             86729.0                 9698                   9698
# 8909             65328.0                12455                   9281
# 8910             71118.0                11977                  11604
# 8911             67499.0                11681                   5841
#
#       AmountOfVehicleDamage  InsuredAge  InsuredZipCode  CapitalGains  \
# 0                     53460          27          471704         56400
# 1                     41917          40          455810         56700
# 2                     42915          39          461919         30400
# 3                      3581          38          600904         68500
# 4                     23100          29          430632         35100
# ...                     ...         ...             ...           ...
# 8907                  46650          28          446435             0
# 8908                  67333          30          438237         39600
# 8909                  43592          44          450339         25000
# 8910                  47537          29          439304         75800
# 8911                  49977          38          450730         51500
#
#       CapitalLoss  InsurancePolicyNumber  CustomerLoyaltyPeriod  \
# 0          -57000                 119129                     84
# 1          -65600                 119131                    232
# 2               0                 119136                    218
# 3               0                 119141                    205
# 4               0                 110124                    134
# ...           ...                    ...                    ...
# 8907       -53700                 119105                     94
# 8908       -64300                 119107                    115
# 8909            0                 119111                    297
# 8910       -28800                 119116                     94
# 8911       -74300                 119119                    208
#
#       Policy_Deductible  PolicyAnnualPremium  UmbrellaLimit  VehicleYOM  \
# 0                  2000              1006.00              0        1995
# 1                   500              1279.17              0        2006
# 2                  1000              1454.67        1235986        2010
# 3                  2000              1287.76        5873212        2009
# 4                  2000              1413.14        5000000        2007
# ...                 ...                  ...            ...         ...
# 8907                673              1104.02        1959277        2000
# 8908                574               961.46              0        2000
# 8909               1216              1560.49              0        1998
# 8910               1950              1577.48              0        2002
# 8911               2000               928.75        3701890        2007
#
#       TypeOfIncident  TypeOfCollission  SeverityOfIncident  \
# 0                  3                 1                   2
# 1                  1                 2                   2
# 2                  3                 2                   2
# 3                  2                 2                   3
# 4                  3                 2                   2
# ...              ...               ...                 ...
# 8907               1                 2                   1
# 8908               1                 1                   1
# 8909               1                 2                   2
# 8910               1                 0                   2
# 8911               1                 1                   1
#
#       AuthoritiesContacted  IncidentState  IncidentCity  IncidentAddress  \
# 0                        2              4             0              258
# 1                        3              1             5              152
# 2                        4              4             0              639
# 3                        0              3             5              640
# 4                        4              4             0              385
# ...                    ...            ...           ...              ...
# 8907                     4              4             3              894
# 8908                     1              4             0              186
# 8909                     1              4             0              171
# 8910                     4              2             2              289
# 8911                     1              3             2              790
#
#       PropertyDamage  PoliceReport  InsuredGender  InsuredEducationLevel  \
# 0                  2             2              1                      0
# 1                  2             2              1                      1
# 2                  2             2              0                      2
# 3                  2             2              1                      5
# 4                  2             2              1                      6
# ...              ...           ...            ...                    ...
# 8907               1             2              0                      3
# 8908               1             1              1                      3
# 8909               1             2              1                      0
# 8910               1             1              0                      6
# 8911               0             0              1                      6
#
#       InsuredOccupation  DateOfPolicyCoverage  InsurancePolicyState  \
# 0                    11                  3554                     0
# 1                     1                  1880                     1
# 2                     3                  1590                     0
# 3                     0                  1054                     1
# 4                     2                  2718                     1
# ...                 ...                   ...                   ...
# 8907                 12                   411                     1
# 8908                  8                  4147                     0
# 8909                  6                  2544                     0
# 8910                 13                  1872                     0
# 8911                  7                   989                     0
#
#       Policy_CombinedSingleLimit  InsuredRelationship  VehicleMake  \
# 0                              5                    0            2
# 1                              3                    2            1
# 2                              4                    5           13
# 3                              6                    3            9
# 4                              3                    0           11
# ...                          ...                  ...          ...
# 8907                           5                    3            4
# 8908                           4                    4            4
# 8909                           3                    3           12
# 8910                           3                    3            7
# 8911                           5                    4           13
#
#       VehicleModel
# 0               30
# 1               16
# 2                4
# 3               25
# 4               10
# ...            ...
# 8907             5
# 8908            29
# 8909             9
# 8910            17
# 8911            24
#
# [8912 rows x 37 columns]

# %%
final_test.set_index('CustomerID',inplace=True)

# %%
final_test
# Out:
#             IncidentTime  NumberOfVehicles  BodilyInjuries  Witnesses  \
# CustomerID
# Cust10008              4                 3               0          0
# Cust10010             16                 1               1          1
# Cust10015             20                 3               0          1
# Cust10020             10                 1               2          1
# Cust1003               7                 3               2          3
# ...                  ...               ...             ...        ...
# Cust9984              10                 1               1          0
# Cust9986              19                 1               1          1
# Cust9990               9                 1               1          2
# Cust9995              19                 1               0          2
# Cust9998              10                 1               2          2
#
#             AmountOfTotalClaim  AmountOfInjuryClaim  AmountOfPropertyClaim  \
# CustomerID
# Cust10008              68354.0                 6835                   8059
# Cust10010              55270.0                 8113                   5240
# Cust10015              59515.0                 7490                   9110
# Cust10020               4941.0                  494                    866
# Cust1003               34650.0                 7700                   3850
# ...                        ...                  ...                    ...
# Cust9984               61296.0                 5785                   8861
# Cust9986               86729.0                 9698                   9698
# Cust9990               65328.0                12455                   9281
# Cust9995               71118.0                11977                  11604
# Cust9998               67499.0                11681                   5841
#
#             AmountOfVehicleDamage  InsuredAge  InsuredZipCode  CapitalGains  \
# CustomerID
# Cust10008                   53460          27          471704         56400
# Cust10010                   41917          40          455810         56700
# Cust10015                   42915          39          461919         30400
# Cust10020                    3581          38          600904         68500
# Cust1003                    23100          29          430632         35100
# ...                           ...         ...             ...           ...
# Cust9984                    46650          28          446435             0
# Cust9986                    67333          30          438237         39600
# Cust9990                    43592          44          450339         25000
# Cust9995                    47537          29          439304         75800
# Cust9998                    49977          38          450730         51500
#
#             CapitalLoss  InsurancePolicyNumber  CustomerLoyaltyPeriod  \
# CustomerID
# Cust10008        -57000                 119129                     84
# Cust10010        -65600                 119131                    232
# Cust10015             0                 119136                    218
# Cust10020             0                 119141                    205
# Cust1003              0                 110124                    134
# ...                 ...                    ...                    ...
# Cust9984         -53700                 119105                     94
# Cust9986         -64300                 119107                    115
# Cust9990              0                 119111                    297
# Cust9995         -28800                 119116                     94
# Cust9998         -74300                 119119                    208
#
#             Policy_Deductible  PolicyAnnualPremium  UmbrellaLimit  VehicleYOM  \
# CustomerID
# Cust10008                2000              1006.00              0        1995
# Cust10010                 500              1279.17              0        2006
# Cust10015                1000              1454.67        1235986        2010
# Cust10020                2000              1287.76        5873212        2009
# Cust1003                 2000              1413.14        5000000        2007
# ...                       ...                  ...            ...         ...
# Cust9984                  673              1104.02        1959277        2000
# Cust9986                  574               961.46              0        2000
# Cust9990                 1216              1560.49              0        1998
# Cust9995                 1950              1577.48              0        2002
# Cust9998                 2000               928.75        3701890        2007
#
#             TypeOfIncident  TypeOfCollission  SeverityOfIncident  \
# CustomerID
# Cust10008                3                 1                   2
# Cust10010                1                 2                   2
# Cust10015                3                 2                   2
# Cust10020                2                 2                   3
# Cust1003                 3                 2                   2
# ...                    ...               ...                 ...
# Cust9984                 1                 2                   1
# Cust9986                 1                 1                   1
# Cust9990                 1                 2                   2
# Cust9995                 1                 0                   2
# Cust9998                 1                 1                   1
#
#             AuthoritiesContacted  IncidentState  IncidentCity  \
# CustomerID
# Cust10008                      2              4             0
# Cust10010                      3              1             5
# Cust10015                      4              4             0
# Cust10020                      0              3             5
# Cust1003                       4              4             0
# ...                          ...            ...           ...
# Cust9984                       4              4             3
# Cust9986                       1              4             0
# Cust9990                       1              4             0
# Cust9995                       4              2             2
# Cust9998                       1              3             2
#
#             IncidentAddress  PropertyDamage  PoliceReport  InsuredGender  \
# CustomerID
# Cust10008               258               2             2              1
# Cust10010               152               2             2              1
# Cust10015               639               2             2              0
# Cust10020               640               2             2              1
# Cust1003                385               2             2              1
# ...                     ...             ...           ...            ...
# Cust9984                894               1             2              0
# Cust9986                186               1             1              1
# Cust9990                171               1             2              1
# Cust9995                289               1             1              0
# Cust9998                790               0             0              1
#
#             InsuredEducationLevel  InsuredOccupation  DateOfPolicyCoverage  \
# CustomerID
# Cust10008                       0                 11                  3554
# Cust10010                       1                  1                  1880
# Cust10015                       2                  3                  1590
# Cust10020                       5                  0                  1054
# Cust1003                        6                  2                  2718
# ...                           ...                ...                   ...
# Cust9984                        3                 12                   411
# Cust9986                        3                  8                  4147
# Cust9990                        0                  6                  2544
# Cust9995                        6                 13                  1872
# Cust9998                        6                  7                   989
#
#             InsurancePolicyState  Policy_CombinedSingleLimit  \
# CustomerID
# Cust10008                      0                           5
# Cust10010                      1                           3
# Cust10015                      0                           4
# Cust10020                      1                           6
# Cust1003                       1                           3
# ...                          ...                         ...
# Cust9984                       1                           5
# Cust9986                       0                           4
# Cust9990                       0                           3
# Cust9995                       0                           3
# Cust9998                       0                           5
#
#             InsuredRelationship  VehicleMake  VehicleModel
# CustomerID
# Cust10008                     0            2            30
# Cust10010                     2            1            16
# Cust10015                     5           13             4
# Cust10020                     3            9            25
# Cust1003                      0           11            10
# ...                         ...          ...           ...
# Cust9984                      3            4             5
# Cust9986                      4            4            29
# Cust9990                      3           12             9
# Cust9995                      3            7            17
# Cust9998                      4           13            24
#
# [8912 rows x 36 columns]

# %%
final_test.dtypes
# Out:
# IncidentTime                    int64
# NumberOfVehicles                int64
# BodilyInjuries                  int64
# Witnesses                       int64
# AmountOfTotalClaim            float64
# AmountOfInjuryClaim             int64
# AmountOfPropertyClaim           int64
# AmountOfVehicleDamage           int64
# InsuredAge                      int64
# InsuredZipCode                  int64
# CapitalGains                    int64
# CapitalLoss                     int64
# InsurancePolicyNumber           int64
# CustomerLoyaltyPeriod           int64
# Policy_Deductible               int64
# PolicyAnnualPremium           float64
# UmbrellaLimit                   int64
# VehicleYOM                      int64
# TypeOfIncident                  int64
# TypeOfCollission                int64
# SeverityOfIncident              int64
# AuthoritiesContacted            int64
# IncidentState                   int64
# IncidentCity                    int64
# IncidentAddress                 int64
# PropertyDamage                  int64
# PoliceReport                    int64
# InsuredGender                   int64
# InsuredEducationLevel           int64
# InsuredOccupation               int64
# DateOfPolicyCoverage            int64
# InsurancePolicyState            int64
# Policy_CombinedSingleLimit      int64
# InsuredRelationship             int64
# VehicleMake                     int64
# VehicleModel                    int64
# dtype: object

# %%
x_test=final_test

# %%
x_test
# Out:
#             IncidentTime  NumberOfVehicles  BodilyInjuries  Witnesses  \
# CustomerID
# Cust10008              4                 3               0          0
# Cust10010             16                 1               1          1
# Cust10015             20                 3               0          1
# Cust10020             10                 1               2          1
# Cust1003               7                 3               2          3
# ...                  ...               ...             ...        ...
# Cust9984              10                 1               1          0
# Cust9986              19                 1               1          1
# Cust9990               9                 1               1          2
# Cust9995              19                 1               0          2
# Cust9998              10                 1               2          2
#
#             AmountOfTotalClaim  AmountOfInjuryClaim  AmountOfPropertyClaim  \
# CustomerID
# Cust10008              68354.0                 6835                   8059
# Cust10010              55270.0                 8113                   5240
# Cust10015              59515.0                 7490                   9110
# Cust10020               4941.0                  494                    866
# Cust1003               34650.0                 7700                   3850
# ...                        ...                  ...                    ...
# Cust9984               61296.0                 5785                   8861
# Cust9986               86729.0                 9698                   9698
# Cust9990               65328.0                12455                   9281
# Cust9995               71118.0                11977                  11604
# Cust9998               67499.0                11681                   5841
#
#             AmountOfVehicleDamage  InsuredAge  InsuredZipCode  CapitalGains  \
# CustomerID
# Cust10008                   53460          27          471704         56400
# Cust10010                   41917          40          455810         56700
# Cust10015                   42915          39          461919         30400
# Cust10020                    3581          38          600904         68500
# Cust1003                    23100          29          430632         35100
# ...                           ...         ...             ...           ...
# Cust9984                    46650          28          446435             0
# Cust9986                    67333          30          438237         39600
# Cust9990                    43592          44          450339         25000
# Cust9995                    47537          29          439304         75800
# Cust9998                    49977          38          450730         51500
#
#             CapitalLoss  InsurancePolicyNumber  CustomerLoyaltyPeriod  \
# CustomerID
# Cust10008        -57000                 119129                     84
# Cust10010        -65600                 119131                    232
# Cust10015             0                 119136                    218
# Cust10020             0                 119141                    205
# Cust1003              0                 110124                    134
# ...                 ...                    ...                    ...
# Cust9984         -53700                 119105                     94
# Cust9986         -64300                 119107                    115
# Cust9990              0                 119111                    297
# Cust9995         -28800                 119116                     94
# Cust9998         -74300                 119119                    208
#
#             Policy_Deductible  PolicyAnnualPremium  UmbrellaLimit  VehicleYOM  \
# CustomerID
# Cust10008                2000              1006.00              0        1995
# Cust10010                 500              1279.17              0        2006
# Cust10015                1000              1454.67        1235986        2010
# Cust10020                2000              1287.76        5873212        2009
# Cust1003                 2000              1413.14        5000000        2007
# ...                       ...                  ...            ...         ...
# Cust9984                  673              1104.02        1959277        2000
# Cust9986                  574               961.46              0        2000
# Cust9990                 1216              1560.49              0        1998
# Cust9995                 1950              1577.48              0        2002
# Cust9998                 2000               928.75        3701890        2007
#
#             TypeOfIncident  TypeOfCollission  SeverityOfIncident  \
# CustomerID
# Cust10008                3                 1                   2
# Cust10010                1                 2                   2
# Cust10015                3                 2                   2
# Cust10020                2                 2                   3
# Cust1003                 3                 2                   2
# ...                    ...               ...                 ...
# Cust9984                 1                 2                   1
# Cust9986                 1                 1                   1
# Cust9990                 1                 2                   2
# Cust9995                 1                 0                   2
# Cust9998                 1                 1                   1
#
#             AuthoritiesContacted  IncidentState  IncidentCity  \
# CustomerID
# Cust10008                      2              4             0
# Cust10010                      3              1             5
# Cust10015                      4              4             0
# Cust10020                      0              3             5
# Cust1003                       4              4             0
# ...                          ...            ...           ...
# Cust9984                       4              4             3
# Cust9986                       1              4             0
# Cust9990                       1              4             0
# Cust9995                       4              2             2
# Cust9998                       1              3             2
#
#             IncidentAddress  PropertyDamage  PoliceReport  InsuredGender  \
# CustomerID
# Cust10008               258               2             2              1
# Cust10010               152               2             2              1
# Cust10015               639               2             2              0
# Cust10020               640               2             2              1
# Cust1003                385               2             2              1
# ...                     ...             ...           ...            ...
# Cust9984                894               1             2              0
# Cust9986                186               1             1              1
# Cust9990                171               1             2              1
# Cust9995                289               1             1              0
# Cust9998                790               0             0              1
#
#             InsuredEducationLevel  InsuredOccupation  DateOfPolicyCoverage  \
# CustomerID
# Cust10008                       0                 11                  3554
# Cust10010                       1                  1                  1880
# Cust10015                       2                  3                  1590
# Cust10020                       5                  0                  1054
# Cust1003                        6                  2                  2718
# ...                           ...                ...                   ...
# Cust9984                        3                 12                   411
# Cust9986                        3                  8                  4147
# Cust9990                        0                  6                  2544
# Cust9995                        6                 13                  1872
# Cust9998                        6                  7                   989
#
#             InsurancePolicyState  Policy_CombinedSingleLimit  \
# CustomerID
# Cust10008                      0                           5
# Cust10010                      1                           3
# Cust10015                      0                           4
# Cust10020                      1                           6
# Cust1003                       1                           3
# ...                          ...                         ...
# Cust9984                       1                           5
# Cust9986                       0                           4
# Cust9990                       0                           3
# Cust9995                       0                           3
# Cust9998                       0                           5
#
#             InsuredRelationship  VehicleMake  VehicleModel
# CustomerID
# Cust10008                     0            2            30
# Cust10010                     2            1            16
# Cust10015                     5           13             4
# Cust10020                     3            9            25
# Cust1003                      0           11            10
# ...                         ...          ...           ...
# Cust9984                      3            4             5
# Cust9986                      4            4            29
# Cust9990                      3           12             9
# Cust9995                      3            7            17
# Cust9998                      4           13            24
#
# [8912 rows x 36 columns]

# %%
def StandardScaler(X):
    mean = np.mean(X, axis=0)
    std = np.std(X, axis=0)
    a=((X - mean) / std)
    return a

# %%
x_test=StandardScaler(x_test)

# %%
# def min_max_scaler(X):
    
#     min_val = np.min(X)
#     max_val = np.max(X)
#     scaled_X = (X - min_val) / (max_val - min_val)
#     return scaled_X

# %%
# x_test=min_max_scaler(x_test)

# %%
def normalize(X):
    x_min = np.min(X)
    x_max = np.max(X)
    X_normalized = (X - x_min) / (x_max - x_min)
    return X_normalized
normalize(x_test)
# Out:
#             IncidentTime  NumberOfVehicles  BodilyInjuries  Witnesses  \
# CustomerID
# Cust10008       0.321429          0.666667             0.0   0.000000
# Cust10010       0.750000          0.000000             0.5   0.333333
# Cust10015       0.892857          0.666667             0.0   0.333333
# Cust10020       0.535714          0.000000             1.0   0.333333
# Cust1003        0.428571          0.666667             1.0   1.000000
# ...                  ...               ...             ...        ...
# Cust9984        0.535714          0.000000             0.5   0.000000
# Cust9986        0.857143          0.000000             0.5   0.333333
# Cust9990        0.500000          0.000000             0.5   0.666667
# Cust9995        0.857143          0.000000             0.0   0.666667
# Cust9998        0.535714          0.000000             1.0   0.666667
#
#             AmountOfTotalClaim  AmountOfInjuryClaim  AmountOfPropertyClaim  \
# CustomerID
# Cust10008             0.608216             0.325647               0.342965
# Cust10010             0.491624             0.386536               0.222998
# Cust10015             0.529451             0.356854               0.387693
# Cust10020             0.043138             0.023536               0.036854
# Cust1003              0.307877             0.366859               0.163844
# ...                        ...                  ...                    ...
# Cust9984              0.545322             0.275621               0.377096
# Cust9986              0.771957             0.462052               0.412716
# Cust9990              0.581251             0.593406               0.394970
# Cust9995              0.632846             0.570632               0.493829
# Cust9998              0.600597             0.556530               0.248574
#
#             AmountOfVehicleDamage  InsuredAge  InsuredZipCode  CapitalGains  \
# CustomerID
# Cust10008                0.687218    0.177778        0.217963      0.561194
# Cust10010                0.538641    0.466667        0.134687      0.564179
# Cust10015                0.551487    0.444444        0.166695      0.302488
# Cust10020                0.045192    0.422222        0.894906      0.681592
# Cust1003                 0.296435    0.222222        0.002766      0.349254
# ...                           ...         ...             ...           ...
# Cust9984                 0.599562    0.200000        0.085566      0.000000
# Cust9986                 0.865787    0.244444        0.042613      0.394030
# Cust9990                 0.560201    0.555556        0.106021      0.248756
# Cust9995                 0.610980    0.222222        0.048203      0.754229
# Cust9998                 0.642386    0.422222        0.108070      0.512438
#
#             CapitalLoss  InsurancePolicyNumber  CustomerLoyaltyPeriod  \
# CustomerID
# Cust10008      0.486949               0.233939               0.175732
# Cust10010      0.409541               0.233991               0.485356
# Cust10015      1.000000               0.234120               0.456067
# Cust10020      1.000000               0.234250               0.428870
# Cust1003       1.000000               0.000000               0.280335
# ...                 ...                    ...                    ...
# Cust9984       0.516652               0.233315               0.196653
# Cust9998                 1.000000           0.538462              0.218226
#
#             InsurancePolicyState  Policy_CombinedSingleLimit  \
# CustomerID
# Cust10008                    0.0                       0.625
# Cust10010                    0.5                       0.375
# Cust10015                    0.0                       0.500
# Cust10020                    0.5                       0.750
# Cust1003                     0.5                       0.375
# ...                          ...                         ...
# Cust9984                     0.5                       0.625
# Cust9986                     0.0                       0.500
# Cust9990                     0.0                       0.375
# Cust9995                     0.0                       0.375
# Cust9998                     0.0                       0.625
#
#             InsuredRelationship  VehicleMake  VehicleModel
# CustomerID
# Cust10008                   0.0     0.153846      0.810811
# Cust10010                   0.4     0.076923      0.432432
# Cust10015                   1.0     1.000000      0.108108
# Cust10020                   0.6     0.692308      0.675676
# Cust1003                    0.0     0.846154      0.270270
# ...                         ...          ...           ...
# Cust9984                    0.6     0.307692      0.135135
# Cust9986                    0.8     0.307692      0.783784
# Cust9990                    0.6     0.923077      0.243243
# Cust9995                    0.6     0.538462      0.459459
# Cust9998                    0.8     1.000000      0.648649
#
# [8912 rows x 36 columns]

# %% [markdown]
# # Without Keras Model

# %%
class ANN:
    
    def predict(self,X, y, parameters,active_func_h,active_func_o):
        m = X.shape[1]
        p = np.zeros((1,m), dtype = np.int64)
        a3, caches = self.forward_propagation(X, parameters,active_func_h,active_func_o)
        for i in range(0, a3.shape[1]):
            if a3[0,i] > 0.5:
                p[0,i] = 1
            else:
                p[0,i] = 0
        #print("Accuracy: "  + str(np.mean((p[0,:] == y[0]))))
        a=str(np.mean((p[0,:] == y[0])))
        return p,a
    
    def predict_ann(self,x_test, parameters, active_func_h, active_func_o):
        m = x_test.shape[1]
        p = np.zeros((1,m), dtype=np.int64)
        a3, caches = self.forward_propagation(x_test, parameters, active_func_h, active_func_o)
        for i in range(0, a3.shape[1]):
            if a3[0,i] > 0.5:
                p[0,i] = 1
            else:
                p[0,i] = 0
        return p

    def update_parameters_with_gd(self,parameters, grads, learning_rate):
        L = len(parameters) // 2 # number of layers in the neural networks
        for l in range(L):
            parameters["W" + str(l+1)] = parameters["W" + str(l+1)] - learning_rate * grads["dW" + str(l+1)]
            parameters["b" + str(l+1)] = parameters["b" + str(l+1)] - learning_rate * grads["db" + str(l+1)]
        return parameters

    def backward_propagation(self,X, Y, cache):
        m = X.shape[1]
        (z1, a1, W1, b1, z2, a2, W2, b2, z3, a3, W3, b3) = cache

        dz3 = 1./m * (a3 - Y)
        dW3 = np.dot(dz3, a2.T)
        db3 = np.sum(dz3, axis=1, keepdims = True)
        
        da2 = np.dot(W3.T, dz3)
        dz2 = np.multiply(da2, np.int64(a2 > 0))
        dW2 = np.dot(dz2, a1.T)
        db2 = np.sum(dz2, axis=1, keepdims = True)
        
        da1 = np.dot(W2.T, dz2)
        dz1 = np.multiply(da1, np.int64(a1 > 0))
        dW1 = np.dot(dz1, X.T)
        db1 = np.sum(dz1, axis=1, keepdims = True)
        
        gradients = {"dz3": dz3, "dW3": dW3, "db3": db3,
                 "da2": da2, "dz2": dz2, "dW2": dW2, "db2": db2,
                 "da1": da1, "dz1": dz1, "dW1": dW1, "db1": db1}
    
        return gradients

    def compute_cost(self,a3, Y):
        m = Y.shape[1]
        logprobs = np.multiply(-np.log(a3),Y) + np.multiply(-np.log(1 - a3), 1 - Y)
        cost = 1./m * np.sum(logprobs)
        return cost

    def relu(self,x):
        s = np.maximum(0,x)
        return s
    
    def sigmoid(self,x):
        s = 1/(1+np.exp(-x))
        return s
    
    def leaky_relu(self,x, alpha=0.01):
        return np.maximum(alpha*x, x)

    def tanh(self,x):
        return np.tanh(x)

    def softmax(self,x):
        e_x = np.exp(x - np.max(x))
        return e_x / e_x.sum()

    def elu(self,z, alpha=1):
        return np.where(z < 0, alpha * (np.exp(z) - 1), z)

    def swish(self,z, beta=1):
        return z / (1 + np.exp(-beta * z))

    def softplus(self,z):
        return np.log(1 + np.exp(z))

    def softsign(self,z):
        return z / (1 + np.abs(z))


    def forward_propagation(self,X, parameters,active_func_h,active_func_o):
        W1 = parameters["W1"]
        b1 = parameters["b1"]
        W2 = parameters["W2"]
        b2 = parameters["b2"]
        W3 = parameters["W3"]
        b3 = parameters["b3"]
        
        if(active_func_h =='sigmoid'):
            z1 = np.dot(W1, X) + b1
            a1 = self.sigmoid(z1)
            z2 = np.dot(W2, a1) + b2
            a2 = self.sigmoid(z2)
            
        elif(active_func_h=='relu'):
            z1 = np.dot(W1, X) + b1
            a1 = self.relu(z1)
            z2 = np.dot(W2, a1) + b2
            a2 = self.relu(z2)
            
        elif(active_func_h=='leaky_relu'):
            z1 = np.dot(W1, X) + b1
            a1 = self.leaky_relu(z1)
            z2 = np.dot(W2, a1) + b2
            a2 = self.leaky_relu(z2)
            
        elif(active_func_h=='tanh'):
            z1 = np.dot(W1, X) + b1
            a1 = self.tanh(z1)
            z2 = np.dot(W2, a1) + b2
            a2 = self.tanh(z2)
            
        elif(active_func_h=='elu'):
            z1 = np.dot(W1, X) + b1
            a1 = self.elu(z1)
            z2 = np.dot(W2, a1) + b2
            a2 = self.elu(z2)
            
        elif(active_func_h=='softplus'):
            z1 = np.dot(W1, X) + b1
            a1 = self.softplus(z1)
            z2 = np.dot(W2, a1) + b2
            a2 = self.softplus(z2)
        
        if(active_func_o=='sigmoid'):
            z3 = np.dot(W3, a2) + b3
            a3 = self.sigmoid(z3)
        
        elif(active_func_o=='softmax'):
            z3 = np.dot(W3, a2) + b3
            a3 = self.softmax(z3)
        
    
        cache = (z1, a1, W1, b1, z2, a2, W2, b2, z3, a3, W3, b3)
    
        return a3, cache

    def random_mini_batches(self,X, Y, mini_batch_size = 64, seed = 0):
    
        np.random.seed(seed)            
        m = X.shape[1]                 
        mini_batches = []
        
        permutation = list(np.random.permutation(m))   
        shuffled_X = X.iloc[:, permutation]
        shuffled_Y = Y[permutation].values.reshape((1, m))
        #shuffled_Y = Y[permutation].reshape((1, m))
        

        num_complete_minibatches = math.floor(m/mini_batch_size) 
        for k in range(0, num_complete_minibatches):
            mini_batch_X = shuffled_X[:, k * mini_batch_size : (k + 1) * mini_batch_size]
            mini_batch_Y = shuffled_Y[:, k * mini_batch_size : (k + 1) * mini_batch_size]
            mini_batch = (mini_batch_X, mini_batch_Y)
            mini_batches.append(mini_batch)
    
        if m % mini_batch_size != 0:
            mini_batch_X = shuffled_X.iloc[:, num_complete_minibatches * mini_batch_size : ]
            mini_batch_Y = shuffled_Y[:, num_complete_minibatches * mini_batch_size : ]
            mini_batch = (mini_batch_X, mini_batch_Y)
            mini_batches.append(mini_batch)
    
        return mini_batches

    def initialize_parameters(self,layer_dims):
        np.random.seed(3)
        parameters = {}
        L = len(layer_dims) # number of layers in the network

        for l in range(1, L):
            parameters['W' + str(l)] = np.random.randn(layer_dims[l], layer_dims[l-1])*  np.sqrt(2 / layer_dims[l-1])
            parameters['b' + str(l)] = np.zeros((layer_dims[l], 1))
        
            assert (parameters['W' + str(l)].shape == layer_dims[l], layer_dims[l-1])
            assert (parameters['W' + str(l)].shape == layer_dims[l], 1)
        
        return parameters
    # GRADED FUNCTION: update_parameters_with_momentum

    def update_parameters_with_momentum(self,parameters, grads, v, beta, learning_rate):
  
        L = len(parameters) // 2
        for l in range(L):
            v["dW" + str(l+1)] = beta * v["dW" + str(l+1)] + (1 - beta) * grads["dW" + str(l+1)]
            v["db" + str(l+1)] = beta * v["db" + str(l+1)] + (1 - beta) * grads["db" + str(l+1)]
            parameters["W" + str(l+1)] = parameters["W" + str(l+1)] - learning_rate * v["dW" + str(l+1)]
            parameters["b" + str(l+1)] = parameters["b" + str(l+1)] - learning_rate * v["db" + str(l+1)]
        
        return parameters, v

    def initialize_velocity(self,parameters):
        L = len(parameters) // 2 
        v = {}
        for l in range(L):
            v["dW" + str(l+1)] = np.zeros(parameters["W"+str(l+1)].shape)
            v["db" + str(l+1)] = np.zeros(parameters["b"+str(l+1)].shape)
        return v
    
    def update_parameters_with_adam(self,parameters, grads, v, s, t, learning_rate = 0.01,
                                beta1 = 0.9, beta2 = 0.999,  epsilon = 1e-8):
        L = len(parameters) // 2                 
        v_corrected = {}                         
        s_corrected = {}                         
    
        for l in range(L):
            v["dW" + str(l+1)] = beta1 * v["dW" + str(l+1)] + (1 - beta1) * grads["dW" + str(l+1)]
            v["db" + str(l+1)] = beta1 * v["db" + str(l+1)] + (1 - beta1) * grads["db" + str(l+1)]
            v_corrected["dW" + str(l+1)] = v["dW" + str(l+1)] / (1 - beta1)
            v_corrected["db" + str(l+1)] = v["db" + str(l+1)] / (1 - beta1)
            s["dW" + str(l+1)] = beta2 * s["dW" + str(l+1)] + (1 - beta2) * (grads["dW" + str(l+1)] * grads["dW" + str(l+1)])
            s["db" + str(l+1)] = beta2 * s["db" + str(l+1)] + (1 - beta2) * (grads["db" + str(l+1)] * grads["db" + str(l+1)])
            s_corrected["dW" + str(l+1)] = s["dW" + str(l+1)] / (1 - beta2)
            s_corrected["db" + str(l+1)] = s["db" + str(l+1)] / (1 - beta2)
            parameters["W" + str(l+1)] = parameters["W" + str(l+1)] - learning_rate * v_corrected["dW" + str(l+1)] / (np.sqrt(s_corrected["dW" + str(l+1)]) + epsilon)
            parameters["b" + str(l+1)] = parameters["b" + str(l+1)] - learning_rate * v_corrected["db" + str(l+1)] / (np.sqrt(s_corrected["db" + str(l+1)]) + epsilon)

        return parameters, v, s

    def initialize_adam(self,parameters):
        L = len(parameters) // 2 
        v = {}
        s = {}
        for l in range(L):
            v["dW" + str(l+1)] = np.zeros(parameters["W" + str(l+1)].shape)
            v["db" + str(l+1)] = np.zeros(parameters["b" + str(l+1)].shape)
            s["dW" + str(l+1)] = np.zeros(parameters["W" + str(l+1)].shape)
            s["db" + str(l+1)] = np.zeros(parameters["b" + str(l+1)].shape)    
        return v, s
    
    def model(self,X, Y, layers_dims, optimizer, learning_rate = 0.0001, mini_batch_size =64, beta = 0.9,
          beta1 = 0.9, beta2 = 0.999,  epsilon = 1e-8, num_epochs = 1000, active_func_h=None, active_func_o=None, print_cost = True):
        acc=0
        L = len(layers_dims)            
        costs = []
        accuracy=[]
        t = 0                            
        seed = 10                        
        parameters = self.initialize_parameters(layers_dims)
        
        if optimizer == "gd":
            pass 
        elif optimizer == "momentum":
            v = self.initialize_velocity(parameters)
        elif optimizer == "adam":
            v, s = self.initialize_adam(parameters)
    
        for i in range(num_epochs):
            seed = seed + 1
            minibatches = self.random_mini_batches(X, Y, mini_batch_size, seed)

            for minibatch in minibatches:
                (minibatch_X, minibatch_Y) = minibatch
                a3, caches = self.forward_propagation(minibatch_X, parameters,active_func_h,active_func_o)
                cost = self.compute_cost(a3, minibatch_Y)
                grads = self.backward_propagation(minibatch_X, minibatch_Y, caches)
                if optimizer == "gd":
                    parameters = self.update_parameters_with_gd(parameters, grads, learning_rate)
                elif optimizer == "momentum":
                    parameters, v = self.update_parameters_with_momentum(parameters, grads, v, beta, learning_rate)
                elif optimizer == "adam":
                    t = t + 1 
                    parameters, v, s = self.update_parameters_with_adam(parameters, grads, v, s,
                                                               t, learning_rate, beta1, beta2,  epsilon)
            
            if print_cost and i % 10 == 0:
                p,a=self.predict(minibatch_X, minibatch_Y, parameters,active_func_h,active_func_o)
                print ("Cost after epoch %i: %f" %(i, cost),'Accuracy: ',a)
            if print_cost and i % 1 == 0:
                costs.append(cost)
                p,a=self.predict(minibatch_X, minibatch_Y, parameters,active_func_h,active_func_o)
                accuracy.append(float(a))
            if print_cost and i == (num_epochs-1):
                p,a=self.predict(minibatch_X, minibatch_Y, parameters,active_func_h,active_func_o)
                acc=a
                
        
        plt.plot(costs)
        plt.ylabel('cost')
        plt.xlabel('epochs (per 100)')
        plt.title("Cost @ Learning rate = " + str(learning_rate))
        plt.show()
        
        plt.plot(accuracy)
        plt.ylabel('accuracy')
        plt.xlabel('epochs (per 100)')
        plt.title("Accuracy @ Learning rate = " + str(learning_rate))
        plt.show()
        print ('Accuracy: ',acc)
        return parameters

# %%
layers_dims = [x.shape[0], 5,3, 1]
adam=ANN()
adam_parameters = adam.model(x, y, layers_dims, optimizer = "adam",active_func_h="relu",active_func_o="sigmoid")
# Out:
# Cost after epoch 0: nan Accuracy:  0.9444444444444444
# Cost after epoch 10: nan Accuracy:  0.9444444444444444
I tensorflow/core/platform/cpu_feature_guard.cc:193] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  SSE4.1 SSE4.2
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 721/721 [==============================] - 1s 880us/step - loss: nan - accuracy: 0.8070 - val_loss: nan - val_accuracy: 0.4145
# Epoch 2/50
# 721/721 [==============================] - 1s 723us/step - loss: nan - accuracy: 0.8089 - val_loss: nan - val_accuracy: 0.4145
# Epoch 3/50
# 721/721 [==============================] - 1s 724us/step - loss: nan - accuracy: 0.8089 - val_loss: nan - val_accuracy: 0.4145
# Epoch 4/50
# 721/721 [==============================] - 1s 724us/step - loss: nan - accuracy: 0.8089 - val_loss: nan - val_accuracy: 0.4145
# Epoch 5/50
# 721/721 [==============================] - 1s 723us/step - loss: nan - accuracy: 0.8089 - val_loss: nan - val_accuracy: 0.4145
# Epoch 6/50
# 721/721 [==============================] - 1s 731us/step - loss: nan - accuracy: 0.8089 - val_loss: nan - val_accuracy: 0.4145
# Epoch 7/50
# 721/721 [==============================] - 1s 728us/step - loss: nan - accuracy: 0.8089 - val_loss: nan - val_accuracy: 0.4145
# Epoch 8/50
# 721/721 [==============================] - 1s 752us/step - loss: nan - accuracy: 0.8089 - val_loss: nan - val_accuracy: 0.4145
# Epoch 9/50
# 721/721 [==============================] - 1s 727us/step - loss: nan - accuracy: 0.8089 - val_loss: nan - val_accuracy: 0.4145
# Epoch 10/50
# 721/721 [==============================] - 1s 724us/step - loss: nan - accuracy: 0.8089 - val_loss: nan - val_accuracy: 0.4145
# Epoch 11/50
# 721/721 [==============================] - 1s 731us/step - loss: nan - accuracy: 0.8089 - val_loss: nan - val_accuracy: 0.4145
# Epoch 12/50
# 721/721 [==============================] - 1s 724us/step - loss: nan - accuracy: 0.8089 - val_loss: nan - val_accuracy: 0.4145
# Epoch 13/50
# 721/721 [==============================] - 1s 724us/step - loss: nan - accuracy: 0.8089 - val_loss: nan - val_accuracy: 0.4145
# Epoch 14/50
# 721/721 [==============================] - 1s 726us/step - loss: nan - accuracy: 0.8089 - val_loss: nan - val_accuracy: 0.4145
# Epoch 15/50
# 721/721 [==============================] - 1s 721us/step - loss: nan - accuracy: 0.8089 - val_loss: nan - val_accuracy: 0.4145
# Epoch 16/50
# 721/721 [==============================] - 1s 723us/step - loss: nan - accuracy: 0.8089 - val_loss: nan - val_accuracy: 0.4145
# Epoch 17/50
# 721/721 [==============================] - 1s 718us/step - loss: nan - accuracy: 0.8089 - val_loss: nan - val_accuracy: 0.4145
# Epoch 18/50
# 721/721 [==============================] - 1s 725us/step - loss: nan - accuracy: 0.8089 - val_loss: nan - val_accuracy: 0.4145
# Epoch 19/50
# 721/721 [==============================] - 1s 722us/step - loss: nan - accuracy: 0.8089 - val_loss: nan - val_accuracy: 0.4145
# Epoch 20/50
# 721/721 [==============================] - 1s 725us/step - loss: nan - accuracy: 0.8089 - val_loss: nan - val_accuracy: 0.4145
# Epoch 21/50
# 721/721 [==============================] - 1s 726us/step - loss: nan - accuracy: 0.8089 - val_loss: nan - val_accuracy: 0.4145
# Epoch 22/50
# 721/721 [==============================] - 1s 723us/step - loss: nan - accuracy: 0.8089 - val_loss: nan - val_accuracy: 0.4145
# Epoch 23/50
# 721/721 [==============================] - 1s 715us/step - loss: nan - accuracy: 0.8089 - val_loss: nan - val_accuracy: 0.4145
# Epoch 24/50
# 721/721 [==============================] - 1s 727us/step - loss: nan - accuracy: 0.8089 - val_loss: nan - val_accuracy: 0.4145
# Epoch 25/50
# 721/721 [==============================] - 1s 722us/step - loss: nan - accuracy: 0.8089 - val_loss: nan - val_accuracy: 0.4145
# Epoch 26/50
# 721/721 [==============================] - 1s 748us/step - loss: nan - accuracy: 0.8089 - val_loss: nan - val_accuracy: 0.4145
# Epoch 27/50
# 721/721 [==============================] - 1s 754us/step - loss: nan - accuracy: 0.8089 - val_loss: nan - val_accuracy: 0.4145
# Epoch 28/50
# 721/721 [==============================] - 1s 780us/step - loss: nan - accuracy: 0.8089 - val_loss: nan - val_accuracy: 0.4145
# Epoch 29/50
# 721/721 [==============================] - 1s 737us/step - loss: nan - accuracy: 0.8089 - val_loss: nan - val_accuracy: 0.4145
# Epoch 30/50
# 721/721 [==============================] - 1s 730us/step - loss: nan - accuracy: 0.8089 - val_loss: nan - val_accuracy: 0.4145
# Epoch 31/50
# 721/721 [==============================] - 1s 718us/step - loss: nan - accuracy: 0.8089 - val_loss: nan - val_accuracy: 0.4145
# Epoch 32/50
# 721/721 [==============================] - 1s 729us/step - loss: nan - accuracy: 0.8089 - val_loss: nan - val_accuracy: 0.4145
# Epoch 33/50
# 721/721 [==============================] - 1s 717us/step - loss: nan - accuracy: 0.8089 - val_loss: nan - val_accuracy: 0.4145
# Epoch 34/50
# 721/721 [==============================] - 1s 733us/step - loss: nan - accuracy: 0.8089 - val_loss: nan - val_accuracy: 0.4145
# Epoch 35/50
# 721/721 [==============================] - 1s 713us/step - loss: nan - accuracy: 0.8089 - val_loss: nan - val_accuracy: 0.4145
# Epoch 36/50
# 721/721 [==============================] - 1s 717us/step - loss: nan - accuracy: 0.8089 - val_loss: nan - val_accuracy: 0.4145
# Epoch 37/50
# 721/721 [==============================] - 1s 716us/step - loss: nan - accuracy: 0.8089 - val_loss: nan - val_accuracy: 0.4145
# Epoch 38/50
# 721/721 [==============================] - 1s 722us/step - loss: nan - accuracy: 0.8089 - val_loss: nan - val_accuracy: 0.4145
# Epoch 39/50
# 721/721 [==============================] - 1s 723us/step - loss: nan - accuracy: 0.8089 - val_loss: nan - val_accuracy: 0.4145
# Epoch 40/50
# 721/721 [==============================] - 1s 744us/step - loss: nan - accuracy: 0.8089 - val_loss: nan - val_accuracy: 0.4145
# Epoch 41/50
# 721/721 [==============================] - 1s 710us/step - loss: nan - accuracy: 0.8089 - val_loss: nan - val_accuracy: 0.4145
# Epoch 42/50
# 721/721 [==============================] - 1s 718us/step - loss: nan - accuracy: 0.8089 - val_loss: nan - val_accuracy: 0.4145
# Epoch 43/50
# 721/721 [==============================] - 1s 716us/step - loss: nan - accuracy: 0.8089 - val_loss: nan - val_accuracy: 0.4145
# Epoch 44/50
# 721/721 [==============================] - 1s 722us/step - loss: nan - accuracy: 0.8089 - val_loss: nan - val_accuracy: 0.4145
# Epoch 45/50
# 721/721 [==============================] - 1s 734us/step - loss: nan - accuracy: 0.8089 - val_loss: nan - val_accuracy: 0.4145
# Epoch 46/50
# 721/721 [==============================] - 1s 731us/step - loss: nan - accuracy: 0.8089 - val_loss: nan - val_accuracy: 0.4145
# Epoch 47/50
# 721/721 [==============================] - 1s 734us/step - loss: nan - accuracy: 0.8089 - val_loss: nan - val_accuracy: 0.4145
# Epoch 48/50
# 721/721 [==============================] - 1s 730us/step - loss: nan - accuracy: 0.8089 - val_loss: nan - val_accuracy: 0.4145
# Epoch 49/50
# 721/721 [==============================] - 1s 735us/step - loss: nan - accuracy: 0.8089 - val_loss: nan - val_accuracy: 0.4145
# Epoch 50/50
# 721/721 [==============================] - 1s 731us/step - loss: nan - accuracy: 0.8089 - val_loss: nan - val_accuracy: 0.4145

# %%
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense (Dense)               (None, 16)                592
#
#  dense_1 (Dense)             (None, 8)                 136
#
#  dropout (Dropout)           (None, 8)                 0
#
#  dense_2 (Dense)             (None, 4)                 36
#
#  dropout_1 (Dropout)         (None, 4)                 0
#
#  dense_3 (Dense)             (None, 1)                 5
#
# =================================================================
# Total params: 769
# Trainable params: 769
# Non-trainable params: 0
# _________________________________________________________________

# %%
val_accuracy = np.mean(history.history['val_accuracy'])
print("\n%s: %.2f%%" % ('val_accuracy', val_accuracy*100))
# Out:
# val_accuracy: 41.45%

# %%
history_df = pd.DataFrame(history.history)

plt.plot(history_df.loc[:, ['loss']], "#6daa9f", label='Training loss')
plt.plot(history_df.loc[:, ['val_loss']],"#774571", label='Validation loss')
plt.title('Training and Validation loss')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.legend(loc="best")

plt.show()

# %%
history_df = pd.DataFrame(history.history)

plt.plot(history_df.loc[:, ['accuracy']], "#6daa9f", label='Training accuracy')
plt.plot(history_df.loc[:, ['val_accuracy']], "#774571", label='Validation accuracy')

plt.title('Training and Validation accuracy')
plt.xlabel('Epochs')
plt.ylabel('Accuracy')
plt.legend()
plt.show()

# %%
y_pred = model.predict(x_test)
y_pred = (y_pred > 0.5)
#print(classification_report(target_test, y_pred))
# Out:
# 279/279 [==============================] - 0s 383us/step
